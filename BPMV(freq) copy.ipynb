# %% [markdown]
# # Cars 4 You: Expending Car Evaluations with ML

# %% [markdown]
# ## 1. Import the needed libraries

# %%
import pandas as pd
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
from sklearn.impute import SimpleImputer
from sklearn.impute import KNNImputer
from sklearn.preprocessing import MinMaxScaler
from sklearn.feature_selection import RFE
from sklearn.linear_model import LinearRegression, Ridge
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error
from sklearn.feature_selection import RFECV
from sklearn.model_selection import KFold
from sklearn.feature_selection import mutual_info_regression
import seaborn as sns
import matplotlib.pyplot as plt
import seaborn as sns
from math import ceil
import numpy as np
import os
from sklearn.metrics import make_scorer 
from sklearn.model_selection import PredefinedSplit

import pandas as pd
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, mean_squared_error
from sklearn.impute import SimpleImputer
from sklearn.impute import KNNImputer
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from sklearn.feature_selection import RFE
from sklearn.linear_model import LinearRegression, Ridge
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestRegressor, ExtraTreesRegressor, HistGradientBoostingRegressor
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error
from sklearn.feature_selection import RFECV
from sklearn.model_selection import KFold
from sklearn.feature_selection import mutual_info_regression
import seaborn as sns
import matplotlib.pyplot as plt
import seaborn as sns
from math import ceil
import numpy as np
import os
# !pip install tensorflow
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.optimizers import Adam
import random
# Out:
# 'pip' is not recognized as an internal or external command,
# operable program or batch file.

# %% [markdown]
# ## 2. Data importation and integration

# %%
train_data = pd.read_csv('project_data/train.csv')
test_data = pd.read_csv('project_data/test.csv')

# %%
data= train_data.copy()

# %% [markdown]
# ## 3. Data exploration and understanding

# %% [markdown]
# ### Metadata
# - *carID*: An attribute that contains an identifier for each car.
# - *Brand*: The car’s main brand (e.g. Ford, Toyota).
# - *model*: The car model.
# - *year*: The year of Registration of the Car.
# - *mileage*: The total reported distance travelled by the car (in
#  miles).
# - *tax*: The amount of road tax (in £) that, in 2020, was
#  applicable to the car in question.
# - *fuelType*: Type of Fuel used by the car (Diesel, Petrol, Hybrid,
#  Electric).
# - *mpg*: Average Miles per Gallon.
# - *engineSize*: Size of Engine in liters (Cubic Decimeters).
# - *paintQuality%*:  The mechanic’s assessment of the cars’ overall paint
#  quality and hull integrity (filled by the mechanic
#  during evaluation).
# - *previousOwners*: Number of previous registered owners of the vehicle.
# - *hasDamage*:  Boolean marker filled by the seller at the time of
#  registration stating whether the car is damaged or
#  not.
# - *price*: The car’s price when purchased by Cars 4 You (in £).

# %% [markdown]
# ### 3.1. Data Overview

# %%
#overview the dataset
data.info()

# %%
#first 20 rows
data.head(20)

# %%
#last 20 rows
data.tail(20)

# %%
#Descriptive statistics for numerical data
data.describe().T

# %%
#Descriptive statistics for categorical data
data.describe(include = ['O'])

# %%
#separate numerical and categorical features 

metric_features = ['year', 'mileage', 'tax', 'mpg',
                    'engineSize', 'paintQuality%', 'previousOwners', 'hasDamage']

non_metric_features= ['Brand','model','transmission','fuelType']

identifier = 'carID'

target = 'price'

# %%
#checking what are the unique values of categorical variables
for col in non_metric_features:
    print(f"\nColumn: {col}")
    print(data[col].unique())

# %% [markdown]
# ### 3.2. Checking Duplicates

# %%
#Number of duplicates
data.duplicated().sum()

# %% [markdown]
# ### 3.3. Checking Missing Values

# %%
#Number of missing values
data.isna().sum()

# %%
#Number of missing values in each column as a percentage
data.isna().sum()/len(data) * 100

# %% [markdown]
# ### 3.4. Checking Outliers

# %%
# Checking outliers of numerical variables through the visualization of boxplots

def plot_multiple_boxplots(data, feats, title="Numeric Variables' Box Plots"):

    # Prepare figure. Create individual axes where each histogram will be placed
    fig, axes = plt.subplots(4, ceil(len(feats) / 4), figsize=(40, 30))

    # Plot data
    # Iterate across axes objects and associate each histogram:
    for ax, feat in zip(axes.flatten(), feats):
        sns.boxplot(x=data[feat], ax=ax, color="#5dade2")
        ax.set_title(feat)

    # Layout
    plt.suptitle(title)
    plt.show()

    return

# %%
plot_multiple_boxplots(data, metric_features)

# %% [markdown]
# ### 3.5. Checking Distributions

# %%
df= pd.DataFrame(data[metric_features])

# %%
# Creating histograms to see the distribrution of numerical variables

num_cols = df.select_dtypes(include=['number']).columns
n = len(num_cols)

# Adjust layout
fig, axes = plt.subplots(nrows=(n // 3) + 1, ncols=3, figsize=(15, 10))
axes = axes.flatten()

for i, col in enumerate(num_cols):
    axes[i].hist(df[col].dropna(), bins=20, color='#5dade2', edgecolor='black')  
    axes[i].set_title(col)
    axes[i].set_xlabel('')
    axes[i].set_ylabel('frequency')

# Remove empty axes
for j in range(i + 1, len(axes)):
    fig.delaxes(axes[j])

plt.tight_layout()
plt.show()

# %% [markdown]
# ### 3.5. Checking Categorical Variables

# %%
# Creating barplots to understand the categorical data

sns.set_style('white')  
sns.set_palette(['#5dade2'])  

# Create 4 subplots stacked vertically
fig, ax = plt.subplots(nrows=4, ncols=1, dpi=300, figsize=(20, 40))
fig.patch.set_facecolor('white') 

# Plot each variable in its own row
sns.countplot(data=test_data, x='Brand', ax=ax[0])
sns.countplot(data=test_data, x='model', ax=ax[1])
sns.countplot(data=test_data, x='transmission', ax=ax[2])
sns.countplot(data=test_data, x='fuelType', ax=ax[3])

# Improve spacing between plots
plt.tight_layout()
plt.show()

# %% [markdown]
# ### 3.6. Checking Correlation between Variables

# %%
# Check correlation between variables 
# We are going to use spearman correlation since our variables do not follow a normal distribution
cor_spearman = data[metric_features].corr(method ='spearman')
cor_spearman

# %%
# Create correlation matrix to facilitate interpretation

def cor_heatmap(cor):
    plt.figure(figsize=(12, 10))

    # Create a mask for the upper triangle
    mask = np.triu(np.ones_like(cor, dtype=bool))

    # Plot heatmap 
    sns.heatmap(
        data=cor,
        mask=mask,
        annot=True,
        cmap='YlGnBu',   
        fmt='.2f',
        square=True,
        linewidths=0.5,
        cbar_kws={"shrink": 0.8},
    )

    plt.title("Spearman Correlation Matrix", fontsize=14)
    plt.show()

# %%
cor_heatmap(cor_spearman)

# %%
# Pairwise Relationship of Numerical Variables
sns.set()

# Setting pairplot and use historgrams in the diagonal
sns.pairplot(df[metric_features], diag_kind="hist")

# Layout
plt.subplots_adjust(top=0.95)
plt.suptitle("Pairwise Relationship of Numerical Variables", fontsize=20)

# Create eda directory 
if not os.path.exists(os.path.join('..', 'figures', 'eda')):
    os.makedirs(os.path.join('..', 'figures', 'eda'))
    
plt.savefig(os.path.join('..', 'figures', 'eda', 'pairwise_numeric_scatterplots.png'), dpi=200)
plt.show()

# %% [markdown]
# ## 4. Data preparation

# %% [markdown]
# ### 4.1. Set index

# %%
# Set index to CarID as each car has its own unique identifier
data.set_index('carID', inplace = True)
test_data.set_index('carID', inplace = True)

# %% [markdown]
# ### 4.2. Slipt the data into train and validation dataset

# %% [markdown]
# #### The Hold Out Method

# %%
X = data.drop('price', axis = 1) # In X, the target variable will be removed and the dataset will be used as the training set
y = data['price']  # y corresponds to the target variable

# %%
# Splits the dataset

X_train, X_val, y_train, y_val = train_test_split(X,y, test_size = 0.3,  # 30% will be used for validation 
                                                  random_state = 0,      # Ensures the split is always the same every time the code runs
                                                  shuffle = True)        # Shuffles the data before spliting to avoid bias

# %%
y_train_log = np.log1p(y_train)
y_val_log   = np.log1p(y_val)

# %% [markdown]
# ### 4.3. Changing datatypes

# %%
# Rounds the floats and changes them to integers

#year to integer
X_train['year'] = X_train['year'].round().astype('Int32')
X_val['year'] = X_val['year'].round().astype('Int32')
test_data['year'] = test_data['year'].round().astype('Int32')

#previousOwners to integer
X_train['previousOwners'] = X_train['previousOwners'].round().astype('Int32')
X_val['previousOwners'] = X_val['previousOwners'].round().astype('Int32')
test_data['previousOwners'] = test_data['previousOwners'].round().astype('Int32')

#hasDamaged to boolean
X_train['hasDamage'] = X_train['hasDamage'].astype('Int8')
X_val['hasDamage'] = X_val['hasDamage'].astype('Int8')
test_data['hasDamage'] = test_data['hasDamage'].astype('Int8')

# %%
X_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 53181 entries, 42520 to 15659
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Brand           52128 non-null  object
#  1   model           52136 non-null  object
#  2   year            52130 non-null  Int32
#  3   transmission    52086 non-null  object
#  4   mileage         52157 non-null  float64
#  5   fuelType        52160 non-null  object
#  6   tax             47671 non-null  float64
#  7   mpg             47683 non-null  float64
#  8   engineSize      52118 non-null  float64
#  9   paintQuality%   52091 non-null  float64
#  10  previousOwners  52090 non-null  Int32
#  11  hasDamage       52087 non-null  Int8
# dtypes: Int32(2), Int8(1), float64(5), object(4)
# memory usage: 4.7+ MB

# %% [markdown]
# ### 4.4. Handling Incoherencies

# %% [markdown]
# #### 4.4.1. Categorical Variables

# %% [markdown]
# ##### 4.4.1.1. Correcting Spelling Mistakes

# %%
#correcting spelling mistakes of 'brand' for X_train, X_val and test_data

correct_brand = {
    'VW': ['V', 'vw', 'v', 'W', 'w'],
    'Toyota': ['Toyot', 'TOYOTA', 'oyota', 'toyota', 'OYOTA', 'TOYOT', 'toyot', 'oyot'],
    'Audi': ['udi', 'AUDI', 'audi', 'Aud', 'aud', 'UDI', 'AUD'],
    'Ford': ['FOR', 'ord', 'For', 'FORD', 'ford', 'for', 'or', 'ORD'],
    'BMW': ['MW', 'bmw', 'BM', 'mw', 'M', 'bm'],
    'Skoda': ['koda', 'skoda', 'SKODA', 'Skod', 'kod', 'SKOD', 'KODA', 'skod'],
    'Opel': ['Ope', 'opel', 'pel', 'pe', 'OPEL', 'PEL', 'OPE', 'ope'],
    'Mercedes': ['mercedes', 'Mercede', 'MERCEDES', 'ercedes', 'mercede', 'ERCEDES', 'ercede', 'MERCEDE'],
    'Hyundai': ['yundai', 'Hyunda', 'hyundai', 'HYUNDAI', 'yunda', 'HYUNDA', 'ud', 'hyunda', 'YUNDAI']
}

# Create a reverse lookup dictionary (each incorrect form maps to the correct one)
replacement_dict = {variant: correct for correct, variants in correct_brand.items() for variant in variants}

# Replace incorrect brand names with the correct ones
X_train["Brand"] = X_train["Brand"].replace(replacement_dict)
X_val["Brand"] = X_val["Brand"].replace(replacement_dict)
test_data["Brand"] = test_data["Brand"].replace(replacement_dict)

# Verify the cleaning
print(X_train["Brand"].unique())
print(X_val["Brand"].unique())
print(test_data["Brand"].unique())
# Out:
# ['Mercedes' 'Ford' 'Hyundai' 'VW' 'Opel' 'Audi' 'Toyota' 'BMW' nan 'Skoda']
# ['Mercedes' 'Opel' 'Ford' 'VW' 'Toyota' nan 'BMW' 'Skoda' 'Audi' 'Hyundai']
# ['Hyundai' 'VW' 'BMW' 'Opel' 'Ford' 'Mercedes' 'Skoda' 'Toyota' 'Audi' nan]

# %%
##correcting spelling mistakes of 'model' for X_train, X_val and test_data

correct_model = {
    'Golf': [' GOLF', ' Gol', ' golf', 'golf', ' Golf', ' gol', ' GOL', 'Gol', 'GOLF'],
    'Yaris': [' Yaris', ' YARIS', ' Yari', ' yaris', ' yari', 'Yari', ' YARI', 'yaris', 'YARIS'],
    'Q2': [' q2', ' Q2'],
    '2 Series': [' 2 series', ' 2 serie', '2 Series', ' 2 SERIES', ' 2 Serie', '2 Serie', ' 2 Series'],
    '3 Series': [' 3 Series', ' 3 Serie', ' 3 series', ' 3 SERIES', ' 3 serie', '3 Serie'],
    'A3': [' A3', ' a3'],
    'Octavia': [' Octavi', ' OCTAVIA', ' Octavia', ' octavia', 'Octavi', 'octavia', ' octavi', ' OCTAVI'],
    'Passat': [' PASSAT', ' passat', ' Passa', 'Passat', ' Passat', 'PASSAT', ' PASSA'],
    'Insignia': [' Insigni', ' INSIGNIA', ' insignia', ' Insignia', ' INSIGNI', 'Insigni'],
    'Fabia': [' Fabia', ' fabia', ' FABIA', ' Fabi', 'FABIA'],
    'A Class': [' A Clas', ' A Class', ' a class', ' A CLASS', 'a class', 'A CLASS', ' a clas'],
    'Ka+': [' Ka+', ' KA+', ' ka+', 'ka+'],
    'GLC Class': [' GLC Class', ' GLC CLASS', ' GLC Clas', ' glc class', ' glc clas'], 
    'I30': [' i30', ' I30'],
    'C Class': [' C Clas', ' C CLASS', ' c class', 'C Clas', ' C CLAS', 'c class', ' c clas', ' C Class', 'C CLASS'],
    'Polo': [' POLO', ' Polo', ' polo', ' Pol', ' POL', 'Pol', 'POLO'],
    'E Class': [' E Class', ' E Clas', ' E CLASS', ' e class', 'E CLASS', 'e class'],
    'Q5': [' Q5', ' q5', 'q5'],
    'Up': ['U', ' up', ' UP', ' Up', ' U', 'UP'],
    'Fiesta': [' FIESTA', ' fiesta', ' Fiest', ' Fiesta', 'fiesta', 'Fiest', ' FIESTA', 'FIESTA', ' fiest'],
    'C-HR': [' C-H', ' c-hr', ' C-HR', ' c-h'],
    'Mokka X': [' mokka x', ' MOKKA X', ' Mokka X'],
    'Corsa': [' Corsa', ' corsa', ' Cors', ' CORSA', ' cors', ' CORS', 'corsa'],
    'Astra': [' ASTRA', ' Astr', ' Astra', ' astra', 'ASTRA', 'astra'],
    'TT': [' tt', ' TT', ' T'],
    '5 Series': [' 5 Series', ' 5 Serie', ' 5 SERIES', ' 5 series', '5 SERIES', ' 5 SERIE'],
    'Aygo': [' aygo', ' ayg', ' AYGO', ' Ayg', ' Aygo', 'aygo', ' AYG'],
    '4 Series': [' 4 SERIES', ' 4 Serie', ' 4 serie', '4 series', '4 Series', ' 4 Series', ' 4 series'],
    'SLK': [' slk', ' SLK'],
    'Viva': [' viva', ' Viva', ' VIVA', ' Viv', 'viva'],
    'Focus': [' Focus', ' Focu', ' FOCUS', ' focus', ' FOCU', 'focus', 'Focu', ' focu', 'FOCUS'],
    'EcoSport': [' EcoSpor', ' ECOSPORT', ' ecosport', ' EcoSport'],
    'X-CLASS': [' x-clas', ' X-CLAS', ' x-class', ' X-CLASS'],
    'CL Class': [' cl class', ' CL Clas', ' CL CLASS', ' CL Class'],
    'IX20': [' ix20', ' IX20'],
    'Rapid': [' Rapi', ' rapid', ' Rapid'],
    'Auris': [' Auris', ' AURIS', ' auris', ' Auri'],
    'I20': [' i20', ' I20'],
    'X3': [' x3', ' X3'],
    'A8': [' A8', 'a8'],
    'GLS Class': [' GLS Clas', ' GLS CLASS', ' gls class', ' GLS Class'],
    'B-MAX': [' B-MA', ' B-MAX', 'B-MA', ' b-max'],
    'A4': [' A4', ' a4'],
    'Kona': [' KONA', ' Kon', ' Kona', ' KON', ' kona'],
    'I10': [' i10', ' I10'],
    'A1': [' A1', ' a1'],
    'Mokka': [' Mokka ', ' Mokk', ' Mokka', ' mokka ', ' mokka', ' MOKKA', 'Mokka ', 'Mokk'],
    'S-MAX': [' S-MA', ' s-max', ' S-MAX', ' s-ma'],
    'X2': [' x2', ' X2'],
    'Crossland X': [' crossland x', ' CROSSLAND X', ' Crossland X'],
    'Tiguan': [' Tiguan', ' tiguan', ' Tigua', ' TIGUAN', ' TIGUA', 'Tigua', 'TIGUAN', 'tiguan', ' tigua'],
    'A5': [' A5', ' a5', 'a5'],
    'GLE Class': [' GLE Clas', ' GLE Class', ' gle class', ' GLE CLASS'],
    'Zafira': [' Zafira', ' Zafir', ' ZAFIRA', ' zafira', 'Zafir', ' ZAFIR'],
    'Ioniq': [' Ioni', ' Ioniq', ' IONIQ', 'IONIQ', ' ioniq'],
    'A6': [' A6', ' a6'],
    'Yeti Outdoor': [' yeti outdoor', ' Yeti Outdoor', ' YETI OUTDOOR', ' Yeti Outdoo', ' yeti outdoor', 'yeti outdoor', ' yeti outdoo'],
    'X1': [' x1', 'x1', ' X1'],
    'Scala': [' SCALA', ' Scala', ' scala', ' Scal', ' scal'],
    'S Class': [' S Class', ' S Clas', ' s class', ' S CLASS'],
    '1 Series': [' 1 Series', ' 1 SERIES', ' 1 Serie', ' 1 series', '1 SERIES', ' 1 SERIE', '1 series', ' 1 serie'],
    'Kamiq': [' KAMIQ', ' KAMI', ' kamiq', ' Kamiq'],
    'Kuga': [' Kug', ' KUGA', ' kuga', 'Kuga', ' Kuga', 'kuga'],
    'Tourneo Connect': [' tourneo connect', ' Tourneo Connect'],
    'Q7': [' q7', ' Q7'],
    'GLA Class': [' GLA Class', ' GLA CLASS', ' GLA Clas', ' gla class'],
    'Arteon': [' arteon', ' Arteon', ' Arteon'],
    'SL CLASS': [' SL CLAS', ' SL CLASS', ' sl class', ' SL'],
    'Tucson': [' Tucson', ' TUCSON', ' Tucso', ' tucson', ' TUCSO', 'Tucso'],
    'Santa Fe': [' Santa F', ' santa fe', ' SANTA FE', ' Santa Fe'],
    'Grandland X': [' Grandland X', ' grandland x', ' GRANDLAND X'],
    'RAV4': [' rav4', 'RAV4', 'RAV', ' RAV', 'rav4', ' rav', ' RAV4'],
    'Touran': [' Touran', 'Toura', ' TOURAN', ' touran', ' Toura', ' TOURA'],
    'Citigo': [' Citig', ' citigo', ' Citigo', ' CITIGO', 'CITIGO'],
    'Roomster': [' Roomste', ' Roomster'],
    'Prius': [' PRIUS', ' Prius', 'Prius', ' prius'],
    'Corolla': [' corolla', ' COROLLA', ' Coroll', ' Corolla', 'corolla'],
    'B Class': [' b class', ' B Clas', ' B Class', ' B CLASS', 'b class'],
    'Sharan': [' sharan', ' Shara', ' Sharan', ' SHARAN'],
    'Kodiaq': [' Kodia', ' kodiaq', 'kodiaq', ' KODIAQ', ' Kodiaq'],
    'V Class': [' V Clas', ' V CLASS', ' V Class', ' v class'],
    'Caddy Maxi Life': [' Caddy Maxi Lif', ' Caddy Maxi Life'],
    'Superb': [' Superb', ' Super', ' SUPERB', ' superb', ' super'],
    'T-Roc': [' T-Roc', ' T-RO', ' t-roc', ' T-Ro', ' T-ROC'],
    'Combo Life': [' COMBO LIFE', ' combo life', ' Combo Lif', 'COMBO LIFE', ' Combo Life'],
    'Beetle': [' Beetl', ' Beetle', ' beetle'],
    'Galaxy': [' GALAXY', ' Galax', ' galaxy', ' Galaxy'],
    'M3': [' M3', ' m3'],
    'Gtc': [' gtc', ' GTC', ' gtc', 'gtc', 'GTC'],
    'X4': [' X4', ' x4'],
    'KA': [' Ka', ' ka', ' K', ' KA'],
    'IX35': [' ix35', ' IX35'],
    'Grand Tourneo Connect': [' Grand Tourneo Connec', ' Grand Tourneo Connect'],
    'M4': [' m4', ' M4'],
    'Tourneo Custom': [' tourneo custom', ' Tourneo Custo', ' Tourneo Custom'],
    'Z4': [' Z4', ' z4'],
    'X5': [' X5', ' x5'],
    'Meriva': [' Meriva', ' MERIVA', ' Meriv', ' meriva'],
    'RS6': [' RS6'],
    'Verso': [' VERSO', ' verso', ' Verso', ' Vers'],
    'Touareg': [' Touareg', ' TOUAREG', ' touareg', ' Touare'],
    'Mondeo': [' MONDEO', ' Mondeo', ' mondeo', ' MONDE', ' Monde'],
    'Shuttle': [' shuttle', ' Shuttle', ' SHUTTLE'],
    'CLS Class': [' CLS Class', ' cls class', ' CLS Clas', ' CLS CLASS'], 
    'C-MAX': [' C-MAX', ' c-max', ' C-MA'],
    'Puma': [' puma', ' PUMA', ' Puma', 'Pum', ' Pum'],
    'CLA Class': [' CLA Class', ' CLA CLASS', ' cla class', ' CLA Clas'],
    'I40': [' I40', ' i40'],
    'Q3': [' q3', ' Q3'],
    'Tiguan Allspace': [' TIGUAN ALLSPACE', ' tiguan allspace', ' Tiguan Allspac', ' Tiguan Allspace'],
    '6 Series': [' 6 SERIES', ' 6 series', ' 6 Series', ' 6 Serie'],
    'Caravelle': [' caravelle', ' Caravell', ' Caravelle'],
    'Karoq': [' Karoq', ' karoq', ' KAROQ', ' Karo'],
    'I3': [' i3', 'i3', ' I3'],
    'Grand C-MAX': [' GRAND C-MAX', ' grand c-max', ' Grand C-MA', ' Grand C-MAX'],
    'T-Cross': [' T-Cros', ' T-CROSS', ' T-Cross', ' t-cros', ' t-cross'],
    'A7': [' a7', ' A7'],
    'Golf SV': [' Golf SV', ' golf sv', ' GOLF SV'],
    'A': [' a', ' A'],
    'GT86': [' gt86', ' GT86'],
    'Yeti': [' yeti', ' Yet', ' Yeti', ' YETI'],
    'X': [' x', ' X'],
    'Land Cruiser': [' Land Cruise', ' Land Cruiser', ' land cruiser'],
    'EDGE': [' Edge', ' edge', ' Edg', ' EDGE'],
    'X6': [' X6'],
    'Fusion': [' Fusion', ' fusion'],
    'GL Class': [' GL CLASS', ' gl class', ' GL Class', ' GL Clas'],
    'Scirocco': [' scirocco', ' SCIROCCO', ' Scirocc', ' Scirocco'],
    'Z3': [' Z3'],
    'Hilux': [' hilux', ' Hilux', ' Hilu', ' HILU'],
    'Amarok': [' amarok', ' Amarok', ' Amaro'],
    'CC': [' cc', ' CC'],
    '7 Series': [' 7 Serie', ' 7 SERIES', ' 7 series', ' 7 Series'],
    'Avensis': [' AVENSIS', ' avensis', ' Avensis'],
    'M Class': [' m class', ' M CLASS', ' M Class', ' M Clas', ' M CLAS'],
    'Grandland': [' grandland ', ' Grandland '],
    'Zafira Tourer': [' Zafira Toure', ' ZAFIRA TOURER', ' Zafira Tourer', ' zafira tourer'],
    'R8': [' R8', ' r8'],
    'Mustang': [' mustang', ' Mustang'],
    'Q8': [' Q8'],
    'CLK': [' CLK'],
    'RS3': [' RS3'],
    'Jetta': [' JETTA', ' Jetta', ' jetta', 'Jetta' ],
    'Supra': [' Supra'],
    'X7': [' X7'],
    'SQ7': [' SQ7', ' sq7'],
    'S3': [' s3', ' S3'],
    'Arteon': [' Arteo', 'Arteo', ' ARTEON', ' arteon', ' Arteon'],
    'GLB Class': [' glb class', ' GLB Class'],
    'Adam': [' Ada', ' adam', ' ADAM', ' Adam'],
    'M5': [' M5',' m5'],
    'Golf S': [' golf s', ' Golf S'],
    'Vectra': ['Vectra', ' Vectra', ' VECTRA', 'VECTRA'],
    '8 Series': [' 8 SERIES', ' 8 Serie', ' 8 Series', ' 8 series'],
    'Urban Cruiser': [' Urban Cruise', ' Urban Cruiser'],
    'Fox': ['fox', ' fox', ' Fox'], 
    'Q': [' Q'], 
    'M2': [' M2'], 
    'RS4':[' RS4'], 
    'Veloster': [' Veloster', ' Veloste'],  
    'IQ': [' IQ'], 
    'Agila': [' AGILA', ' Agila'], 
    'I2': [' I2'], 
    'Antara': [' Antara', ' antara'], 
    'G Class': [' G Class', ' G CLAS'], 
    'Caddy Life': [' Caddy Life', ' Caddy'],
    'R Class': [' R Class'], 
    'I800': [' I800'],
    'Amica': [' Amica'], 
    'Crossland': [' Crossland '],
    'Proace Verso': [' proace verso', ' PROACE VERSO', 'PROACE VERSO'],
    'Camry': [' Camry', 'Camry', ' Camr'], 
    'Tigra': [' Tigra'], 
    'Eos': [' Eos'], 
    'M': [' M'],
    'California': [' Californi', ' California'], 
    'Ampera': [' Ampera'], 
    'I1': [' I1'], 
    'S5': [' S5'], 
    'CLC Class': [' CLC Class'], 
    'Shara': [' SHARA'], 
    'I8': [' i8', 'i8'], 
    'RS7': [' RS7'], 
    'Transit Tourneo': [' Transit Tourneo'], 
    'I4': [' I4'], 
    'S4':[' S4'], 
    'Terracan': [' Terracan'], 
    'Cascada': [' Cascada'], 
    'S8': [' S8'], 
    'A2':[' A2'], 
    'Vivaro':[' Vivaro'],
    'RS5':[' RS5'],
    'SQ5':[' SQ5'], 
    'Getz':[' Getz'], 
    'M6':[' M6'], 
    'Caddy Maxi': [' Caddy Maxi'], 
    'Z':[' Z'], 
    'Verso-S': [' Verso-S'], 
    'Kadjar': [' Kadjar'], 
    'I80': [' I80'], 
    'Streetka': [' Streetka'],
    'RS': [' RS'], 
    'I': [' i'], 
    'Ranger': [' Ranger'], 
    'IX2': [' IX2'], 
    'Escort': [' Escort'],
    'Accent': [' Accent']
}


# Create a reverse lookup dictionary (each incorrect form maps to the correct one)
replacement_dict = {variant: correct for correct, variants in correct_model.items() for variant in variants}

# Replace incorrect brand names with the correct ones
X_train["model"] = X_train["model"].replace(replacement_dict)
X_val["model"] = X_val["model"].replace(replacement_dict)
test_data["model"] = test_data["model"].replace(replacement_dict)

# Verify the cleaning
print(X_train["model"].unique())
print(X_val["model"].unique())
print(test_data["model"].unique())
# Out:
# ['E Class' 'Focus' 'C Class' 'IX20' 'Golf' 'I10' 'T-Cross' 'Corsa' 'A4'
#  'Polo' 'Tucson' 'Kuga' 'Corolla' 'Yaris' 'Q3' 'A Class' 'A1' 'A5' 'Q5'
#  'GLE Class' '3 Series' 'Fiesta' 'T-Roc' 'Insignia' 'GLC Class' 'X1'
#  'Astra' 'Q2' 'Aygo' 'C-MAX' 'Q' '2 Series' 'A3' 'Touran' 'TT' 'Santa Fe'
#  'C-HR' 'Superb' 'EDGE' 'S Class' 'CL Class' 'Ka+' 'Octavia' 'Arteon' 'X4'
#  'Z4' nan 'EcoSport' 'Yeti Outdoor' 'Meriva' 'I20' 'Hilux' 'X5' 'M4'
#  'CLA Class' '1 Series' 'Mokka X' 'Prius' 'X2' '4 Series' 'S4' 'Fabia'
#  'Auris' 'Galaxy' 'Citigo' 'A6' 'RAV4' 'Passat' 'Grand C-MAX' 'Adam'
#  'GLA Class' 'G Class' 'Zafira' 'Touareg' 'Sharan' 'Mokka' 'Tiguan'
#  'Ioniq' 'Q7' 'Viva' 'X3' 'Tiguan Allspace' 'B Class' 'Up' 'Crossland X'
#  'CLS Class' 'SLK' 'Kodiaq' 'Mondeo' 'B-MAX' 'Caddy Life' 'SL CLASS' 'A7'
#  'A' 'I30' 'Yeti' 'Grandland X' 'Tourneo Custom' 'Antara' 'Avensis' 'X6'
#  '5 Series' 'GL Class' 'IX35' 'Kamiq' 'KA' 'Caravelle' 'Karoq' 'Scala'
#  'V Class' 'Golf SV' 'Verso' 'Kona' '7 Series' '6 Series' 'SQ7' 'Golf S'
#  'M Class' 'Scirocco' 'Amarok' 'S3' 'X-CLASS' 'M5' '8 Series' 'Shuttle'
#  'S-MAX' 'I800' 'Q8' 'I40' 'I3' 'Rapid' 'X7' 'Combo Life' 'RS3' 'CC'
#  'Mustang' 'I2' 'A8' 'Crossland' 'Grand Tourneo Connect' 'GLS Class' 'X'
#  'I1' 'RS6' 'Proace Verso' 'Puma' 'Zafira Tourer' 'GT86' 'Beetle' 'RS4'
#  'M2' 'Caddy Maxi Life' 'I8' 'M' 'Agila' 'R8' 'Land Cruiser' 'M3' 'Vivaro'
#  'Jetta' 'GLB Class' 'RS5' 'Roomster' 'California' 'Fusion' 'Gtc' 'SQ5'
#  'A2' 'Camry' 'Tigra' 'Tourneo Connect' 'Z3' 'Grandland' 'CLK' 'Getz'
#  'Veloster' 'M6' 'CLC Class' 'Supra' 'Caddy Maxi' 'Z' 'Urban Cruiser'
#  'Vectra' 'S8' 'Eos' 'Verso-S' 'Kadjar' 'IQ' 'Cascada' 'I80' 'Streetka'
#  'RS' 'Ampera' 'I' '230' 'Ranger' 'IX2' 'Escort' 'Accent']
# ['C Class' 'Mokka' 'Focus' 'T-Cross' 'Tourneo Custom' 'Golf' 'Kuga'
#  'Mustang' 'Yaris' 'Corsa' '2 Series' 'Zafira' '5 Series' 'Aygo' 'X5'
#  'Scirocco' 'Corolla' '1 Series' 'Citigo' 'A3' 'Tucson' 'R8' 'Kona' 'Q3'
#  'X3' nan 'CLS Class' 'X2' 'T-Roc' 'S3' 'I10' 'Grandland X' 'A Class'
#  'Octavia' 'Polo' 'Fiesta' 'A4' 'I40' 'B Class' 'Viva' 'Q7' 'Astra'
#  'Passat' 'Sharan' 'B-MAX' '4 Series' 'TT' 'I1' 'V Class' 'Ka+' '3 Series'
#  'Tiguan' 'Yeti Outdoor' 'RS6' 'Ioniq' 'Arteon' 'I30' 'GLA Class' 'Z3'
#  'Mokka X' 'M4' 'I20' 'A5' 'Q5' 'E Class' 'X1' 'CL Class' 'Mondeo'
#  'Insignia' 'C-HR' 'GLC Class' 'Fabia' 'C-MAX' '8 Series' 'M3' 'A6' 'Q2'
#  'Superb' 'EcoSport' 'RAV4' 'Prius' 'GLE Class' 'Crossland X' 'Q' 'A1'
#  'Karoq' 'GL Class' 'Galaxy' 'X4' 'Adam' 'Auris' 'S Class' 'Up' 'Meriva'
#  'Rapid' 'Golf SV' 'S-MAX' 'X6' 'Caravelle' 'A' 'SL CLASS' 'Touareg'
#  'Kodiaq' 'Agila' 'Tourneo Connect' 'Z4' 'CLA Class' 'Touran' 'Caddy Life'
#  '6 Series' 'SLK' 'Beetle' 'Gtc' 'Grand C-MAX' 'Kamiq' 'EDGE' 'I800'
#  'Yeti' '7 Series' 'Santa Fe' 'KA' 'Shuttle' 'Getz' 'Verso' 'X-CLASS'
#  'IX35' 'Amarok' 'IX2' 'California' 'Scala' 'Golf S' 'CC' 'IX20'
#  'Combo Life' 'M2' 'GLS Class' 'Hilux' 'Avensis' 'Caddy Maxi Life'
#  'Grand Tourneo Connect' 'RS5' 'M Class' 'I3' 'Puma' 'S4' 'GT86' 'A7' 'Q8'
#  'Jetta' 'Caddy Maxi' 'G Class' 'A8' 'X' 'M' 'RS3' 'X7' 'GLB Class'
#  'Zafira Tourer' 'SQ5' 'Roomster' 'Land Cruiser' 'Fusion' 'polo' 'I8'
#  'RS4' 'M5' 'Camry' 'Vivaro' 'Antara' 'Supra' 'Tiguan Allspace'
#  'Urban Cruiser' 'Fox' 'M6' 'Crossland' '200' 'I80' 'Proace Verso' '220'
#  'Eos' 'S8' 'Grandland' 'Terracan' 'CLK' 'Kadjar' 'S5' 'I2' 'SQ7']
# ['I30' 'Tiguan' '2 Series' 'Grandland X' '1 Series' 'Fiesta' 'X1'
#  'B Class' 'Focus' 'Superb' '5 Series' 'C Class' 'Up' 'Aygo' 'Golf'
#  'M Class' 'Land Cruiser' 'TT' 'Adam' 'Zafira' 'E Class' '3 Series' 'IX20'
#  'A4' 'Yaris' 'Passat' 'I10' 'Mokka X' 'EcoSport' '4 Series' 'A7' 'Corsa'
#  'Kuga' 'Grand C-MAX' 'Q2' 'M4' 'A Class' 'RAV4' 'Fabia' 'Insignia' 'A1'
#  'X6' 'Meriva' 'Caravelle' 'Octavia' 'Auris' 'X-CLASS' 'Astra' 'V Class'
#  'Polo' 'Karoq' 'Shuttle' 'Mokka' 'Q5' 'Tucson' 'A3' 'SL CLASS' 'Corolla'
#  'Ka+' 'X3' 'I40' 'I20' 'Kamiq' nan 'IX35' 'Crossland X' 'Q3' 'Viva'
#  'GLA Class' 'CLS Class' 'KA' 'Galaxy' 'X2' 'Kodiaq' 'GLC Class' 'Vivaro'
#  'Mondeo' 'Touran' 'CL Class' 'X5' 'Verso' 'Touareg' 'T-Roc' 'Q' 'A5'
#  'S Class' 'Scirocco' 'X7' 'B-MAX' '8 Series' 'A6' 'Santa Fe' 'GL Class'
#  'GLE Class' 'Beetle' 'X4' 'Golf SV' 'Sharan' 'C-MAX' 'M6' 'A8'
#  'CLA Class' 'Kona' 'Citigo' 'Prius' 'Rapid' 'Fusion' 'G Class' 'SLK'
#  'Yeti Outdoor' 'Q7' 'C-HR' 'M5' 'T-Cross' 'Avensis' 'Ioniq' 'Amarok' 'Z4'
#  'California' 'M2' 'M3' 'Arteon' 'Scala' 'Hilux' 'Puma' 'Gtc'
#  'Zafira Tourer' 'S-MAX' 'EDGE' 'CC' 'RS3' 'X' 'Tiguan Allspace' 'RS4'
#  'Combo Life' 'Caddy Maxi Life' 'Tourneo Custom' 'Mustang' '7 Series'
#  'Yeti' 'Veloster' 'A' 'I800' 'Grandland' 'Fox' 'GLB Class' '6 Series'
#  'IQ' 'R8' 'GT86' 'Agila' 'GLS Class' 'RS5' 'Grand Tourneo Connect'
#  'Antara' 'I2' '180' 'Supra' 'SQ5' 'Q8' 'SQ7' 'I8' 'Tourneo Connect' 'I3'
#  'Caddy Life' 'Jetta' 'R Class' 'S3' 'Edge' 'VERSO' 'Amica' 'Crossland'
#  'RS6' 'Proace Verso' 'Camry' 'Tigra' 'Eos' 'M' 'Roomster' 'CLK' 'Ampera'
#  'I1' 'S5' 'CLC Class' '2 series' 'Shara' 'RS7' 'Transit Tourneo' 'Vectra'
#  'Golf S' 'I4' 'Z3' 'S4' 'Terracan' 'Cascada']

# %%
##correcting spelling mistakes of 'transmission' for X_train, X_val and test_data

correct_transmission = {
    'Semi-Auto': ['Semi-Aut', 'semi-auto', 'emi-Auto', 'SEMI-AUTO', 'SEMI-AUT', 'EMI-AUTO', 'emi-Aut', 'emi-auto', 'semi-aut'],
    'Manual': ['anual', 'manual', 'Manua', 'MANUAL', ' Manual ', 'ANUAL', 'manua', 'anua', 'MANUA', ' manual ', ' MANUAL ', ' Manual', 'Manual ', 'manual '],
    'Automatic': ['AUTOMATIC', 'automatic', 'Automati', 'utomatic', 'UTOMATIC', 'automati', 'AUTOMATI', 'utomati'],
}

# Create a reverse lookup dictionary (each incorrect form maps to the correct one)
replacement_dict = {variant: correct for correct, variants in correct_transmission.items() for variant in variants}

# Replace incorrect brand names with the correct ones
X_train["transmission"] = X_train["transmission"].replace(replacement_dict)
X_val["transmission"] = X_val["transmission"].replace(replacement_dict)
test_data["transmission"] = test_data["transmission"].replace(replacement_dict)

#replacing the 'unknown' and 'other' variable with a missing value
X_train["transmission"] = X_train["transmission"].replace(['unknow','UNKNOWN','nknown','nknow', 'unknown', 'Other'], np.nan)
X_val["transmission"] = X_val["transmission"].replace(['unknow','UNKNOWN','nknown','nknow', 'unknown', 'Other'], np.nan)
test_data["transmission"] = test_data["transmission"].replace(['unknow','UNKNOWN','nknown','nknow', 'unknown', 'Other'], np.nan)

# Verify the cleaning
print(X_train["transmission"].unique())
print(X_val["transmission"].unique())
print(test_data["transmission"].unique())
# Out:
# ['Semi-Auto' 'Automatic' 'Manual' nan]
# ['Semi-Auto' 'Manual' nan 'Automatic']
# ['Automatic' 'Semi-Auto' 'Manual' nan]

# %%
##correcting spelling mistakes of 'fuelType' for X_train, X_val and test_data

correct_fuelType = {
    'Petrol': ['etrol', 'petrol', 'PETROL', 'Petro', 'petro', 'ETROL', 'PETRO', 'etro', 'ETRO'],
    'Diesel': ['diesel','iesel','Diese','DIESEL','DIESE','IESEL','iese','diese','IESE'],
    'Hybrid': ['HYBRID','ybri','Hybri','ybrid','hybrid','YBRID','HYBRI', 'hybri'],
    'Other': ['ther','Othe','OTHER','other']
}

# Create a reverse lookup dictionary (each incorrect form maps to the correct one)
replacement_dict = {variant: correct for correct, variants in correct_fuelType.items() for variant in variants}

# Replace incorrect brand names with the correct ones
X_train["fuelType"] = X_train["fuelType"].replace(replacement_dict)
X_val["fuelType"] = X_val["fuelType"].replace(replacement_dict)
test_data["fuelType"] = test_data["fuelType"].replace(replacement_dict)

#replacing the 'other' variable with a missing value 
X_train["fuelType"] = X_train["fuelType"].replace(['ther','Othe','OTHER','other', 'Other'], np.nan)
X_val["fuelType"] = X_val["fuelType"].replace(['ther','Othe','OTHER','other', 'Other'], np.nan)
test_data["fuelType"] = test_data["fuelType"].replace(['ther','Othe','OTHER','other', 'Other'], np.nan)

# Verify the cleaning
print(X_train["fuelType"].unique())
print(X_val["fuelType"].unique())
print(test_data["fuelType"].unique())
# Out:
# ['Diesel' 'Petrol' 'Hybrid' nan 'Electric']
# ['Diesel' 'Petrol' nan 'Hybrid']
# ['Petrol' 'Diesel' 'Hybrid' nan 'Electric']

# %% [markdown]
# ##### 4.4.1.2. Check if the Models correspond to the Brand

# %% [markdown]
# **Audi**

# %%
#Check the models of Audi for X_train
audi = X_train[X_train['Brand'].str.lower() == 'audi']
unique_audi_models = sorted(audi['model'].dropna().unique())
unique_audi_models
# Out:
# ['A',
#  'A1',
#  'A2',
#  'A3',
#  'A4',
#  'A5',
#  'A6',
#  'A7',
#  'A8',
#  'Q',
#  'Q2',
#  'Q3',
#  'Q5',
#  'Q7',
#  'Q8',
#  'R8',
#  'RS',
#  'RS3',
#  'RS4',
#  'RS5',
#  'RS6',
#  'S3',
#  'S4',
#  'S8',
#  'SQ5',
#  'SQ7',
#  'TT']

# %%
#Check the models of Audi for X_val
audi = X_val[X_val['Brand'].str.lower() == 'audi']
unique_audi_models_v = sorted(audi['model'].dropna().unique())
unique_audi_models_v
# Out:
# ['A',
#  'A1',
#  'A3',
#  'A4',
#  'A5',
#  'A6',
#  'A7',
#  'A8',
#  'Q',
#  'Q2',
#  'Q3',
#  'Q5',
#  'Q7',
#  'Q8',
#  'R8',
#  'RS3',
#  'RS4',
#  'RS5',
#  'RS6',
#  'S3',
#  'S4',
#  'S5',
#  'S8',
#  'SQ5',
#  'SQ7',
#  'TT']

# %%
#Check the models of Audi for test_data
audi = test_data[test_data['Brand'].str.lower() == 'audi']
unique_audi_models = sorted(audi['model'].dropna().unique())
unique_audi_models
# Out:
# ['A',
#  'A1',
#  'A3',
#  'A4',
#  'A5',
#  'A6',
#  'A7',
#  'A8',
#  'Q',
#  'Q2',
#  'Q3',
#  'Q5',
#  'Q7',
#  'Q8',
#  'R8',
#  'RS3',
#  'RS4',
#  'RS5',
#  'RS6',
#  'RS7',
#  'S3',
#  'S4',
#  'S5',
#  'SQ5',
#  'SQ7',
#  'TT']

# %% [markdown]
# - All models seem to correspond to Audi cars, except for models 'A' and 'Q'. There are no models in Audi that are named 'A' and 'Q' solely, normally there are followed by a number, for example, 'A1' or 'Q3' as seen in the dataset.
# - Since it might be a problem of data collection, in a way that is missing a number after the letter, we have decided to replace these values by missing values.

# %%
#replacing model 'A' by missing values
X_train.loc[X_train["model"] == 'A', "model"] = np.nan
X_val.loc[X_val["model"] == 'A', "model"] = np.nan
test_data.loc[test_data["model"] == 'A', "model"] = np.nan

# %%
#replacing model 'Q' by missing values
X_train.loc[X_train["model"] == 'Q', "model"] = np.nan
X_val.loc[X_val["model"] == 'Q', "model"] = np.nan
test_data.loc[test_data["model"] == 'Q', "model"] = np.nan

# %% [markdown]
# **BMW**

# %%
#Check the models of 'BMW' for X_train
BMW = X_train[X_train['Brand'].str.lower() == 'bmw']
unique_bmw_models = sorted(BMW['model'].dropna().unique())
unique_bmw_models
# Out:
# ['1 Series',
#  '2 Series',
#  '3 Series',
#  '4 Series',
#  '5 Series',
#  '6 Series',
#  '7 Series',
#  '8 Series',
#  'I',
#  'I3',
#  'I8',
#  'M',
#  'M2',
#  'M3',
#  'M4',
#  'M5',
#  'M6',
#  'X',
#  'X1',
#  'X2',
#  'X3',
#  'X4',
#  'X5',
#  'X6',
#  'X7',
#  'Z',
#  'Z3',
#  'Z4']

# %%
#Check the models of 'BMW' for X_val
BMW = X_val[X_val['Brand'].str.lower() == 'bmw']
unique_bmw_models_v = sorted(BMW['model'].dropna().unique())
unique_bmw_models_v
# Out:
# ['1 Series',
#  '2 Series',
#  '3 Series',
#  '4 Series',
#  '5 Series',
#  '6 Series',
#  '7 Series',
#  '8 Series',
#  'I3',
#  'I8',
#  'M',
#  'M2',
#  'M3',
#  'M4',
#  'M5',
#  'M6',
#  'X',
#  'X1',
#  'X2',
#  'X3',
#  'X4',
#  'X5',
#  'X6',
#  'X7',
#  'Z3',
#  'Z4']

# %%
#Check the models of 'BMW' for test_data
BMW = test_data[test_data['Brand'].str.lower() == 'bmw']
unique_bmw_models = sorted(BMW['model'].dropna().unique())
unique_bmw_models
# Out:
# ['1 Series',
#  '2 Series',
#  '2 series',
#  '3 Series',
#  '4 Series',
#  '5 Series',
#  '6 Series',
#  '7 Series',
#  '8 Series',
#  'I3',
#  'I8',
#  'M',
#  'M2',
#  'M3',
#  'M4',
#  'M5',
#  'M6',
#  'X',
#  'X1',
#  'X2',
#  'X3',
#  'X4',
#  'X5',
#  'X6',
#  'X7',
#  'Z3',
#  'Z4']

# %% [markdown]
# - Similarly to 'Audi', in 'BMW' there are also models that should be followed by a number, which are 'X', 'Z', 'I' and 'M'.
# - Therefore, we are going to replace it by missing values, for the same reason.

# %%
#replacing model 'X' by missing values
X_train.loc[X_train["model"] == 'X', "model"] = np.nan
X_val.loc[X_val["model"] == 'X', "model"] = np.nan
test_data.loc[test_data["model"] == 'X', "model"] = np.nan

# %%
#replacing model 'Z' by missing values
X_train.loc[X_train["model"] == 'Z', "model"] = np.nan

# %%
#replacing model 'I' by missing values
X_train.loc[X_train["model"] == 'I', "model"] = np.nan

# %%
#replacing model 'M' by missing values
X_train.loc[X_train["model"] == 'M', "model"] = np.nan
X_val.loc[X_val["model"] == 'M', "model"] = np.nan
test_data.loc[test_data["model"] == 'M', "model"] = np.nan

# %% [markdown]
# **Ford**

# %%
#Check the models of 'Ford' for X_train
Ford = X_train[X_train['Brand'].str.lower() == 'ford']
unique_ford_models = sorted(Ford['model'].dropna().unique())
unique_ford_models
# Out:
# ['B-MAX',
#  'C-MAX',
#  'EDGE',
#  'EcoSport',
#  'Escort',
#  'Fiesta',
#  'Focus',
#  'Fusion',
#  'Galaxy',
#  'Grand C-MAX',
#  'Grand Tourneo Connect',
#  'KA',
#  'Ka+',
#  'Kuga',
#  'Mondeo',
#  'Mustang',
#  'Puma',
#  'Ranger',
#  'S-MAX',
#  'Streetka',
#  'Tourneo Connect',
#  'Tourneo Custom']

# %%
#Check the models of 'Ford' for X_val
Ford = X_val[X_val['Brand'].str.lower() == 'ford']
unique_ford_models_v = sorted(Ford['model'].dropna().unique())
unique_ford_models_v
# Out:
# ['B-MAX',
#  'C-MAX',
#  'EDGE',
#  'EcoSport',
#  'Fiesta',
#  'Focus',
#  'Fusion',
#  'Galaxy',
#  'Grand C-MAX',
#  'Grand Tourneo Connect',
#  'KA',
#  'Ka+',
#  'Kuga',
#  'Mondeo',
#  'Mustang',
#  'Puma',
#  'S-MAX',
#  'Tourneo Connect',
#  'Tourneo Custom']

# %%
#Check the models of 'Ford' for test_data
Ford = test_data[test_data['Brand'].str.lower() == 'ford']
unique_ford_models_v = sorted(Ford['model'].dropna().unique())
unique_ford_models_v
# Out:
# ['B-MAX',
#  'C-MAX',
#  'EDGE',
#  'EcoSport',
#  'Fiesta',
#  'Focus',
#  'Fusion',
#  'Galaxy',
#  'Grand C-MAX',
#  'Grand Tourneo Connect',
#  'KA',
#  'Ka+',
#  'Kuga',
#  'Mondeo',
#  'Mustang',
#  'Puma',
#  'S-MAX',
#  'Tourneo Connect',
#  'Tourneo Custom',
#  'Transit Tourneo']

# %% [markdown]
# - All the models from the lists correspond to Ford models.

# %% [markdown]
# **Hyundai**

# %%
#Check the models of 'Hyundai' for X_train
Hyundai = X_train[X_train['Brand'].str.lower() == 'hyundai']
unique_hyundai_models = sorted(Hyundai['model'].dropna().unique())
unique_hyundai_models
# Out:
# ['Accent',
#  'Getz',
#  'I1',
#  'I10',
#  'I2',
#  'I20',
#  'I3',
#  'I30',
#  'I40',
#  'I80',
#  'I800',
#  'IX2',
#  'IX20',
#  'IX35',
#  'Ioniq',
#  'Kona',
#  'Q7',
#  'Santa Fe',
#  'Tucson',
#  'Veloster']

# %%
#Check the models of 'Hyundai' for X_train
Hyundai = X_val[X_val['Brand'].str.lower() == 'hyundai']
unique_hyundai_models_v = sorted(Hyundai['model'].dropna().unique())
unique_hyundai_models_v
# Out:
# ['Getz',
#  'I1',
#  'I10',
#  'I2',
#  'I20',
#  'I3',
#  'I30',
#  'I40',
#  'I80',
#  'I800',
#  'IX2',
#  'IX20',
#  'IX35',
#  'Ioniq',
#  'Kona',
#  'Q3',
#  'Q5',
#  'Santa Fe',
#  'Terracan',
#  'Tucson']

# %%
#Check the models of 'Hyundai' for test_data
Hyundai = test_data[test_data['Brand'].str.lower() == 'hyundai']
unique_hyundai_models = sorted(Hyundai['model'].dropna().unique())
unique_hyundai_models
# Out:
# ['A5',
#  'I1',
#  'I10',
#  'I2',
#  'I20',
#  'I3',
#  'I30',
#  'I4',
#  'I40',
#  'I800',
#  'IX20',
#  'IX35',
#  'Ioniq',
#  'Kona',
#  'Q2',
#  'Q3',
#  'Santa Fe',
#  'Terracan',
#  'Tucson',
#  'Veloster']

# %% [markdown]
# - Models 'Q2', 'Q3', 'Q5', 'Q7', 'A5' are from 'Audi' not from 'Hyundai'. There are no such models in Hyundai.
# - Here, since the number of observations where the brand is a hyundai and the model is either 'Q3', 'Q5', or 'Q7 is low, it was assumes it was a mistake of the brand name, so the brand was changed from 'Hyundai' to 'Audi'.

# %%
# Replace Hyundai Q7 by Audi Q7 of X_train
mask_train = (X_train["Brand"] == "Hyundai") & (X_train["model"] == "Q7")
X_train.loc[mask_train, "Brand"] = "Audi"
X_train.loc[mask_train, "model"] = "Q7"

# Replace Hyundai Q3 by Audi Q3 of X_val
mask_val = (X_val["Brand"] == "Hyundai") & (X_val["model"] == "Q3")
X_val.loc[mask_val, "Brand"] = "Audi"
X_val.loc[mask_val, "model"] = "Q3"

# Replace Hyundai Q5 by Audi Q5 of X_val
mask_val = (X_val["Brand"] == "Hyundai") & (X_val["model"] == "Q5")
X_val.loc[mask_val, "Brand"] = "Audi"
X_val.loc[mask_val, "model"] = "Q5"

# Replace Hyundai A5 by Audi A5 of test_data
mask_test = (test_data["Brand"] == "Hyundai") & (test_data["model"] == "A5")
test_data.loc[mask_test, "Brand"] = "Audi"
test_data.loc[mask_test, "model"] = "A5"

# Replace Hyundai Q2 by Audi Q2 of test_data
mask_test = (test_data["Brand"] == "Hyundai") & (test_data["model"] == "Q2")
test_data.loc[mask_test, "Brand"] = "Audi"
test_data.loc[mask_test, "model"] = "Q2"

# Replace Hyundai Q3 by Audi Q3 of test_data
mask_test = (test_data["Brand"] == "Hyundai") & (test_data["model"] == "Q3")
test_data.loc[mask_test, "Brand"] = "Audi"
test_data.loc[mask_test, "model"] = "Q3"

# %% [markdown]
# **Mercedes**

# %%
#Check the models of 'Mercedes' for X_train
Mercedes = X_train[X_train['Brand'].str.lower() == 'mercedes']
unique_mercedes_models = sorted(Mercedes['model'].dropna().unique())
unique_mercedes_models
# Out:
# ['230',
#  'A Class',
#  'B Class',
#  'C Class',
#  'CL Class',
#  'CLA Class',
#  'CLC Class',
#  'CLK',
#  'CLS Class',
#  'E Class',
#  'G Class',
#  'GL Class',
#  'GLA Class',
#  'GLB Class',
#  'GLC Class',
#  'GLE Class',
#  'GLS Class',
#  'M Class',
#  'S Class',
#  'SL CLASS',
#  'SLK',
#  'V Class',
#  'X-CLASS']

# %%
#Check the models of 'Mercedes' for X_val
Mercedes = X_val[X_val['Brand'].str.lower() == 'mercedes']
unique_mercedes_models_v = sorted(Mercedes['model'].dropna().unique())
unique_mercedes_models_v
# Out:
# ['200',
#  '220',
#  'A Class',
#  'B Class',
#  'C Class',
#  'CL Class',
#  'CLA Class',
#  'CLK',
#  'CLS Class',
#  'E Class',
#  'G Class',
#  'GL Class',
#  'GLA Class',
#  'GLB Class',
#  'GLC Class',
#  'GLE Class',
#  'GLS Class',
#  'M Class',
#  'S Class',
#  'SL CLASS',
#  'SLK',
#  'V Class',
#  'X-CLASS']

# %%
#Check the models of 'Mercedes' for test_data
Mercedes = test_data[test_data['Brand'].str.lower() == 'mercedes']
unique_mercedes_models = sorted(Mercedes['model'].dropna().unique())
unique_mercedes_models
# Out:
# ['180',
#  'A Class',
#  'B Class',
#  'C Class',
#  'CL Class',
#  'CLA Class',
#  'CLC Class',
#  'CLK',
#  'CLS Class',
#  'E Class',
#  'G Class',
#  'GL Class',
#  'GLA Class',
#  'GLB Class',
#  'GLC Class',
#  'GLE Class',
#  'GLS Class',
#  'M Class',
#  'R Class',
#  'S Class',
#  'SL CLASS',
#  'SLK',
#  'V Class',
#  'X-CLASS']

# %% [markdown]
# - In Mercedes, 200, 220, 230 and 180 are not complete model names, they refer only to the engine/variant, not the class or body style.
# - Therefore, we have decided to replace them by missing values.

# %%
#replacing model '230' by missing value of X_train
X_train.loc[X_train["model"] == '230', "model"] = np.nan

#replacing model '200' by missing value of X_val
X_val.loc[X_val["model"] == '200', "model"] = np.nan

#replacing model '220' by missing value of X_val
X_val.loc[X_val["model"] == '220', "model"] = np.nan

#replacing model '180' by missing value of test_data
test_data.loc[test_data["model"] == '180', "model"] = np.nan

# %% [markdown]
# **Opel**

# %%
#Check the models of 'Opel' for X_train
Opel = X_train[X_train['Brand'].str.lower() == 'opel']
unique_opel_models = sorted(Opel['model'].dropna().unique())
unique_opel_models
# Out:
# ['Adam',
#  'Agila',
#  'Ampera',
#  'Antara',
#  'Astra',
#  'Cascada',
#  'Combo Life',
#  'Corsa',
#  'Crossland',
#  'Crossland X',
#  'Grandland',
#  'Grandland X',
#  'Gtc',
#  'Insignia',
#  'Kadjar',
#  'Meriva',
#  'Mokka',
#  'Mokka X',
#  'Tigra',
#  'Vectra',
#  'Viva',
#  'Vivaro',
#  'Zafira',
#  'Zafira Tourer']

# %%
#Check the models of 'Opel' for X_val
Opel = X_val[X_val['Brand'].str.lower() == 'opel']
unique_opel_models_v = sorted(Opel['model'].dropna().unique())
unique_opel_models_v
# Out:
# ['Adam',
#  'Agila',
#  'Antara',
#  'Astra',
#  'Combo Life',
#  'Corsa',
#  'Crossland',
#  'Crossland X',
#  'Grandland',
#  'Grandland X',
#  'Gtc',
#  'Insignia',
#  'Kadjar',
#  'Meriva',
#  'Mokka',
#  'Mokka X',
#  'Viva',
#  'Vivaro',
#  'Zafira',
#  'Zafira Tourer']

# %%
#Check the models of 'Opel' for test_data
Opel = test_data[test_data['Brand'].str.lower() == 'opel']
unique_opel_models = sorted(Opel['model'].dropna().unique())
unique_opel_models
# Out:
# ['Adam',
#  'Agila',
#  'Ampera',
#  'Antara',
#  'Astra',
#  'Cascada',
#  'Combo Life',
#  'Corsa',
#  'Crossland',
#  'Crossland X',
#  'Grandland',
#  'Grandland X',
#  'Gtc',
#  'Insignia',
#  'Meriva',
#  'Mokka',
#  'Mokka X',
#  'Tigra',
#  'Vectra',
#  'Viva',
#  'Vivaro',
#  'Zafira',
#  'Zafira Tourer']

# %% [markdown]
# - 'Kadjar' is a 'Renault' model not a 'Opel' model.
# - Since the brand 'Renault' is not in our dataset, we have decided to replace this model by missing values.

# %%
#replacing model 'Kadjar' by missing value for X_train and X_val
X_train.loc[X_train["model"] == 'Kadjar', "model"] = np.nan
X_val.loc[X_val["model"] == 'Kadjar', "model"] = np.nan

# %% [markdown]
# **Skoda**

# %%
#Check the models of 'Skoda' for X_train
Skoda = X_train[X_train['Brand'].str.lower() == 'skoda']
unique_skoda_models = sorted(Skoda['model'].dropna().unique())
unique_skoda_models
# Out:
# ['Citigo',
#  'Fabia',
#  'Kamiq',
#  'Karoq',
#  'Kodiaq',
#  'Octavia',
#  'Rapid',
#  'Roomster',
#  'Scala',
#  'Superb',
#  'Yeti',
#  'Yeti Outdoor']

# %%
#Check the models of 'Skoda' for X_val
Skoda = X_val[X_val['Brand'].str.lower() == 'skoda']
unique_skoda_models_v = sorted(Skoda['model'].dropna().unique())
unique_skoda_models_v
# Out:
# ['Citigo',
#  'Fabia',
#  'Kamiq',
#  'Karoq',
#  'Kodiaq',
#  'Octavia',
#  'Rapid',
#  'Roomster',
#  'Scala',
#  'Superb',
#  'Yeti',
#  'Yeti Outdoor']

# %%
#Check the models of 'Skoda' for test_data
Skoda = test_data[test_data['Brand'].str.lower() == 'skoda']
unique_skoda_models = sorted(Skoda['model'].dropna().unique())
unique_skoda_models
# Out:
# ['Citigo',
#  'Fabia',
#  'Kamiq',
#  'Karoq',
#  'Kodiaq',
#  'Octavia',
#  'Rapid',
#  'Roomster',
#  'Scala',
#  'Superb',
#  'Yeti',
#  'Yeti Outdoor']

# %% [markdown]
# - All the models showed seem to correspond to the brand 'Skoda'.

# %% [markdown]
# **VW**

# %%
#Check the models of 'VW' fro X_train
VW = X_train[X_train['Brand'].str.lower() == 'vw']
unique_vw_models = sorted(VW['model'].dropna().unique())
unique_vw_models
# Out:
# ['Amarok',
#  'Arteon',
#  'Beetle',
#  'CC',
#  'Caddy Life',
#  'Caddy Maxi',
#  'Caddy Maxi Life',
#  'California',
#  'Caravelle',
#  'Eos',
#  'Golf',
#  'Golf S',
#  'Golf SV',
#  'Jetta',
#  'Passat',
#  'Polo',
#  'Scirocco',
#  'Sharan',
#  'Shuttle',
#  'T-Cross',
#  'T-Roc',
#  'Tiguan',
#  'Tiguan Allspace',
#  'Touareg',
#  'Touran',
#  'Up']

# %%
#Check the models of 'VW' for X_val
VW = X_val[X_val['Brand'].str.lower() == 'vw']
unique_vw_models_v = sorted(VW['model'].dropna().unique())
unique_vw_models_v
# Out:
# ['Amarok',
#  'Arteon',
#  'Beetle',
#  'CC',
#  'Caddy Life',
#  'Caddy Maxi',
#  'Caddy Maxi Life',
#  'California',
#  'Caravelle',
#  'Eos',
#  'Fox',
#  'Golf',
#  'Golf S',
#  'Golf SV',
#  'Jetta',
#  'Passat',
#  'Polo',
#  'Scirocco',
#  'Sharan',
#  'Shuttle',
#  'T-Cross',
#  'T-Roc',
#  'Tiguan',
#  'Tiguan Allspace',
#  'Touareg',
#  'Touran',
#  'Up',
#  'polo']

# %%
#Check the models of 'VW' for test_data
VW = test_data[test_data['Brand'].str.lower() == 'vw']
unique_vw_models = sorted(VW['model'].dropna().unique())
unique_vw_models
# Out:
# ['Amarok',
#  'Arteon',
#  'Beetle',
#  'CC',
#  'Caddy Life',
#  'Caddy Maxi Life',
#  'California',
#  'Caravelle',
#  'Eos',
#  'Fox',
#  'Golf',
#  'Golf S',
#  'Golf SV',
#  'Jetta',
#  'Passat',
#  'Polo',
#  'Scirocco',
#  'Shara',
#  'Sharan',
#  'Shuttle',
#  'T-Cross',
#  'T-Roc',
#  'Tiguan',
#  'Tiguan Allspace',
#  'Touareg',
#  'Touran',
#  'Up']

# %% [markdown]
# - In x_train and X_val, all the models showed seem to correspond to the brand 'VW'.
# - In test_data, *Shara* is not the right VW model, the correct would be 'Sharan'.

# %%
#replacing 'Shara' by the correct name for test_data
test_data.loc[test_data["model"] == 'Shara', "model"] = 'Sharan'

# %% [markdown]
# #### 4.4.2. Numerical Variables

# %% [markdown]
# ##### 4.4.2.1. Correcting variables' incoherent values

# %% [markdown]
# **Previous Owners**

# %%
#checking negative values for X_train
X_train[X_train['previousOwners'] < 0]['previousOwners']
# Out:
# carID
# 75498    -2
# 29008    -2
# 61598    -2
# 41596    -2
# 73060    -2
#          ..
# 66085    -2
# 63759    -2
# 75549    -2
# 59833    -2
# 65364    -2
# Name: previousOwners, Length: 265, dtype: Int32

# %%
#checking negative values for X_val 
X_val[X_val['previousOwners'] < 0]['previousOwners']
# Out:
# carID
# 48893    -2
# 27263    -2
# 64618    -2
# 19970    -2
# 55427    -2
#          ..
# 75662    -2
# 31261    -2
# 50689    -2
# 52063    -2
# 49608    -2
# Name: previousOwners, Length: 106, dtype: Int32

# %%
#checking negative values for test_data
test_data[test_data['previousOwners'] < 0]['previousOwners']
# Out:
# carID
# 104574    -2
# 102304    -2
# 78379     -2
# 76435     -2
# 76702     -2
#           ..
# 95465     -2
# 86894     -2
# 98334     -2
# 107094    -2
# 103453    -2
# Name: previousOwners, Length: 168, dtype: Int32

# %% [markdown]
# - The training dataset has 265 cars with negative owners and the validation set has 106, all equal to -2, which is not possible. - Since the mean value of the previousOwners is 1.994580 and the median is 2, we made the assumption that these negative values are spelling mistakes made during the data collection, that added the '-'. Therefore, we decided the change all of the negative values to positive.

# %%
#replacing the negative values by their module.
X_train['previousOwners'] = X_train['previousOwners'].replace(-2, 2)
X_val['previousOwners'] = X_val['previousOwners'].replace(-2, 2)
test_data['previousOwners'] = test_data['previousOwners'].replace(-2, 2)

# %% [markdown]
# **Milage**

# %%
#checking negative observations for X_train 
X_train[X_train['mileage'] < 0]
# Out:
#           Brand      model  year transmission       mileage fuelType    tax  \
# carID
# 30017      Ford       EDGE  2016    Automatic -42650.453719   Diesel  200.0
# 52522    Toyota      Auris  2016          NaN -39765.602338   Hybrid    0.0
# 70201        VW      T-Roc  2018       Manual -48190.655673   Petrol  150.0
# 43065  Mercedes        SLK  2007          NaN -50755.210230   Petrol  325.0
# 30227      Ford     Fiesta  2016    Automatic -42650.453719   Petrol   30.0
# ...         ...        ...   ...          ...           ...      ...    ...
# 70143        VW  Caravelle  2016       Manual -48190.655673   Diesel  235.0
# 75549        VW    Golf SV  2016    Automatic -48190.655673   Petrol   30.0
# 24436      Ford     Fiesta  2017       Manual -42650.453719   Petrol  125.0
# 52966    Toyota      Yaris  2017    Automatic -39765.602338   Petrol  145.0
# 2675       Audi         TT  2019    Semi-Auto -52618.457894   Petrol  145.0
#
#         mpg  engineSize  paintQuality%  previousOwners  hasDamage
# carID
# 30017  47.9         2.0      83.000000               0          0
# 52522  70.6         1.8      86.000000               2          0
# 70201  53.3         1.5            NaN               2          0
# 43065  32.1         1.8      92.000000               4          0
# 30227  57.7         1.0      45.000000               1          0
# ...     ...         ...            ...             ...        ...
# 70143  42.8         2.0       1.769474               4          0
# 75549  54.3         1.4      59.000000               2          0
# 24436  54.3         1.2      97.000000            <NA>          0
# 52966  60.1         1.5      66.000000               2          0
# 2675   37.2         NaN      87.000000               4          0
#
# [247 rows x 12 columns]

# %%
#checking negative observations for X_val
X_val[X_val['mileage'] < 0]
# Out:
#           Brand    model  year transmission       mileage fuelType    tax  \
# carID
# 37025  Mercedes  C Class  2016    Semi-Auto -50755.210230   Diesel   30.0
# 47157     Skoda  Octavia  2019       Manual -46497.584838   Petrol  145.0
# 6786       Audi       Q7  2019    Semi-Auto -52618.457894   Diesel  150.0
# 25030      Ford   Fiesta  2017       Manual -42650.453719   Petrol  145.0
# 17015      Ford   Fiesta  2018       Manual -42650.453719   Petrol  145.0
# ...         ...      ...   ...          ...           ...      ...    ...
# 60678      Opel    Mokka  2016       Manual -42707.564215      NaN  160.0
# 72628        VW   Arteon  2020    Semi-Auto -48190.655673   Petrol  150.0
# 45883  Mercedes  E Class  2016    Semi-Auto -50755.210230   Diesel  160.0
# 12446       BMW       X2  2019    Automatic -58540.574478   Petrol  145.0
# 52509    Toyota    Yaris  2018    Automatic -39765.602338   Petrol  145.0
#
#         mpg  engineSize  paintQuality%  previousOwners  hasDamage
# carID
# 37025  64.2         1.6            NaN               0          0
# 47157  55.4         1.5           89.0               1          0
# 6786   33.6         3.0           43.0               3          0
# 25030  65.7         1.0           34.0               4          0
# 17015  65.7         1.0           33.0               1          0
# ...     ...         ...            ...             ...        ...
# 60678  44.8         1.4           60.0               1          0
# 72628  32.8         2.0           83.0               1          0
# 45883  50.4         3.0           48.0               4          0
# 12446  38.7         2.0           59.0               4          0
# 52509  60.1         1.5           33.0               0          0
#
# [122 rows x 12 columns]

# %%
#checking negative observations for test_data
test_data[test_data['mileage'] < 0]
# Out:
#            Brand    model  year transmission       mileage fuelType    tax  \
# carID
# 106581        VW   Tiguan  2017    Semi-Auto -48190.655673   Petrol  150.0
# 92673   Mercedes  C Class  2017          NaN -50755.210230   Diesel    NaN
# 93065   Mercedes  C Class  2019    Semi-Auto -50755.210230   Petrol    NaN
# 89444    Hyundai   Tucson  2020    Semi-Auto -36635.042697   Hybrid  150.0
# 85269       Ford   Mondeo  2017    Automatic -42650.453719   Diesel   20.0
# ...          ...      ...   ...          ...           ...      ...    ...
# 100676      Opel  Cascada  2015       Manual -42707.564215   Diesel  125.0
# 92455   Mercedes  C Class  2019    Semi-Auto -50755.210230   Petrol    NaN
# 106053        VW     Polo  2017       Manual -48190.655673   Petrol   20.0
# 95430   Mercedes  A Class  2016       Manual -50755.210230   Petrol  125.0
# 91768   Mercedes  A Class  2019       Manual -50755.210230   Petrol  145.0
#
#          mpg  engineSize  paintQuality%  previousOwners  hasDamage
# carID
# 106581  38.2         2.0           60.0               2          0
# 92673    NaN         2.1           93.0               2          0
# 93065    NaN         3.0           97.0               4          0
# 89444   50.4         1.6           41.0               0          0
# 85269   67.3         2.0           31.0               0          0
# ...      ...         ...            ...             ...        ...
# 100676  57.6         2.0           77.0               2          0
# 92455    NaN         2.0           59.0               2          0
# 106053  58.9         1.0           72.0               4          0
# 95430   51.4         1.6           58.0               1          0
# 91768   28.5         1.3           81.0               1          0
#
# [170 rows x 12 columns]

# %% [markdown]
# - Here we have 247 negative values in the training set, 122 in the validation and 170 in test dataset.
# - Since, it appers that these negative numbers do not have any kind of relationship, we decided to convert them into missing values to fill them in later.

# %%
#replacing negative values by missing values 
X_train.loc[X_train["mileage"] < 0, "mileage"] = np.nan
X_val.loc[X_val["mileage"] < 0, "mileage"] = np.nan
test_data.loc[test_data["mileage"] < 0, "mileage"] = np.nan

# %% [markdown]
# **Mpg**

# %%
#checking negative observations for X_train 
X_train[X_train['mpg'] < 0]
# Out:
#       Brand     model  year transmission  mileage fuelType    tax        mpg  \
# carID
# 14662   BMW  4 Series  2019    Automatic    123.0   Diesel  145.0 -43.421768
# 13698   BMW  3 Series  2016       Manual  59222.0   Diesel  125.0 -43.421768
# 14420   BMW  2 Series  2015    Automatic  38902.0   Petrol  260.0 -43.421768
# 11883   BMW  2 Series  2019    Semi-Auto   9531.0   Diesel  150.0 -43.421768
# 13134   BMW  1 Series  2016       Manual      NaN   Petrol   30.0 -43.421768
# 10078   BMW  6 Series  2019    Semi-Auto  27713.0   Diesel  145.0 -43.421768
# 13574   BMW  3 Series  2017    Semi-Auto  25000.0   Diesel   30.0 -43.421768
# 12352   BMW        M3  2018    Semi-Auto  12879.0   Petrol  150.0 -43.421768
# 8542    NaN  3 Series  2013    Semi-Auto  40900.0   Diesel  145.0 -43.421768
# 14603   BMW  2 Series  2015    Semi-Auto  26035.0   Petrol  165.0 -43.421768
# 13396   BMW        X1  2019    Semi-Auto   5163.0   Petrol  145.0 -43.421768
# 13901   BMW  1 Series  2019          NaN  10927.0   Petrol  150.0 -43.421768
# 10653   BMW        I3  2017    Automatic  29851.0   Hybrid    0.0 -43.421768
# 8314    BMW  5 Series  2014    Semi-Auto  59317.0   Diesel   30.0 -43.421768
# 14767   BMW  5 Series  2019    Semi-Auto  13000.0   Hybrid  140.0 -43.421768
# 10972   BMW  5 Series  2020    Semi-Auto     11.0   Hybrid  145.0 -43.421768
# 7781    BMW  3 Series  2017       Manual  29968.0   Diesel   30.0 -43.421768
# 12026   BMW  2 Series  2018       Manual  19853.0   Diesel  150.0 -43.421768
# 14842   BMW        X1  2016       Manual  17531.0   Diesel  125.0 -43.421768
# 11181   BMW  1 Series  2019    Semi-Auto  10040.0   Diesel  145.0 -43.421768
# 13713   BMW  3 Series  2020    Automatic    100.0   Diesel  145.0 -43.421768
# 9202    BMW        X1  2016    Automatic  46968.0   Diesel  125.0 -43.421768
# 8094    BMW        X3  2016    Automatic  59692.0   Diesel  145.0 -43.421768
# 13073   BMW  3 Series  2015    Automatic  35248.0   Diesel   30.0 -43.421768
# 8956    BMW  7 Series  2019    Automatic   8546.0   Diesel  145.0 -43.421768
#
#        engineSize  paintQuality%  previousOwners  hasDamage
# carID
# 14662         2.0           58.0               0          0
# 13698         2.0           74.0               1          0
# 14420         3.0           33.0               4          0
# 11883         2.0           64.0               4          0
# 13134         1.5           70.0               2          0
# 10078         3.0           47.0               1          0
# 13574         2.0           43.0               0          0
# 12352         3.0           59.0               1          0
# 8542          3.0           88.0            <NA>          0
# 14603         2.0           75.0               3          0
# 13396         2.0           86.0               1          0
# 13901         1.5           78.0               4          0
# 10653         0.0           40.0               0          0
# 8314          2.0           74.0               4          0
# 14767         2.0           62.0               4          0
# 10972         2.0           77.0               2          0
# 7781          2.0           52.0               1          0
# 12026         2.0           96.0               3          0
# 14842         2.0           60.0               2          0
# 11181         2.0           70.0               3          0
# 13713         2.0           49.0               4          0
# 9202          2.0           82.0               0          0
# 8094          2.0           40.0               4          0
# 13073         2.0           96.0               3          0
# 8956          3.0           43.0               0          0

# %%
#checking negative observations for X_val
X_val[X_val['mpg'] < 0]
# Out:
#       Brand     model  year transmission  mileage fuelType         tax  \
# carID
# 14934   BMW  3 Series  2019    Automatic   3185.0   Petrol  145.000000
# 13723   BMW  5 Series  <NA>    Automatic  34599.0   Diesel   30.000000
# 13140   BMW  1 Series  2019    Automatic   6744.0   Petrol  -43.242082
# 12400   BMW        X5  2016    Automatic  46126.0   Diesel  200.000000
# 13874   BMW  2 Series  2014    Automatic  45868.0   Petrol  145.000000
# 11921   BMW  2 Series  2017          NaN  14612.0   Diesel  145.000000
# 10214   BMW  3 Series  2014    Automatic  45140.0   Diesel  125.000000
# 13855   BMW  3 Series  <NA>    Automatic  27725.0   Diesel  145.000000
# 11143   BMW        Z4  2013    Semi-Auto  26356.0   Petrol  200.000000
# 14127   BMW  2 Series  2020    Semi-Auto   1118.0   Diesel  145.000000
# 8691    BMW  1 Series  2019    Automatic  12839.0   Diesel  145.000000
#
#              mpg  engineSize  paintQuality%  previousOwners  hasDamage
# carID
# 14934 -43.421768         2.0           97.0               3          0
# 13723 -43.421768         2.0           43.0               3          0
# 13140 -43.421768         1.5           57.0               3          0
# 12400 -43.421768         3.0           77.0               2          0
# 13874 -43.421768         2.0           95.0               0          0
# 11921 -43.421768         2.0           92.0               2          0
# 10214 -43.421768         3.0           77.0               2          0
# 13855 -43.421768         2.0           96.0               1          0
# 11143 -43.421768         2.0           44.0               4          0
# 14127 -43.421768         2.0           37.0               1          0
# 8691  -43.421768         2.0           68.0               1          0

# %%
#checking negative observations for tes_data
test_data[test_data['mpg'] < 0]
# Out:
#       Brand     model  year transmission  mileage fuelType         tax  \
# carID
# 79461   BMW  5 Series  2016    Automatic  83189.0   Diesel   20.000000
# 81976   BMW  3 Series  2019    Semi-Auto   6000.0   Diesel  145.000000
# 80175   BMW        X1  2016       Manual      NaN   Diesel   20.000000
# 80445   BMW  1 Series  2015       Manual  46000.0   Petrol  125.000000
# 79366   BMW        X3  2015    Semi-Auto  44126.0   Diesel  200.000000
# 82248   BMW  5 Series  2019    Semi-Auto   5130.0   Diesel  145.000000
# 80677   BMW  1 Series  2015    Semi-Auto  46242.0   Diesel   30.000000
# 79287   BMW  3 Series  2019    Semi-Auto  23000.0   Petrol  150.000000
# 82168   BMW  3 Series  2016       Manual  27796.0   Petrol  205.000000
# 80535   BMW  5 Series  2017    Semi-Auto  20279.0      NaN  135.000000
# 81821   BMW        X1  2017       Manual  33600.0      NaN  150.000000
# 80414   BMW  3 Series  2019    Semi-Auto   7004.0   Petrol  145.000000
# 81353   BMW  2 Series  2017    Semi-Auto  30330.0   Diesel  145.000000
# 82185   BMW  6 Series  2015    Semi-Auto  51412.0   Diesel  160.000000
# 81132   BMW  3 Series  2015    Automatic  50000.0   Diesel  316.487189
# 80965   BMW        X1  2017    Automatic  89232.0   Diesel  145.000000
# 80270   BMW  3 Series  2019    Automatic   1000.0   Diesel  145.000000
#
#              mpg  engineSize  paintQuality%  previousOwners  hasDamage
# carID
# 79461 -43.421768    2.000000           68.0               2          0
# 81976 -43.421768    3.822758           86.0               1          0
# 80175 -43.421768    2.000000           32.0               0          0
# 80445 -43.421768    1.500000           54.0               0          0
# 79366 -43.421768    3.000000           79.0               3          0
# 82248 -43.421768    2.000000           41.0               4          0
# 80677 -43.421768    2.000000           74.0               0          0
# 79287 -43.421768    2.000000           41.0               2          0
# 82168 -43.421768    2.000000           97.0               2          0
# 80535 -43.421768    2.000000           91.0               3          0
# 81821 -43.421768    2.000000           61.0               0          0
# 80414 -43.421768    2.000000           98.0               3          0
# 81353 -43.421768    2.000000           52.0               1          0
# 82185 -43.421768    3.000000           33.0               0          0
# 81132 -43.421768    3.000000           87.0               4          0
# 80965 -43.421768    2.000000           94.0               0          0
# 80270 -43.421768    2.000000           48.0               1          0

# %% [markdown]
# - We can observe that negative values are all the same. In the context of the variable 'mpg', it is not normal to have dozens of cars with the exact same number of milles per gallon, since the car's consumption are dependent on a lot of factors such as the driver, the age of the car and the way the car is used. We have also noticed that all of the cars with negative values are BMWs, so it was probably an error related to the brand.
# - Therefore we decided to replace them with missing values to fill them afterwards.

# %%
#replacing negative values by missing values 
X_train.loc[X_train["mpg"] < 0, "mpg"] = np.nan
X_val.loc[X_val["mpg"] < 0, "mpg"] = np.nan
test_data.loc[test_data["mpg"] < 0, "mpg"] = np.nan

# %%
#checking electric cars for X_train
X_train[X_train['fuelType'] == 'Electric']
# Out:
#       Brand   model  year transmission  mileage  fuelType  tax    mpg  \
# carID
# 21931  Ford  Mondeo  <NA>    Automatic  24531.0  Electric  0.0   67.3
# 12786   NaN      I3  2015    Automatic  29465.0  Electric  0.0  470.8
# 64169  Opel  Ampera  2015    Automatic  34461.0  Electric  0.0  235.4
# 16306  Ford  Mondeo  2016    Automatic   9396.0  Electric  0.0   67.3
#
#        engineSize  paintQuality%  previousOwners  hasDamage
# carID
# 21931    2.000000           82.0               4          0
# 12786    3.822758           67.0               2          0
# 64169    1.400000           83.0               1          0
# 16306    2.000000           59.0               3          0

# %%
#checking electric cars for X_val
X_val[X_val['fuelType'] == 'Electric']
# Out:
# Empty DataFrame
# Columns: [Brand, model, year, transmission, mileage, fuelType, tax, mpg, engineSize, paintQuality%, previousOwners, hasDamage]
# Index: []

# %%
#checking electric cars for test_data
test_data[test_data['fuelType'] == 'Electric']
# Out:
#       Brand model  year transmission  mileage  fuelType    tax    mpg  \
# carID
# 79316   BMW    I3  2017    Automatic  20321.0  Electric  135.0  470.8
#
#        engineSize  paintQuality%  previousOwners  hasDamage
# carID
# 79316         0.0           90.0               3          0

# %% [markdown]
# - Also it does not make sense for an electric car to have the variable *mpg* since electric cars do not use petrol, so “miles per gallon” is meaningless.
# - Therefore, we have decided to replace *mpg* of electric cars by 0.

# %%
#changing the mpg of electric cars to 0 for X_train and test_data
X_train.loc[X_train['fuelType'] == 'Electric', 'mpg'] = 0
test_data.loc[test_data['fuelType'] == 'Electric', 'mpg'] = 0

# %% [markdown]
# **Engine Size**

# %%
#checking engineSize lower than 0.5 for X_train 
X_train[X_train['engineSize'] < 0.5]
# Out:
#           Brand    model  year transmission  mileage fuelType         tax  \
# carID
# 75544        VW     Golf  2016       Manual  36000.0   Petrol  -49.153541
# 8487        BMW       X2  2019       Manual    103.0   Diesel  145.000000
# 75852        VW     Polo  2020       Manual   1950.0   Petrol  145.000000
# 24308       NaN   Fiesta  2014       Manual  59361.0   Petrol    0.000000
# 41091  Mercedes  C Class  2019    Semi-Auto   9693.0   Petrol         NaN
# ...         ...      ...   ...          ...      ...      ...         ...
# 72432        VW     Polo  2018    Semi-Auto   3103.0   Petrol  145.000000
# 5271       Audi       Q3  2019       Manual   3125.0   Petrol  145.000000
# 46984       NaN      NaN  2019    Automatic   8326.0   Petrol  145.000000
# 16713      Ford    Focus  2019       Manual   7124.0   Petrol         NaN
# 75954        VW     Golf  2015       Manual  57226.0   Diesel   20.000000
#
#         mpg  engineSize  paintQuality%  previousOwners  hasDamage
# carID
# 75544  53.3    0.186425           40.0               0          0
# 8487   53.3    0.313407           41.0               1          0
# 75852  48.7    0.186425           98.0               1          0
# 24308  65.7   -0.103493           81.0               1          0
# 41091   NaN    0.307074           70.0               3          0
# ...     ...         ...            ...             ...        ...
# 72432  45.6    0.186425           81.0               2          0
# 5271   40.9    0.154529           62.0               0          0
# 46984  36.7    0.191462           45.0               6          0
# 16713   NaN   -0.103493           96.0               2          0
# 75954  67.3    0.186425           54.0               1       <NA>
#
# [390 rows x 12 columns]

# %%
#checking engineSize lower than 0.5 for X_val
X_val[X_val['engineSize'] < 0.5]
# Out:
#          Brand     model  year transmission  mileage fuelType         tax  \
# carID
# 4949      Audi       NaN  2018       Manual  20560.0   Petrol  145.000000
# 10470      BMW  5 Series  2019    Semi-Auto   3901.0   Petrol  145.000000
# 70650       VW     T-Roc  2019          NaN   2009.0   Petrol  303.148891
# 32659  Hyundai      IX35  2015       Manual  23041.0   Diesel  165.000000
# 24755     Ford     Focus  2018       Manual  13794.0   Petrol  299.473504
# ...        ...       ...   ...          ...      ...      ...         ...
# 5468      Audi        A1  2015       Manual  20048.0   Petrol    0.000000
# 21985     Ford     Focus  2017       Manual  23000.0   Petrol         NaN
# 5664      Audi        A6  2019    Automatic   6498.0   Diesel  145.000000
# 11545      BMW  3 Series  2019    Semi-Auto   2754.0   Diesel  150.000000
# 34141  Hyundai       I20  2018       Manual   3920.0   Petrol  150.000000
#
#         mpg  engineSize  paintQuality%  previousOwners  hasDamage
# carID
# 4949   67.3    0.154529           83.0               2          0
# 10470  46.3    0.313407           76.0               3          0
# 70650  39.8    0.000000           80.0               4          0
# 32659  51.4    0.000000           47.0               1          0
# 24755   NaN   -0.103493           93.0               2          0
# ...     ...         ...            ...             ...        ...
# 5468   67.3    0.154529           55.0               3          0
# 21985   NaN    0.000000           52.0               3          0
# 5664   50.4    0.154529           90.0               2          0
# 11545  52.3    0.313407           68.0               2          0
# 34141  46.3    0.000000           54.0               3          0
#
# [128 rows x 12 columns]

# %%
#checking engineSize lower than 0.5 for test_data
test_data[test_data['engineSize'] < 0]
# Out:
#       Brand        model  year transmission  mileage fuelType    tax   mpg  \
# carID
# 86916  Ford       Fiesta  2017       Manual  32320.0   Petrol    0.0  65.7
# 87653  Ford       Mondeo  2016       Manual  75309.0   Diesel   30.0   NaN
# 84976  Ford        Focus  2019       Manual  10000.0   Petrol  145.0  46.3
# 86234  Ford        Focus  2017       Manual  40096.0   Diesel    0.0  74.3
# 86621  Ford         Kuga  2019       Manual   6888.0   Diesel  145.0  38.2
# 85746  Ford         Kuga  2018       Manual   7796.0      NaN  145.0  54.3
# 85059  Ford        Focus  2015       Manual  18741.0      NaN    NaN   NaN
# 87744  Ford        Focus  2017    Semi-Auto  11882.0   Diesel    NaN   NaN
# 84468  Ford       Fiesta  2017       Manual  29533.0   Petrol   20.0  62.8
# 84264  Ford       Mondeo  2011       Manual      NaN   Petrol  145.0  48.7
# 86696  Ford        Focus  2019    Automatic   8221.0   Diesel    NaN   NaN
# 87952  Ford  Grand C-MAX  2011          NaN  90000.0   Diesel  200.0  48.7
# 87865  Ford       Mondeo  2019       Manual     23.0   Diesel  145.0  65.7
# 83249  Ford       Fiesta  2019       Manual  13723.0   Petrol  145.0  58.9
# 83304  Ford        Focus  2018       Manual   8005.0   Petrol    NaN   NaN
# 88081  Ford        Focus  2019       Manual   5252.0   Petrol  145.0  51.4
# 89065  Ford        Focus  2016       Manual  20408.0   Petrol    NaN   NaN
# 86602  Ford        Focus  2019    Automatic   4896.0      NaN    NaN   NaN
# 82868  Ford       Fiesta  2019       Manual   7156.0   Petrol  145.0  58.9
# 84971  Ford       Fiesta  2016    Automatic  30373.0   Petrol    0.0  57.7
# 85327  Ford        Focus  2019       Manual   6156.0   Diesel    NaN   NaN
# 84062  Ford       Fiesta  2018       Manual  20015.0   Petrol  145.0  65.7
# 89183  Ford        Focus  2018       Manual  26491.0   Diesel  145.0  74.3
# 88364  Ford       Fiesta  2015       Manual      NaN   Petrol   20.0   NaN
# 88475  Ford        Focus  2019       Manual   3088.0   Diesel    NaN   NaN
# 85687  Ford       Galaxy  2017    Semi-Auto  28613.0   Diesel  145.0  52.3
# 86568  Ford        Focus  2015       Manual  54451.0   Diesel    NaN   NaN
# 82521  Ford         Kuga  2017    Automatic      NaN   Petrol  235.0  38.2
# 86406  Ford        Focus  2019    Automatic  11689.0   Petrol  145.0  48.7
# 89194  Ford         Kuga  2014       Manual  65000.0   Diesel  200.0  47.9
# 86514  Ford       Fiesta  2018       Manual  18220.0   Petrol  145.0  64.2
# 86161  Ford       Fiesta  2016       Manual   7519.0   Petrol  125.0  54.3
# 89380  Ford       Fiesta  2018       Manual  10573.0   Petrol  150.0  65.7
#
#        engineSize  paintQuality%  previousOwners  hasDamage
# carID
# 86916   -0.103493      54.000000               2          0
# 87653   -0.103493      68.000000               1          0
# 84976   -0.103493      68.000000               1          0
# 86234   -0.103493      77.000000               2          0
# 86621   -0.103493      93.000000               2          0
# 85746   -0.103493      61.000000               1          0
# 85059   -0.103493      42.000000               1          0
# 87744   -0.103493      66.000000               1          0
# 84468   -0.103493      66.000000               2          0
# 84264   -0.103493      72.000000               0          0
# 86696   -0.103493      67.000000               1          0
# 87952   -0.103493      46.000000               1          0
# 87865   -0.103493      38.000000               2          0
# 83249   -0.103493      37.000000               0          0
# 83304   -0.103493      65.000000               4          0
# 88081   -0.103493      86.000000            <NA>          0
# 89065   -0.103493      73.000000               2          0
# 86602   -0.103493      92.000000               3          0
# 82868   -0.103493      68.000000               2          0
# 84971   -0.103493      51.000000               3       <NA>
# 85327   -0.103493      69.000000               1          0
# 84062   -0.103493      74.000000               4          0
# 89183   -0.103493       3.225744               3          0
# 88364   -0.103493      36.000000               4          0
# 88475   -0.103493      66.000000               3          0
# 85687   -0.103493      52.000000            <NA>          0
# 86568   -0.103493      32.000000               1          0
# 82521   -0.103493      37.000000               4          0
# 86406   -0.103493      59.000000               0          0
# 89194   -0.103493      30.000000               4          0
# 86514   -0.103493      85.000000               3          0
# 86161   -0.103493      34.000000               3          0
# 89380   -0.103493      49.000000               4          0

# %% [markdown]
# - The negative values of EngineSize are all equal and they all belong to a ford. However, the model is different. It is not common for these models to have the same engine size, therefore, we have decided to replace by missing values.
# - In addition, we have rows where the value is less than 0.5. In those cases, the numbers are changed to missing values as it is highly unlikely to have cars with engine size smaller than 0.5.

# %%
#replacing negative values by missing values 
X_train.loc[X_train["engineSize"] < 0.5, "engineSize"] = np.nan
X_val.loc[X_val["engineSize"] < 0.5, "engineSize"] = np.nan
test_data.loc[test_data["engineSize"] < 0.5, "engineSize"] = np.nan

# %% [markdown]
# **Tax**

# %%
#checking negative observations for X_train 
X_train[X_train['tax'] < 0]
# Out:
#           Brand     model  year transmission  mileage fuelType        tax  \
# carID
# 75544        VW      Golf  2016       Manual  36000.0   Petrol -49.153541
# 71704        VW    Tiguan  2017       Manual  20000.0   Petrol -49.153541
# 1985       Audi        A4  2013    Automatic  81000.0   Diesel -60.684095
# 29851      Ford     Focus  2019    Automatic  17476.0   Diesel -45.780610
# 50135     Skoda   Octavia  2019       Manual  13901.0   Petrol -18.330743
# ...         ...       ...   ...          ...      ...      ...        ...
# 10162       BMW  1 Series  2009       Manual  77000.0   Petrol -43.242082
# 43348  Mercedes   C Class  2019    Automatic  12986.0   Diesel -56.193202
# 42490  Mercedes   C Class  2024    Semi-Auto    901.0   Diesel -56.193202
# 54940    Toyota      Aygo  2018       Manual   4346.0   Petrol -91.121630
# 4681       Audi        A1  2020       Manual   3265.0   Petrol -60.684095
#
#              mpg  engineSize  paintQuality%  previousOwners  hasDamage
# carID
# 75544  53.300000         NaN      40.000000               0          0
# 71704  48.700000         1.4      50.000000               2          0
# 1985   58.900000         2.0     125.301945               3          0
# 29851  64.200000         NaN      41.000000               2          0
# 50135  55.400000         1.5      73.000000               4          0
# ...          ...         ...            ...             ...        ...
# 10162  42.800000         2.0      56.000000               3          0
# 43348        NaN         2.0      37.000000               1          0
# 42490  61.400000         2.0      36.000000               3          0
# 54940  68.900000         1.0      49.000000               4          0
# 4681    9.821462         1.0      32.000000               1          0
#
# [254 rows x 12 columns]

# %%
#checking negative observations for X_val
X_val[X_val['tax'] < 0]
# Out:
#           Brand      model  year transmission  mileage fuelType        tax  \
# carID
# 64518      Opel      Corsa  2017       Manual  15388.0   Petrol -20.241079
# 10920       BMW   4 Series  <NA>       Manual   3500.0      NaN -43.242082
# 68172        VW         Up  2016       Manual  40524.0   Petrol -49.153541
# 44618  Mercedes    C Class  2017    Automatic  35649.0   Diesel -56.193202
# 7577        BMW   5 Series  2015       Manual  68310.0   Diesel -43.242082
# ...         ...        ...   ...          ...      ...      ...        ...
# 42420  Mercedes    B Class  2019    Automatic  13866.0   Petrol -56.193202
# 46614  Mercedes  GLE Class  2017    Semi-Auto  25542.0   Diesel -56.193202
# 13256       BMW   2 Series  2019    Automatic   5913.0   Hybrid -43.242082
# 61217      Opel      Astra  2016       Manual  17458.0   Petrol -20.241079
# 10292       BMW         X1  2016    Automatic  28785.0   Diesel -43.242082
#
#          mpg  engineSize  paintQuality%  previousOwners  hasDamage
# carID
# 64518   55.4         1.4           51.0               2          0
# 10920   46.3         2.0           60.0               2          0
# 68172   62.8         1.0           96.0               0          0
# 44618    NaN         2.1           68.0               1          0
# 7577    65.7         2.0           64.0               2          0
# ...      ...         ...            ...             ...        ...
# 42420   45.6         1.3           72.0               2          0
# 46614   42.8         3.0           61.0               4          0
# 13256  148.7         1.5           46.0               0          0
# 61217   64.2         1.0           67.0               4          0
# 10292   57.6         2.0           97.0               3          0
#
# [124 rows x 12 columns]

# %%
#checking negative observations for test_data
test_data[test_data['tax'] < 0]
# Out:
#            Brand     model  year transmission  mileage fuelType        tax  \
# carID
# 91338   Mercedes   E Class  2019    Automatic   6458.0   Petrol -56.193202
# 107819        VW    Amarok  2019    Automatic   3655.0   Diesel -49.153541
# 82836       Ford    Fiesta  2018          NaN   9358.0   Petrol -45.780610
# 84840       Ford      Kuga  2015       Manual  42277.0   Diesel -45.780610
# 81080        BMW        X5  2019    Semi-Auto   3658.0   Diesel -43.242082
# ...          ...       ...   ...          ...      ...      ...        ...
# 87489       Ford     Focus  2018       Manual  13861.0   Diesel -45.780610
# 94498   Mercedes  CL Class  2013       Manual  69965.0   Petrol -56.193202
# 86620       Ford    Fiesta  2017       Manual      NaN   Petrol -45.780610
# 97807      Skoda     Fabia  2019       Manual     10.0   Petrol -18.330743
# 87336       Ford    Mondeo  2016       Manual  27127.0   Diesel -45.780610
#
#          mpg  engineSize  paintQuality%  previousOwners  hasDamage
# carID
# 91338   32.1         4.0           49.0               3          0
# 107819  33.6         3.0           97.0               4          0
# 82836   65.7         1.0           66.0            <NA>          0
# 84840   60.1         2.0           86.0               2          0
# 81080   37.7         3.0            NaN               1          0
# ...      ...         ...            ...             ...        ...
# 87489   74.3         1.5           48.0               0          0
# 94498   50.4         1.6           78.0               3          0
# 86620   54.3         1.2           38.0               3          0
# 97807   51.4         1.0           78.0               0       <NA>
# 87336   65.7         1.5           44.0               0          0
#
# [161 rows x 12 columns]

# %% [markdown]
# - Even tough 'tax' has different values for different cars, it can never be negative, because that would mean the government is paying the owner to own the car, which is impossible.
# - We have decided to replace these values by missing values.

# %%
#replacing negative values by missing values 
X_train.loc[X_train["tax"] < 0, "tax"] = np.nan
X_val.loc[X_val["tax"] < 0, "tax"] = np.nan
test_data.loc[test_data["tax"] < 0, "tax"] = np.nan

# %% [markdown]
# **Paint Quality (%)**

# %% [markdown]
# - According to project guidelines, we should be able to "create a predictive model capable of evaluating the price of a car based on the user’s input without needing the car to be taken to a mechanic."
# - As *paintQuality%* is " The mechanic’s assessment of the cars’ overall paint quality and hull integrity (filled by the mechanic during evaluation).", this variable is not considered valid and accurate to predict the model, so it would not be considered from now on.

# %%
X_train.drop('paintQuality%', axis = 1, inplace = True)
X_val.drop('paintQuality%', axis = 1, inplace = True)
test_data.drop('paintQuality%', axis = 1, inplace = True)

X_train.head(3)
# Out:
#           Brand    model  year transmission  mileage fuelType    tax   mpg  \
# carID
# 42520  Mercedes  E Class  2018    Semi-Auto   1306.0   Diesel  145.0  41.5
# 25115      Ford    Focus  2015    Automatic   7802.0   Petrol    NaN   NaN
# 45113  Mercedes  C Class  2017    Automatic  18495.0   Diesel    NaN   NaN
#
#        engineSize  previousOwners  hasDamage
# carID
# 42520         3.0               3          0
# 25115         1.6               2          0
# 45113         2.1               4          0

# %% [markdown]
# - It does not make sense to have higher values than 100, since tax is a percentage.
# - Therefore, we have decided to replace them by missing values.

# %% [markdown]
# **Year**

# %%
#checking values higher than 2020 for X_train 
X_train[X_train['year'] > 2020]
# Out:
#           Brand     model  year transmission  mileage fuelType    tax   mpg  \
# carID
# 58698      Opel  Insignia  2023       Manual  34850.0   Petrol  125.0  50.4
# 32317   Hyundai       I10  2023       Manual  17470.0   Petrol  145.0  57.7
# 56901      Opel     Astra  2023       Manual      NaN   Petrol  150.0  62.8
# 44150  Mercedes   C Class  2024       Manual  31540.0   Petrol  145.0  49.6
# 684        Audi        A1  2024       Manual  24755.0      NaN    0.0  76.3
# ...         ...       ...   ...          ...      ...      ...    ...   ...
# 3088       Audi        A4  2024    Semi-Auto  31850.0   Petrol  145.0  36.7
# 54235    Toyota     Yaris  2023       Manual   2157.0   Petrol  145.0  47.9
# 13248       BMW  4 Series  2024       Manual  42348.0   Petrol  200.0  40.4
# 42362  Mercedes   A Class  2024    Semi-Auto  23247.0   Petrol  200.0  42.8
# 11336       BMW        Z4  2024    Semi-Auto   8004.0   Petrol  145.0  37.2
#
#        engineSize  previousOwners  hasDamage
# carID
# 58698         1.4               4          0
# 32317         1.2               3          0
# 56901         1.0               4          0
# 44150         2.0               0          0
# 684           1.6               0          0
# ...           ...             ...        ...
# 3088          3.0               1          0
# 54235         1.5               2          0
# 13248         2.0               2          0
# 42362         2.0               2          0
# 11336         2.0               2          0
#
# [250 rows x 11 columns]

# %%
#checking values higher than 2020 for X_val 
X_val[X_val['year'] > 2020]
# Out:
#           Brand     model  year transmission  mileage fuelType    tax   mpg  \
# carID
# 61654      Opel    Zafira  2023       Manual  14466.0   Petrol  200.0   NaN
# 6647       Audi        R8  2024    Semi-Auto   4000.0   Petrol  145.0  21.4
# 26145      Ford     Focus  2023       Manual  77000.0   Diesel   20.0  67.3
# 60921      Opel       NaN  2023    Automatic  33490.0   Diesel  145.0  51.4
# 50094     Skoda   Octavia  2023       Manual  15740.0   Petrol  145.0  58.9
# ...         ...       ...   ...          ...      ...      ...    ...   ...
# 8195        BMW  2 Series  2024       Manual  43555.0   Petrol   30.0  57.6
# 46582  Mercedes   C Class  2024    Semi-Auto  51304.0   Diesel    NaN   NaN
# 35087  Mercedes   E Class  2024    Automatic   2553.0   Diesel  145.0  70.6
# 71459        VW    Tiguan  2023       Manual   9195.0   Diesel  145.0  47.9
# 33600   Hyundai       I20  2023       Manual  16764.0   Petrol  150.0  58.9
#
#        engineSize  previousOwners  hasDamage
# carID
# 61654         1.4               3          0
# 6647          5.2               4          0
# 26145         1.6               4          0
# 60921         2.0               4          0
# 50094         1.0               0          0
# ...           ...             ...        ...
# 8195          1.5               0          0
# 46582         2.1               4          0
# 35087         2.0               1          0
# 71459         2.0               0          0
# 33600         1.2               1          0
#
# [108 rows x 11 columns]

# %%
#checking values higher than 2020 for test_data
test_data[test_data['year'] > 2020]
# Out:
#            Brand     model  year transmission  mileage fuelType    tax   mpg  \
# carID
# 89856    Hyundai       I30  2023    Automatic  30700.0   Petrol  205.0  41.5
# 101603      Opel    Zafira  2023       Manual  26856.0   Petrol  200.0  41.5
# 81259        BMW  4 Series  2024    Semi-Auto   7208.0   Diesel  145.0  65.7
# 81832        BMW        X5  2024    Automatic  47000.0   Diesel  200.0  47.1
# 100383      Opel   Mokka X  2023       Manual  19094.0   Petrol  145.0  39.2
# ...          ...       ...   ...          ...      ...      ...    ...   ...
# 94357   Mercedes   E Class  2024    Semi-Auto  48976.0   Diesel    NaN  57.7
# 106447        VW    Passat  2023    Semi-Auto   4801.0   Petrol  145.0  41.5
# 100025      Opel  Insignia  2023       Manual  19615.0   Diesel  125.0  60.1
# 76826       Audi        Q3  2024    Semi-Auto  35117.0   Diesel  160.0  50.4
# 103740      Opel     Astra  2023       Manual      NaN   Petrol  160.0  44.8
#
#         engineSize  previousOwners  hasDamage
# carID
# 89856          1.6               3          0
# 101603         1.4               2          0
# 81259          2.0               3          0
# 81832          3.0               2          0
# 100383         1.4            <NA>          0
# ...            ...             ...        ...
# 94357          2.1               3          0
# 106447         1.5               1          0
# 100025         2.0               0          0
# 76826          2.0               2          0
# 103740         1.6               3          0
#
# [180 rows x 11 columns]

# %% [markdown]
# - Since the dataset we are analysing is from 2020, it does not make sense to have years after 2020. Noting that the only years that appear in the dataset after 2020 are 2023 and 2024.
# - Therefore, we have decided to replace these years by missing values, assumming there was an error in the system. These years could be 2013 and 2014 instead.

# %%
#replacing years after 2020 by missing values 
X_train.loc[X_train["year"] > 2020, "year"] = np.nan
X_val.loc[X_val["year"] > 2020, "year"] = np.nan
test_data.loc[test_data["year"] > 2020, "year"] = np.nan

# %% [markdown]
# ### 4.5. Removing Duplicates

# %%
#checking duplicates again after handling incoherencies on X_train
int(X_train.duplicated().sum())
# Out:
# 364

# %%
#checking duplicates again after handling incoherencies on X_val
int(X_val.duplicated().sum())
# Out:
# 87

# %%
#droping duplicate rows of X_train and X_val
X_train = X_train.drop_duplicates()
X_val = X_val.drop_duplicates()

# %% [markdown]
# ### 4.6. Treating Outliers

# %%
#redifining metric features after not considering 'paintQuality%'
metric_features = ['year', 'mileage', 'tax', 'mpg',
                    'engineSize', 'previousOwners', 'hasDamage']

# %%
#checking outliers again after handling incoherencies on X_train
plot_multiple_boxplots(X_train, metric_features, title="Train Set: Numeric Variables' Box Plots")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[81], line 2
#       1 #checking outliers again after handling incoherencies on X_train
# ----> 2 plot_multiple_boxplots(X_train, metric_features, title="Train Set: Numeric Variables' Box Plots")
#
# NameError: name 'plot_multiple_boxplots' is not defined

# %%
#checking outliers again after handling incoherencies on X_train
plot_multiple_boxplots(X_val, metric_features, title="Train Set: Numeric Variables' Box Plots")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[82], line 2
#       1 #checking outliers again after handling incoherencies on X_train
# ----> 2 plot_multiple_boxplots(X_val, metric_features, title="Train Set: Numeric Variables' Box Plots")
#
# NameError: name 'plot_multiple_boxplots' is not defined

# %%
#checking outliers again after handling incoherencies on test_data
plot_multiple_boxplots(test_data, metric_features, title="Train Set: Numeric Variables' Box Plots")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[83], line 2
#       1 #checking outliers again after handling incoherencies on test_data
# ----> 2 plot_multiple_boxplots(test_data, metric_features, title="Train Set: Numeric Variables' Box Plots")
#
# NameError: name 'plot_multiple_boxplots' is not defined

# %% [markdown]
# **Year**

# %%
X_train[X_train['year'] < 1995]
# Out:
#           Brand    model  year transmission  mileage fuelType    tax   mpg  \
# carID
# 62732      Opel   Zafira  1970       Manual  37357.0      NaN  200.0  42.2
# 35769  Mercedes  M Class  1970    Automatic  14000.0   Diesel  305.0  39.2
#
#        engineSize  previousOwners  hasDamage
# carID
# 62732         NaN               2          0
# 35769         NaN               3          0

# %%
X_val[X_val['year'] < 1995]
# Out:
# Empty DataFrame
# Columns: [Brand, model, year, transmission, mileage, fuelType, tax, mpg, engineSize, previousOwners, hasDamage]
# Index: []

# %%
test_data[test_data['year'] < 1995]
# Out:
#           Brand    model  year transmission   mileage fuelType  tax  mpg  \
# carID
# 94627  Mercedes  C Class  1991    Automatic  170000.0   Petrol  NaN  NaN
#
#        engineSize  previousOwners  hasDamage
# carID
# 94627         3.0               4          0

# %%
#replacing years before 1995 by missing values for X_train and test_data
X_train.loc[X_train["year"] < 1995, "year"] = np.nan
test_data.loc[test_data["year"] < 1995, "year"] = np.nan

# %% [markdown]
# **Milage**

# %%
X_train[X_train['mileage'] > 150000]
# Out:
#           Brand         model  year transmission   mileage fuelType    tax  \
# carID
# 58385      Opel         Astra  2008       Manual  186500.0   Petrol  260.0
# 45553  Mercedes       C Class  2012    Automatic  170000.0   Diesel  145.0
# 7038       Audi            A3  2009       Manual  152034.0   Diesel  150.0
# 19562      Ford         Focus  2003       Manual  177644.0   Petrol  200.0
# 45795  Mercedes       C Class  2008    Automatic  170000.0   Diesel    NaN
# 67297        VW          Golf  2009       Manual  193000.0   Diesel  160.0
# 41580  Mercedes       C Class  2012    Automatic  170000.0   Diesel    NaN
# 4692       Audi            A6  2008       Manual  323000.0   Diesel  200.0
# 12289       BMW      3 Series  2010       Manual  156800.0   Diesel  125.0
# 50804     Skoda       Octavia  2015       Manual  175500.0   Diesel    0.0
# 67131        VW          Golf  2014       Manual  152420.0   Diesel   20.0
# 52908    Toyota       Avensis  2003       Manual  167054.0   Diesel  205.0
# 45662  Mercedes           CLK  2003    Automatic  185000.0   Petrol  330.0
# 36131  Mercedes       M Class  2004    Semi-Auto  165000.0   Petrol  330.0
# 41128  Mercedes       E Class  2014    Automatic  154000.0   Diesel   30.0
# 20862      Ford        Mondeo  2015       Manual  150890.0   Diesel   30.0
# 35216  Mercedes       C Class  <NA>    Automatic  173000.0   Petrol    NaN
# 69404        VW        Passat  2010       Manual  168000.0   Diesel  125.0
# 48912     Skoda       Octavia  <NA>    Automatic  241565.0   Diesel  185.0
# 53134    Toyota  Land Cruiser  2004    Automatic  160000.0   Diesel  325.0
# 38070       NaN       E Class  <NA>    Automatic  166086.0   Diesel   30.0
# 39946  Mercedes       A Class  2016          NaN  240494.0   Diesel   20.0
# 36409  Mercedes       C Class  2007    Automatic  160000.0   Diesel  290.0
# 46607  Mercedes       M Class  2010    Automatic  155876.0   Diesel  540.0
#
#         mpg  engineSize  previousOwners  hasDamage
# carID
# 58385  36.7         1.8               1          0
# 45553  54.3         2.1               4          0
# 7038   55.4         1.9               4          0
# 19562  41.5         1.6               2          0
# 45795   NaN         2.1               3          0
# 67297  52.3         2.0               3          0
# 41580   NaN         2.1               2          0
# 4692   44.1         2.0               1          0
# 12289  58.9         2.0               4          0
# 50804  74.3         1.6               2          0
# 67131  67.3         2.0               2          0
# 52908  48.7         2.0               4          0
# 45662  17.8         4.3               2          0
# 36131  20.0         NaN               2          0
# 41128  58.9         2.1               2          0
# 20862  65.7         2.0               4          0
# 35216   NaN         3.6               3          0
# 69404  60.1         2.0               0          0
# 48912  47.9         1.9               4          0
# 53134  31.4         3.0               1          0
# 38070  64.2         2.1               0          0
# 39946  68.9         2.1               4          0
# 36409  39.2         2.2               3          0
# 46607  32.5         3.0               0          0

# %%
X_val[X_val['mileage'] > 150000]
# Out:
#           Brand         model  year transmission   mileage fuelType    tax  \
# carID
# 48042     Skoda       Octavia  2010       Manual  250650.0   Diesel  125.0
# 74387        VW     Caravelle  2012          NaN  212000.0   Diesel  325.0
# 23427      Ford         Focus  2003       Manual  177644.0   Petrol    NaN
# 21764      Ford        Galaxy  2008       Manual  174000.0   Diesel  220.0
# 9978        BMW            X5  2012    Automatic  214000.0   Diesel  300.0
# 9808        BMW      3 Series  <NA>       Manual  162000.0   Diesel  205.0
# 45370  Mercedes       V Class  2010    Automatic  259000.0   Diesel  540.0
# 66971        VW          Golf  2010       Manual  164000.0   Diesel  145.0
# 46713  Mercedes       C Class  2007    Automatic  160000.0   Diesel    NaN
# 48382     Skoda       Octavia  2010       Manual  300000.0   Diesel  125.0
# 44013  Mercedes       C Class  2006    Automatic  153000.0   Petrol    NaN
# 51129    Toyota  Land Cruiser  2008    Automatic  174419.0   Diesel  565.0
# 10446       BMW      1 Series  2007       Manual  167000.0   Diesel  125.0
#
#         mpg  engineSize  previousOwners  hasDamage
# carID
# 48042  57.6         1.9               1          0
# 74387  34.4         2.0               2          0
# 23427   NaN         1.6               4          0
# 21764  44.8         1.8               4          0
# 9978   37.7         3.0               1          0
# 9808   49.6         2.0               0          0
# 45370  30.7         3.0               1          0
# 66971  58.9         2.0               2          0
# 46713   NaN         2.2               4          0
# 48382  57.6         1.9               2          0
# 44013   NaN         1.8               4          0
# 51129  31.4         3.0               0          0
# 10446  57.6         2.0               0          0

# %%
test_data[test_data['mileage'] > 150000]
# Out:
#            Brand      model  year transmission   mileage fuelType    tax  \
# carID
# 78147       Audi         Q5  2011       Manual  168017.0   Diesel  200.0
# 91517   Mercedes    C Class  2006    Automatic  153000.0   Petrol  300.0
# 102018      Opel      Astra  2001       Manual  159000.0   Petrol  235.0
# 81844        BMW   5 Series  2010    Automatic  164500.0   Diesel  140.0
# 94627   Mercedes    C Class  <NA>    Automatic  170000.0   Petrol    NaN
# 100290      Opel     Zafira  2013       Manual  279000.0   Diesel  150.0
# 80858        BMW   5 Series  2013    Automatic  178987.0   Hybrid  190.0
# 106256        VW  Caravelle  2006       Manual  178000.0   Diesel  325.0
# 80355        BMW   3 Series  2011       Manual  190000.0   Diesel   20.0
# 79846        BMW   3 Series  2014    Automatic  155790.0   Diesel  145.0
# 94225   Mercedes    E Class  2014    Automatic  152280.0   Diesel   30.0
# 106117       NaN     Passat  2011       Manual  176000.0   Diesel  125.0
# 86911       Ford     Mondeo  2011       Manual  151000.0   Diesel   30.0
# 108426        VW       Golf  2004       Manual  170000.0   Diesel  165.0
#
#               mpg  engineSize  previousOwners  hasDamage
# carID
# 78147    42.10000         2.0               0          0
# 91517    33.60000         1.8               3          0
# 102018   40.40000         1.6               4          0
# 81844    53.30000         2.0               3          0
# 94627         NaN         3.0               4          0
# 100290   55.40000         1.7               3          0
# 80858    40.40000         3.0               3          0
# 106256   34.40000         2.5               0          0
# 80355    68.90000         2.0               0          0
# 79846   151.04181         3.0               0          0
# 94225    58.90000         2.1               3          0
# 106117   60.10000         2.0               1       <NA>
# 86911    65.70000         1.6               4          0
# 108426   52.30000         NaN               4          0

# %%
#replacing mileages higher than 150000 by missing values
X_train.loc[X_train["mileage"] > 150000, "mileage"] = np.nan
X_val.loc[X_val["mileage"] > 150000, "mileage"] = np.nan
test_data.loc[test_data["mileage"] > 150000, "mileage"] = np.nan

# %% [markdown]
# **Tax**

# %%
X_train[X_train['tax'] < 50]
# Out:
#         Brand    model  year transmission  mileage fuelType   tax       mpg  \
# carID
# 74356      VW     Golf  2016    Semi-Auto  19432.0   Diesel  30.0  62.80000
# 75498      VW     Polo  2016    Semi-Auto   8695.0   Petrol  20.0  60.10000
# 51358  Toyota    Yaris  2017    Automatic  32994.0   Petrol  30.0  55.00000
# 2043     Audi       A1  2016    Semi-Auto  33435.0   Petrol  30.0  70.60000
# 166      Audi       A5  2014       Manual  30884.0   Diesel  30.0  60.10000
# ...       ...      ...   ...          ...      ...      ...   ...       ...
# 28583    Ford    B-MAX  2013       Manual  37058.0      NaN  30.0  27.70949
# 31202    Ford    Focus  2017       Manual  13000.0   Petrol  20.0  61.40000
# 2492     Audi       A4  2016    Automatic  28325.0   Diesel   0.0  72.40000
# 48672   Skoda  Octavia  2016    Semi-Auto  37296.0   Petrol  30.0  57.70000
# 6205     Audi       TT  2016          NaN  28402.0   Diesel  30.0  62.80000
#
#        engineSize  previousOwners  hasDamage
# carID
# 74356         2.0               3          0
# 75498         1.2               2          0
# 51358         1.3               2          0
# 2043          1.4               0          0
# 166           2.0               3          0
# ...           ...             ...        ...
# 28583         1.0               3          0
# 31202         1.0               4          0
# 2492          2.0               3          0
# 48672         1.4               3          0
# 6205          2.0               3          0
#
# [11018 rows x 11 columns]

# %% [markdown]
# - Since the number of cars with *tax* less than 100 is large, these we will not be changed.

# %%
#the same as 400
X_train[X_train['tax'] > 350]
# Out:
#           Brand         model  year transmission   mileage fuelType    tax  \
# carID
# 41531  Mercedes      SL CLASS  2016    Automatic    6200.0   Petrol  555.0
# 44516  Mercedes      SL CLASS  2010    Automatic   79000.0   Petrol  555.0
# 54636    Toyota  Land Cruiser  2006    Automatic  113000.0   Diesel  555.0
# 37494  Mercedes       M Class  2010    Automatic  128000.0   Diesel  555.0
# 52900    Toyota  Land Cruiser  2014    Automatic   60000.0   Diesel  540.0
# ...         ...           ...   ...          ...       ...      ...    ...
# 2116       Audi           RS6  2014    Automatic   59894.0   Petrol  555.0
# 56446      Opel        Antara  2007    Automatic   99500.0   Diesel  565.0
# 35606  Mercedes       M Class  2009    Automatic   59000.0   Diesel  555.0
# 46607  Mercedes       M Class  2010    Automatic  155876.0   Diesel  540.0
# 40610  Mercedes      GL Class  2007    Automatic   74000.0   Diesel  570.0
#
#         mpg  engineSize  previousOwners  hasDamage
# carID
# 41531  28.0         5.5               4       <NA>
# 44516  29.1         3.5               4          0
# 54636  31.4         3.0               0          0
# 37494  32.5         3.0               1          0
# 52900  29.7         4.5               1          0
# ...     ...         ...             ...        ...
# 2116   28.8         NaN               4          0
# 56446  32.8         2.0               3          0
# 35606  30.4         3.0               2          0
# 46607  32.5         3.0               0          0
# 40610  28.8         3.0               1          0
#
# [75 rows x 11 columns]

# %%
X_val[X_val['tax'] > 350]
# Out:
#           Brand         model  year transmission   mileage fuelType    tax  \
# carID
# 2522       Audi            Q7  2009    Automatic  136000.0      NaN  540.0
# 12995       BMW            M3  2013    Automatic   58125.0   Petrol  570.0
# 39852  Mercedes       S Class  2010    Automatic   38000.0   Petrol  570.0
# 921        Audi           RS6  2014    Automatic   58000.0   Petrol  555.0
# 41484  Mercedes       S Class  2016    Automatic   14000.0   Petrol  555.0
# 73570        VW       Touareg  2007    Automatic  122965.0   Diesel  580.0
# 45503  Mercedes      GL Class  2007    Automatic  104000.0   Diesel  570.0
# 39351       NaN     GLE Class  2015    Automatic   13212.0   Petrol  570.0
# 34980  Mercedes       S Class  2014    Automatic   26000.0   Petrol  555.0
# 14613       BMW            X5  2015    Semi-Auto   22103.0   Petrol  570.0
# 6752       Audi            R8  2014    Semi-Auto   19800.0   Petrol  570.0
# 37825  Mercedes       E Class  2008    Semi-Auto   55000.0   Petrol  570.0
# 24745      Ford       Mustang  2017    Semi-Auto   23179.0   Petrol  570.0
# 34814  Mercedes           SLK  2006    Automatic   75000.0   Petrol  555.0
# 14659       BMW            M3  <NA>       Manual   81000.0   Petrol  570.0
# 11113       BMW      3 Series  2006    Automatic   95000.0   Petrol  555.0
# 42643  Mercedes      SL CLASS  2015    Automatic   11000.0   Petrol  555.0
# 44623  Mercedes       M Class  2011    Automatic   69000.0   Diesel  555.0
# 12122       BMW            X6  2016    Semi-Auto   25684.0   Petrol  570.0
# 35612  Mercedes       C Class  2013    Automatic       NaN   Petrol  570.0
# 6094       Audi            R8  2008    Automatic   52500.0   Petrol  580.0
# 40793  Mercedes       M Class  2008    Automatic  110000.0   Diesel  555.0
# 2222       Audi           RS5  2014    Semi-Auto   39210.0   Petrol  555.0
# 45370  Mercedes       V Class  2010    Automatic  259000.0   Diesel  540.0
# 42125  Mercedes      CL Class  2008    Automatic   69000.0      NaN  570.0
# 45321  Mercedes       C Class  2014    Semi-Auto   19562.0   Petrol  570.0
# 715        Audi           RS4  2013          NaN   68000.0   Petrol  555.0
# 2354       Audi            R8  2015    Automatic   23924.0   Petrol  570.0
# 288        Audi           RS4  2013    Semi-Auto   28359.0   Petrol  565.0
# 60994      Opel        Zafira  2009       Manual   75914.0   Petrol  555.0
# 1150       Audi           RS4  2006       Manual   66000.0   Petrol  535.0
# 42435  Mercedes       M Class  2009    Automatic   86000.0   Diesel  555.0
# 6689       Audi            S8  2017    Automatic   22579.0   Petrol  555.0
# 41417  Mercedes       G Class  2015    Semi-Auto   34400.0   Diesel  570.0
# 21006      Ford          Kuga  2012    Automatic   69382.0   Petrol  555.0
# 14652       BMW            M5  2016    Semi-Auto   49689.0   Petrol  565.0
# 51129    Toyota  Land Cruiser  2008    Automatic  174419.0   Diesel  565.0
# 70293        VW       Touareg  2007    Automatic  105000.0   Diesel  570.0
# 12545       BMW            X5  2011    Automatic   46000.0   Petrol  570.0
# 34571   Hyundai      Santa Fe  2006       Manual   71000.0   Petrol  555.0
# 12393       BMW      5 Series  2016    Automatic   32000.0   Petrol  555.0
# 30357      Ford       Mustang  2016       Manual   12000.0   Petrol  570.0
# 46065  Mercedes       E Class  2015    Automatic   42422.0   Petrol  555.0
# 43941  Mercedes     GLE Class  2016    Semi-Auto   19466.0   Petrol  570.0
#
#         mpg  engineSize  previousOwners  hasDamage
# carID
# 2522   31.0         3.0               1          0
# 12995  25.2         4.0               3          0
# 39852  19.5         6.2               4          0
# 921    28.8         4.0               2          0
# 41484  28.0         5.5               4          0
# 73570  26.9         3.0               1          0
# 45503  28.8         3.0               2          0
# 39351  23.7         NaN               2          0
# 34980  28.0         5.5               1          0
# 14613  25.4         4.4               1          0
# 6752   22.8         4.2               3          0
# 37825  19.8         6.2               1          0
# 24745  23.5         5.0               1          0
# 34814  28.0         NaN               2          0
# 14659  22.8         4.0               2          0
# 11113  29.7         3.0               1          0
# 42643  28.5         5.5               6          0
# 44623  32.5         3.0               3          0
# 12122  25.4         4.4               0          0
# 35612  23.5         6.2               2          0
# 6094   21.0         4.2               4          0
# 40793  28.8         3.0            <NA>          0
# 2222   26.9         4.2               0          0
# 45370  30.7         3.0               1          0
# 42125  19.0         NaN               2          0
# 45321   NaN         6.2               4          0
# 715    26.4         4.2               2          0
# 2354   22.8         4.2               1          0
# 288    26.4         4.2               4          0
# 60994  29.4         2.0               4          0
# 1150   20.3         4.2               1          0
# 42435  30.4         3.0               4          0
# 6689   28.2         4.0               2          0
# 41417  25.2         3.0               2          0
# 21006  27.4         2.5               1          0
# 14652  28.5         4.4               3          0
# 51129  31.4         3.0               0          0
# 70293  26.9         NaN               1          0
# 12545  22.6         4.4               3          0
# 34571  28.8         2.4               2          0
# 12393  28.5         4.4               1          0
# 30357  20.9         5.0               3          0
# 46065  28.8         5.5               3          0
# 43941  23.9         5.5               3          0

# %%
test_data[test_data['tax'] > 350]
# Out:
#            Brand      model  year transmission        mileage fuelType    tax  \
# carID
# 95966   Mercedes    S Class  2011    Automatic   66000.000000   Petrol  570.0
# 94732   Mercedes    S Class  2015    Automatic   23156.000000   Petrol  555.0
# 80066        BMW         M6  2016    Semi-Auto   26642.000000   Petrol  555.0
# 79095       Audi         A8  2015    Automatic   30306.000000   Petrol  570.0
# 80790        BMW         M5  <NA>    Automatic   55241.000000   Petrol  555.0
# 79753        BMW         M5  2015    Semi-Auto   42932.000000   Petrol  555.0
# 78115       Audi         A8  2017    Automatic   16975.000000   Petrol  555.0
# 103312      Opel   Insignia  2012       Manual   48490.000000   Petrol  555.0
# 95550   Mercedes   SL CLASS  2016    Automatic   19425.000000      NaN  555.0
# 92738   Mercedes  CLS Class  2012    Automatic   46283.000000   Petrol  555.0
# 91008   Mercedes   GL Class  2014    Automatic   55000.000000   Petrol  570.0
# 81300        BMW         M5  2016    Semi-Auto   25780.000000   Petrol  565.0
# 95730   Mercedes   SL CLASS  2014    Semi-Auto   86705.854885   Petrol  565.0
# 95907   Mercedes  GLE Class  2015    Automatic   13340.000000   Petrol  570.0
# 78458       Audi        RS5  2015    Automatic   66000.000000   Petrol  555.0
# 76238       Audi         R8  2007    Automatic   39000.000000   Petrol  515.0
# 78064       Audi         R8  2016    Semi-Auto   10172.000000   Petrol  570.0
# 79951        BMW         M6  2016    Semi-Auto   19000.000000   Petrol  555.0
# 94338   Mercedes    C Class  2013    Semi-Auto   43442.000000   Petrol  580.0
# 79988        BMW         M5  2012    Automatic   51000.000000   Petrol  555.0
# 80032        BMW         M6  2015    Automatic            NaN   Petrol  555.0
# 80483        BMW   5 Series  2010    Automatic   55000.000000   Petrol  555.0
# 92442   Mercedes    M Class  2010    Automatic  106800.000000   Diesel  555.0
# 94467   Mercedes    R Class  2007    Automatic   60000.000000   Diesel  565.0
# 76412       Audi        RS6  2015    Automatic   28123.000000   Petrol  555.0
# 92966   Mercedes   SL CLASS  <NA>    Automatic   56098.000000   Petrol  555.0
# 87010       Ford       Kuga  2011       Manual   56000.000000   Petrol  555.0
# 95180   Mercedes    S Class  2016    Semi-Auto   25317.000000   Petrol  570.0
# 93937   Mercedes    S Class  2002    Automatic   24000.000000   Petrol  570.0
# 78926       Audi         Q7  <NA>    Semi-Auto   34000.000000   Diesel  555.0
# 81891        BMW         M3  2010       Manual   79000.000000   Petrol  570.0
# 79634        BMW         X3  2007    Automatic  100000.000000   Diesel  555.0
# 80874        BMW         M6  2015    Semi-Auto   34017.000000   Petrol  555.0
# 92367   Mercedes    E Class  2015    Automatic   40988.000000   Petrol  565.0
# 91988   Mercedes    M Class  2011    Automatic   90000.000000   Diesel  555.0
# 79665        BMW         M3  2013    Semi-Auto   30500.000000   Petrol  570.0
# 93078   Mercedes   SL CLASS  2010    Automatic   32450.000000   Petrol  540.0
# 77588       Audi        RS7  2014    Automatic   56000.000000   Petrol  555.0
# 92427   Mercedes        SLK  2006    Automatic   65000.000000   Petrol  565.0
# 82098        BMW         M6  2014          NaN   34000.000000   Petrol  565.0
# 79082       Audi        RS4  2014    Semi-Auto   58460.000000   Petrol  555.0
# 77758       Audi         TT  2007       Manual   63000.000000   Petrol  555.0
# 81467        BMW         M3  2009       Manual            NaN   Petrol  580.0
# 94134   Mercedes   SL CLASS  2007    Automatic   45000.000000   Petrol  570.0
# 93366   Mercedes    M Class  2015    Semi-Auto   43910.000000   Petrol  570.0
# 79044       Audi        RS4  2014    Semi-Auto            NaN   Petrol  555.0
# 86187       Ford      S-MAX  2008    Automatic  106000.000000   Petrol  555.0
# 92550   Mercedes    M Class  2011    Automatic   75000.000000   Diesel  555.0
# 79117       Audi         Q7  2008    Automatic   57000.000000   Diesel  570.0
# 92428   Mercedes    C Class  2006    Automatic   86705.854885   Petrol  565.0
# 81857        BMW         X6  2015    Semi-Auto   22032.000000   Petrol  570.0
# 81114        BMW   6 Series  2015    Automatic   38509.000000   Petrol  555.0
# 83203       Ford    Mustang  2016    Semi-Auto   26104.000000   Petrol  570.0
# 106055        VW    Touareg  2009    Automatic  111000.000000   Diesel  555.0
# 77033       Audi         TT  2007    Automatic   93392.000000   Petrol  565.0
#
#          mpg  engineSize  previousOwners  hasDamage
# carID
# 95966   24.6         3.2               0          0
# 94732   28.0         5.5               2          0
# 80066   28.5         NaN               1          0
# 79095   25.0         6.3               2          0
# 80790   28.5         4.4               3          0
# 79753   28.5         4.4               1          0
# 78115   28.2         4.0               0          0
# 103312  25.9         2.8               2          0
# 95550    NaN         5.5               0          0
# 92738   28.5         5.5               3          0
# 91008   23.0         5.5               4       <NA>
# 81300   28.5         4.4               2          0
# 95730   28.5         5.5               3          0
# 95907   23.9         5.5               0          0
# 78458   26.9         4.2               0          0
# 76238   21.0         4.2               0          0
# 78064   24.8         5.2               0          0
# 79951   27.4         4.4               3          0
# 94338   23.0         6.2               0          0
# 79988    NaN         4.4               2          0
# 80032   28.5         4.4               0          0
# 80483   27.2         4.4               0          0
# 92442   31.0         3.0               2          0
# 94467   30.4         3.0               3          0
# 76412   28.8         4.0               2          0
# 92966   29.1         NaN               2          0
# 87010   28.5         2.5               0          0
# 95180   24.1         6.0               3          0
# 93937   21.1         5.0               0          0
# 78926   28.5         4.1               3          0
# 81891   22.8         4.0               1          0
# 79634   32.8         3.0               1          0
# 80874   28.5         4.4               4          0
# 92367   29.1         5.5               2          0
# 91988   32.5         3.0               4          0
# 79665   24.6         4.0               0          0
# 93078   29.1         3.5               1          0
# 77588   28.8         4.0               3          0
# 92427   28.0         3.5               1          0
# 82098   28.5         4.4               4          0
# 79082   26.4         4.2               3          0
# 77758   27.2         3.2               0          0
# 81467   21.9         4.0               3          0
# 94134   23.3         5.0               3          0
# 93366   23.9         5.5               4          0
# 79044   26.4         4.2               4          0
# 86187   29.1         2.3               0          0
# 92550   31.0         3.0               3          0
# 79117   28.8         3.0               3          0
# 92428   28.2         3.5               0          0
# 81857   25.4         4.4               3          0
# 81114   28.5         4.4               2          0
# 83203   20.8         5.0               3          0
# 106055  28.5         3.0               4          0
# 77033   29.7         3.2               2          0

# %%
#replacing taxes higher than 350 by missing values
X_train.loc[X_train["tax"] > 350, "tax"] = np.nan
X_val.loc[X_val["tax"] > 350, "tax"] = np.nan
test_data.loc[test_data["tax"] > 350, "tax"] = np.nan

# %% [markdown]
# **Mpg**

# %%
X_train[X_train['mpg'] > 300]
# Out:
#       Brand model  year transmission  mileage fuelType    tax    mpg  \
# carID
# 11068   BMW    I3  2016          NaN  43695.0   Hybrid    0.0  470.8
# 14531   BMW    I3  2017    Automatic  36429.0   Hybrid    0.0  470.8
# 12332   BMW    I3  2015    Automatic  65800.0   Hybrid    0.0  470.8
# 9643    BMW    I3  2017    Automatic  20929.0   Hybrid  135.0  470.8
# 12640   BMW    I3  2017    Automatic  23956.0      NaN  135.0  470.8
# 12269   BMW    I3  2017    Automatic  26965.0   Hybrid  140.0  470.8
# 13378   BMW    I3  2015    Automatic   9886.0   Hybrid    0.0  470.8
# 11962   BMW    I3  2017    Automatic  21025.0   Hybrid    0.0  470.8
# 10327   BMW    I3  2014    Automatic  42479.0   Hybrid    0.0  470.8
# 11532   BMW    I3  2016    Automatic  35446.0   Hybrid    0.0  470.8
# 10695   BMW    I3  2017    Automatic      NaN   Hybrid  135.0  470.8
# 14512   BMW   NaN  2017    Automatic  23983.0   Hybrid    0.0  470.8
# 9737    BMW    I3  2014    Automatic  34539.0   Hybrid    0.0  470.8
# 9815    BMW    I3  2016    Automatic  20013.0      NaN    0.0  470.8
# 13430   BMW    I3  2017    Automatic  41146.0   Hybrid    0.0  470.8
# 12853   BMW    I3  2017    Automatic  10839.0   Hybrid    0.0  470.8
#
#        engineSize  previousOwners  hasDamage
# carID
# 11068         NaN               1          0
# 14531         NaN               2          0
# 12332         NaN               3          0
# 9643          NaN               2          0
# 12640         0.6               1          0
# 12269         NaN               3          0
# 13378         NaN               0          0
# 11962         NaN               0          0
# 10327         NaN               2          0
# 11532         NaN               3          0
# 10695         NaN               1          0
# 14512         NaN               4          0
# 9737          NaN               0          0
# 9815          NaN               0          0
# 13430         NaN               1          0
# 12853         NaN               4          0

# %%
X_val[X_val['mpg'] > 300]
# Out:
#       Brand model  year transmission  mileage fuelType  tax    mpg  \
# carID
# 11589   BMW    I3  2016    Automatic  25269.0      NaN  0.0  470.8
# 8497    BMW    I3  2017    Automatic  24041.0   Hybrid  0.0  470.8
# 12090   BMW    I3  2016    Automatic   8421.0   Hybrid  0.0  470.8
# 10967   BMW    I3  2016    Automatic  41063.0      NaN  0.0  470.8
# 8993    BMW    I3  2016    Automatic   9990.0      NaN  0.0  470.8
# 10133   BMW    I3  2017    Automatic      NaN      NaN  0.0  470.8
# 9196    BMW    I3  2016    Automatic  19995.0   Hybrid  0.0  470.8
# 13075   BMW    I3  2015    Automatic  33931.0   Hybrid  0.0  470.8
#
#        engineSize  previousOwners  hasDamage
# carID
# 11589         0.6               0          0
# 8497          NaN               3          0
# 12090         NaN               4          0
# 10967         0.6               6          0
# 8993          NaN               0          0
# 10133         0.6               4          0
# 9196          NaN               3          0
# 13075         NaN               4          0

# %%
test_data[test_data['mpg'] > 300]
# Out:
#       Brand model  year transmission  mileage fuelType    tax    mpg  \
# carID
# 80758   BMW    I3  2016    Automatic  59945.0   Hybrid    0.0  470.8
# 80669   BMW    I3  2017    Automatic  28169.0   Hybrid    0.0  470.8
# 80184   BMW    I3  2017    Automatic  41949.0   Hybrid  140.0  470.8
# 81032   BMW    I3  2017    Automatic  33021.0   Hybrid    0.0  470.8
# 79921   BMW    I3  2017    Automatic  50867.0      NaN  135.0  470.8
# 82073   BMW    I3  2015    Automatic  59000.0      NaN    0.0  470.8
# 80882   BMW    I3  2017    Automatic  10900.0   Hybrid  140.0  470.8
# 80277   BMW    I3  2017    Automatic  26139.0   Hybrid  135.0  470.8
# 79191   BMW    I3  2017    Automatic  17338.0   Hybrid  135.0  470.8
# 82186   BMW    I3  2017    Automatic   3976.0   Hybrid  135.0  470.8
# 81546   BMW    I3  2017    Automatic  22063.0   Hybrid    0.0  470.8
# 82309   BMW    I3  2014    Automatic  37161.0   Hybrid    0.0  470.8
# 81592   BMW    I3  2017    Automatic  20082.0   Hybrid  135.0  470.8
# 79991   BMW    I3  2015    Automatic  79830.0   Hybrid    0.0  470.8
# 81415   BMW    I3  2016    Automatic  68000.0   Hybrid    0.0  470.8
# 82238   BMW    I3  2017    Automatic  19178.0      NaN    0.0  470.8
#
#        engineSize  previousOwners  hasDamage
# carID
# 80758         NaN               3          0
# 80669         NaN               3          0
# 80184         NaN               4          0
# 81032         NaN               3          0
# 79921    0.600000               2          0
# 82073    0.600000               1          0
# 80882         NaN               2          0
# 80277         NaN               2          0
# 79191         NaN               0          0
# 82186         NaN               2          0
# 81546         NaN               3          0
# 82309         NaN               1          0
# 81592         NaN               4          0
# 79991         NaN               4          0
# 81415    3.822758               4          0
# 82238    0.600000               0          0

# %% [markdown]
# - All mpg > 300 are from BMW I3 and they all have the same mpg.

# %%
#replacing mpg higher than 300 by missing values
X_train.loc[X_train["mpg"] > 300, "mpg"] = np.nan
X_val.loc[X_val["mpg"] > 300, "mpg"] = np.nan
test_data.loc[test_data["mpg"] > 300, "mpg"] = np.nan

# %% [markdown]
# **EngineSize**

# %%
X_train[X_train['engineSize'] > 5]
# Out:
#           Brand      model  year transmission  mileage fuelType         tax  \
# carID
# 41531  Mercedes   SL CLASS  2016    Automatic   6200.0   Petrol         NaN
# 35538       NaN    C Class  <NA>    Semi-Auto  49964.0   Petrol  326.028233
# 2487       Audi         R8  2019    Semi-Auto   7800.0   Petrol  145.000000
# 45626  Mercedes   SL CLASS  2016    Semi-Auto  21681.0   Petrol         NaN
# 37895  Mercedes  GLE Class  2019    Semi-Auto  11545.0   Petrol  145.000000
# 35290  Mercedes    C Class  2014    Automatic  56444.0   Petrol         NaN
# 39752  Mercedes    C Class  2014    Automatic  56444.0   Petrol         NaN
# 2022       Audi         R8  2019    Automatic   8175.0   Petrol  145.000000
# 40976  Mercedes  GLE Class  2019    Semi-Auto      9.0   Petrol  145.000000
# 46064  Mercedes  GLE Class  2017    Semi-Auto   6000.0   Petrol  145.000000
# 43741  Mercedes   SL CLASS  2019    Automatic    105.0   Petrol  145.000000
# 1697        NaN         R8  2014    Automatic  35000.0   Petrol         NaN
# 2736       Audi         R8  2019    Semi-Auto    500.0   Petrol  145.000000
# 44412  Mercedes   SL CLASS  2019    Automatic     10.0   Petrol  145.000000
# 2743       Audi         R8  2018    Semi-Auto   3800.0   Petrol  145.000000
# 45353  Mercedes   CL Class  2002    Automatic  77000.0   Petrol  325.000000
# 5953       Audi         R8  2019    Semi-Auto     10.0   Petrol  150.000000
# 35117  Mercedes    C Class  2013    Automatic  39000.0   Petrol         NaN
# 37660  Mercedes   SL CLASS  2019    Semi-Auto   1776.0   Petrol  145.000000
# 38953  Mercedes  GLE Class  2018    Automatic   5234.0   Petrol  145.000000
# 39737  Mercedes    M Class  2014    Semi-Auto  33271.0   Petrol         NaN
# 3167       Audi         A6  2006    Automatic  98000.0   Petrol         NaN
# 44937  Mercedes    C Class  2013    Automatic  41866.0   Petrol         NaN
# 42286  Mercedes    C Class  2014    Semi-Auto  24175.0   Petrol         NaN
# 38980  Mercedes    C Class  2013    Semi-Auto  43442.0   Petrol         NaN
# 35970  Mercedes    G Class  2015    Semi-Auto  10000.0   Petrol         NaN
# 44315  Mercedes  GLE Class  2019    Automatic   3574.0   Petrol  145.000000
# 5324       Audi         R8  2019    Automatic   3000.0   Petrol  145.000000
# 35674  Mercedes   SL CLASS  2019    Automatic    221.0   Petrol  145.000000
# 44794  Mercedes    C Class  2014    Semi-Auto  37000.0   Petrol         NaN
# 46536  Mercedes    C Class  2013    Automatic  44000.0   Petrol         NaN
# 46012  Mercedes   SL CLASS  2011    Automatic   3000.0   Petrol         NaN
# 39725  Mercedes  GLE Class  2017    Semi-Auto  23000.0   Petrol  145.000000
# 35305  Mercedes    S Class  2016          NaN  19953.0   Petrol         NaN
# 4111       Audi         R8  2014    Automatic  31930.0   Petrol         NaN
# 1950       Audi         R8  2019    Automatic   1000.0   Petrol  145.000000
# 46040  Mercedes  GLS Class  2017    Automatic  45239.0   Petrol  150.000000
# 43725  Mercedes    C Class  2014    Semi-Auto  24175.0   Petrol         NaN
# 40664  Mercedes    E Class  2015    Automatic  83079.0   Petrol         NaN
# 9197        BMW   7 Series  2017    Automatic  11297.0   Petrol  145.000000
# 2020       Audi         R8  2016    Automatic  28888.0   Petrol         NaN
# 2424       Audi         R8  2019    Automatic    100.0   Petrol  145.000000
# 35098  Mercedes    C Class  2005    Automatic  73000.0   Petrol         NaN
# 40094  Mercedes    C Class  2013    Automatic  39000.0   Petrol         NaN
# 36394  Mercedes   SL CLASS  2019    Automatic     50.0   Petrol  145.000000
#
#         mpg  engineSize  previousOwners  hasDamage
# carID
# 41531  28.0         5.5               4       <NA>
# 35538   NaN         6.2               3          0
# 2487   21.4         5.2               4          0
# 45626  28.0         5.5               1          0
# 37895  23.9         5.5               2          0
# 35290  23.5         6.2               0          0
# 39752   NaN         6.2               3          0
# 2022   21.6         5.2               4          0
# 40976  23.7         5.5               1          0
# 46064  23.9         5.5               3          0
# 43741  28.0         5.5               0          0
# 1697   21.9         5.2               2          0
# 2736   21.4         5.2               4          0
# 44412  28.0         5.5               4          0
# 2743   23.0         5.2               3          0
# 45353  21.1         5.4            <NA>          0
# 5953   21.4         5.2               1          0
# 35117  23.5         6.2               1          0
# 37660  28.0         5.5               0          0
# 38953  23.9         5.5               0          0
# 39737  23.9         5.5               2          0
# 3167   21.1         5.2               0          0
# 44937  23.5         6.2               0          0
# 42286   NaN         6.2               2          0
# 38980   NaN         6.2               0          0
# 35970  20.5         5.5               3          0
# 44315  23.7         5.5               3          0
# 5324   21.4         5.2               2          0
# 35674  28.0         5.5               3          0
# 44794  23.5         6.2               2          0
# 46536   NaN         6.2               2          0
# 46012  21.4         6.2               4          0
# 39725  23.9         5.5               1          0
# 35305  28.0         5.5               2          0
# 4111   21.9         5.2               1          0
# 1950   32.8         5.2               1          0
# 46040  23.0         5.5               4          0
# 43725  23.5         6.2               1          0
# 40664  28.8         5.5               1          0
# 9197   22.1         6.6               1          0
# 2020   24.1         5.2               3          0
# 2424   24.1         5.2               2          0
# 35098   NaN         5.4               2          0
# 40094   NaN         6.2               1          0
# 36394  28.0         5.5               0          0

# %%
X_val[X_val['engineSize'] > 5]
# Out:
#           Brand      model  year transmission       mileage fuelType    tax  \
# carID
# 6647       Audi         R8  <NA>    Semi-Auto   4000.000000   Petrol  145.0
# 44293  Mercedes    S Class  1998    Automatic  43534.000000   Petrol    NaN
# 44376  Mercedes   SL CLASS  2019    Semi-Auto   3728.000000   Petrol  145.0
# 39852  Mercedes    S Class  2010    Automatic  38000.000000   Petrol    NaN
# 46372  Mercedes    C Class  2013    Semi-Auto  49964.000000   Petrol    NaN
# 41484  Mercedes    S Class  2016    Automatic  14000.000000   Petrol    NaN
# 46668  Mercedes  GLE Class  2017    Automatic   7000.000000   Petrol  145.0
# 34980  Mercedes    S Class  2014    Automatic  26000.000000   Petrol    NaN
# 36076  Mercedes   SL CLASS  2017    Semi-Auto           NaN   Petrol  145.0
# 7208       Audi         R8  2020    Semi-Auto     70.000000   Petrol  145.0
# 37825  Mercedes    E Class  2008    Semi-Auto  55000.000000   Petrol    NaN
# 41767  Mercedes   SL CLASS  2019    Automatic    540.000000   Petrol  145.0
# 40609  Mercedes  GLS Class  2018    Automatic   7390.000000   Petrol  150.0
# 42643  Mercedes   SL CLASS  2015    Automatic  11000.000000   Petrol    NaN
# 36196  Mercedes    C Class  2014    Semi-Auto  86705.854885   Petrol    NaN
# 35612  Mercedes    C Class  2013    Automatic           NaN   Petrol    NaN
# 42778  Mercedes  GLE Class  2018    Automatic  16592.000000   Petrol  145.0
# 39900  Mercedes    C Class  2014    Semi-Auto  19562.000000   Petrol    NaN
# 766        Audi         R8  2020    Semi-Auto   2000.000000   Petrol  145.0
# 36551  Mercedes  GLE Class  2019    Semi-Auto   1493.000000   Petrol  145.0
# 45321  Mercedes    C Class  2014    Semi-Auto  19562.000000   Petrol    NaN
# 4710       Audi         R8  2019          NaN   6954.000000   Petrol  145.0
# 36282  Mercedes        NaN  2017    Automatic  38247.000000   Petrol  145.0
# 3755       Audi         R8  2018    Automatic   5044.000000   Petrol  150.0
# 46065  Mercedes    E Class  2015    Automatic  42422.000000   Petrol    NaN
# 43941  Mercedes  GLE Class  2016    Semi-Auto  19466.000000   Petrol    NaN
#
#         mpg  engineSize  previousOwners  hasDamage
# carID
# 6647   21.4         5.2               4          0
# 44293  23.3         6.0               2          0
# 44376  28.0         5.5               1          0
# 39852  19.5         6.2               4          0
# 46372  23.0         6.2               3          0
# 41484  28.0         5.5               4          0
# 46668  29.5         5.5               3          0
# 34980  28.0         5.5               1          0
# 36076  28.0         5.5               0          0
# 7208   21.1         5.2               0          0
# 37825  19.8         6.2               1          0
# 41767  28.0         5.5               1          0
# 40609  23.0         5.5               4          0
# 42643  28.5         5.5               6          0
# 36196   NaN         6.2               0          0
# 35612  23.5         6.2               2          0
# 42778  23.7         5.5               4          0
# 39900   NaN         6.2               0          0
# 766    21.1         5.2               4          0
# 36551  23.7         5.5               0          0
# 45321   NaN         6.2               4          0
# 4710   21.6         5.2               2          0
# 36282  20.5         5.5            <NA>          0
# 3755   23.0         5.2               4          0
# 46065  28.8         5.5               3          0
# 43941  23.9         5.5               3          0

# %%
test_data[test_data['engineSize'] > 5]
# Out:
#           Brand      model  year transmission       mileage fuelType    tax  \
# carID
# 94732  Mercedes    S Class  2015    Automatic  23156.000000   Petrol    NaN
# 79095      Audi         A8  2015    Automatic  30306.000000   Petrol    NaN
# 95550  Mercedes   SL CLASS  2016    Automatic  19425.000000      NaN    NaN
# 92738  Mercedes  CLS Class  2012    Automatic  46283.000000   Petrol    NaN
# 91008  Mercedes   GL Class  2014    Automatic  55000.000000   Petrol    NaN
# 76804      Audi         R8  2020    Semi-Auto    333.000000   Petrol  145.0
# 94754  Mercedes    C Class  2013    Automatic  41866.000000   Petrol    NaN
# 77563      Audi         R8  2019    Automatic  11936.000000   Petrol  145.0
# 95730  Mercedes   SL CLASS  2014    Semi-Auto  86705.854885   Petrol    NaN
# 95907  Mercedes  GLE Class  2015    Automatic  13340.000000   Petrol    NaN
# 93551  Mercedes  GLE Class  2019    Automatic   2704.000000   Petrol  145.0
# 78064      Audi         R8  2016    Semi-Auto  10172.000000   Petrol    NaN
# 94338  Mercedes    C Class  2013    Semi-Auto  43442.000000   Petrol    NaN
# 92587  Mercedes   SL CLASS  2019    Automatic    150.000000   Petrol  145.0
# 77682      Audi         R8  2019    Automatic           NaN   Petrol  150.0
# 91924  Mercedes    C Class  2006    Automatic  63000.000000   Petrol    NaN
# 95180  Mercedes    S Class  2016    Semi-Auto  25317.000000   Petrol    NaN
# 92367  Mercedes    E Class  2015    Automatic  40988.000000   Petrol    NaN
# 93716  Mercedes    S Class  2017    Semi-Auto  15400.000000   Petrol  145.0
# 76838      Audi         R8  2019    Automatic   2369.000000   Petrol  145.0
# 93123  Mercedes  GLS Class  2018    Semi-Auto  41102.000000   Petrol  145.0
# 81532       BMW   7 Series  2017    Automatic  22000.000000   Petrol  150.0
# 93366  Mercedes    M Class  2015    Semi-Auto  43910.000000   Petrol    NaN
# 76653      Audi         R8  2018    Automatic   3562.000000   Petrol  145.0
#
#         mpg  engineSize  previousOwners  hasDamage
# carID
# 94732  28.0         5.5               2          0
# 79095  25.0         6.3               2          0
# 95550   NaN         5.5               0          0
# 92738  28.5         5.5               3          0
# 91008  23.0         5.5               4       <NA>
# 76804  21.4         5.2               1          0
# 94754   NaN         6.2               1          0
# 77563  21.4         5.2               0          0
# 95730  28.5         5.5               3          0
# 95907  23.9         5.5               0          0
# 93551  23.7         5.5               3          0
# 78064  24.8         5.2               0          0
# 94338  23.0         6.2               0          0
# 92587  28.0         5.5               3          0
# 77682  21.4         5.2               1          0
# 91924   NaN         5.4               2          0
# 95180  24.1         6.0               3          0
# 92367  29.1         5.5               2          0
# 93716  28.0         5.5               3          0
# 76838  22.6         5.2               0          0
# 93123  23.0         5.5               0          0
# 81532  22.1         6.6               0          0
# 93366  23.9         5.5               4          0
# 76653  23.0         5.2               4          0

# %%
#replacing mileages higher than 150000 by missing values
X_train.loc[X_train["engineSize"] > 5, "engineSize"] = np.nan
X_val.loc[X_val["engineSize"] > 5, "engineSize"] = np.nan
test_data.loc[test_data["engineSize"] > 5, "engineSize"] = np.nan

# %% [markdown]
# ### 4.7. Treating Missing Values

# %% [markdown]
# #### 4.7.1. Interative Imputer

# %% [markdown]
# - Here, we want to fill the missing values of each car taking into account its *brand* and *model*. Therefore, we are going to encode these variables to transform them into numerical.
# - Moreover, we transform the rest of the categoreical variables (transmission and fuelType) into numerical through get dummies, in order to fill them as well along with the other and using KNN inputer.

# %%
X_train.isna().sum().sort_values(ascending=False)
# Out:
# tax               5733
# mpg               5434
# transmission      1637
# engineSize        1495
# year              1300
# mileage           1224
# model             1175
# fuelType          1142
# hasDamage         1094
# previousOwners    1091
# Brand             1053
# dtype: int64

# %%
X_val.isna().sum().sort_values(ascending=False)
# Out:
# tax               2539
# mpg               2424
# transmission       626
# engineSize         607
# mileage            552
# year               548
# fuelType           536
# model              529
# Brand              468
# previousOwners     459
# hasDamage          454
# dtype: int64

# %%
test_data.isna().sum().sort_values(ascending=False)
# Out:
# tax               3524
# mpg               3321
# transmission       971
# engineSize         878
# mileage            859
# year               833
# fuelType           738
# model              713
# Brand              649
# previousOwners     597
# hasDamage          597
# dtype: int64

# %%
import pandas as pd
from sklearn.preprocessing import OrdinalEncoder, StandardScaler
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer
from sklearn.ensemble import ExtraTreesRegressor, ExtraTreesClassifier
from sklearn.neural_network import MLPRegressor

# %% [markdown]
# ##### 4.7.1.1. Numerical Variables

# %%
#Define the columns
num_cols = ['mileage', 'mpg', 'tax', 'engineSize', 'previousOwners', 'year']
cat_cols = ['fuelType', 'transmission', 'hasDamage','Brand', 'model']
impute_features = num_cols + cat_cols

# %%
#TEMPORARY Ordinal Encoding (only for imputation of missing values)
#since interactive imputer does not require scalling we can use ordinal encoding
ordinal_encoder = OrdinalEncoder(handle_unknown="use_encoded_value", unknown_value=-1)
X_train_enc = X_train.copy()
X_val_enc = X_val.copy()
test_data_enc = test_data.copy()

# Encode categorical variables temporarily
X_train_enc[cat_cols] = ordinal_encoder.fit_transform(X_train[cat_cols])
X_val_enc[cat_cols] = ordinal_encoder.transform(X_val[cat_cols])
test_data_enc[cat_cols] = ordinal_encoder.transform(test_data[cat_cols])

# %%
#checking if X_train and y_train have the same number of rows
print("X_train shape:", X_train.shape)
print("y_train shape:", y_train.shape)
# Out:
# X_train shape: (52817, 11)
# y_train shape: (53181,)

# %%
#Numerical imputation using ExtraTreesRegressor

num_imputer_ETR = ExtraTreesRegressor(
    n_estimators=80,                                      
    max_depth=12,
    min_samples_leaf=2,
    max_features=None,
    n_jobs=-1,
    random_state=42
)

num_imputer = IterativeImputer(
    estimator=num_imputer_ETR,
    max_iter=12,
    initial_strategy='median',
    imputation_order='ascending',
    skip_complete=True,
    random_state=42
)

# Fit on training (using all predictors) and transform train/val/test
train_num_imputed = num_imputer.fit_transform(X_train_enc[impute_features])
val_num_imputed   = num_imputer.transform(X_val_enc[impute_features])
test_num_imputed  = num_imputer.transform(test_data_enc[impute_features])

# Returned arrays have columns in the same order as impute_features.
# Replace numeric columns (first len(num_cols)) in the DataFrames with the imputed numeric values:
X_train_enc[num_cols] = train_num_imputed[:, :len(num_cols)]
X_val_enc[num_cols]   = val_num_imputed[:, :len(num_cols)]
test_data_enc[num_cols]  = test_num_imputed[:, :len(num_cols)]
#here only the numerical variables are being imputed but we are taking into account the categorical features as well to fill them 

# Quick check:
print("Missing in numeric (train) after numeric imputation:\n", X_train_enc[num_cols].isna().sum())
print("Missing in numeric (val)   after numeric imputation:\n", X_val_enc[num_cols].isna().sum())
print("Missing in numeric (test)  after numeric imputation:\n", test_data_enc[num_cols].isna().sum())
# Out:
# c:\Users\Catarina\anaconda3\Lib\site-packages\sklearn\impute\_iterative.py:895: ConvergenceWarning: [IterativeImputer] Early stopping criterion not reached.
#   warnings.warn(
# Missing in numeric (train) after numeric imputation:
#  mileage           0
# mpg               0
# tax               0
# engineSize        0
# previousOwners    0
# year              0
# dtype: int64
# Missing in numeric (val)   after numeric imputation:
#  mileage           0
# mpg               0
# tax               0
# engineSize        0
# previousOwners    0
# year              0
# dtype: int64
# Missing in numeric (test)  after numeric imputation:
#  mileage           0
# mpg               0
# tax               0
# engineSize        0
# previousOwners    0
# year              0
# dtype: int64

# %% [markdown]
# ##### 4.7.1.2. Categorical Variables

# %%
#Categorical imputation using ExtraTreesClassifier

cat_imputer_ETC = ExtraTreesClassifier(
    n_estimators=80,
    max_depth=12,
    min_samples_leaf=2,
    max_features=None,
    n_jobs=-1, 
    random_state=42
)

cat_imputer = IterativeImputer(
    estimator=cat_imputer_ETC,
    max_iter=12,
    initial_strategy='most_frequent',
    imputation_order='ascending',
    skip_complete=True,
    random_state=42)

# Fit and transform categorical columns
X_train_imputed = cat_imputer.fit_transform(X_train_enc[impute_features])
X_val_imputed = cat_imputer.transform(X_val_enc[impute_features])
test_data_imputed = cat_imputer.transform(test_data_enc[impute_features])

# Convert the returned arrays to DataFrame with columns = impute_features so we can select by name
train_cat_df = pd.DataFrame(X_train_imputed, columns=impute_features, index=X_train_enc.index)
val_cat_df   = pd.DataFrame(X_val_imputed,   columns=impute_features, index=X_val_enc.index)
test_cat_df  = pd.DataFrame(test_data_imputed,  columns=impute_features, index=test_data_enc.index)

# Extract only the categorical columns (they remain in the same columns by name)
# Round and cast to int because classifier outputs were returned as floats by the imputer
train_cat_codes = train_cat_df[cat_cols].round().astype(int)
val_cat_codes   = val_cat_df[cat_cols].round().astype(int)
test_cat_codes  = test_cat_df[cat_cols].round().astype(int)

# Assign the imputed category codes back into the working DataFrames
X_train_enc[cat_cols] = train_cat_codes
X_val_enc[cat_cols]   = val_cat_codes
test_data_enc[cat_cols]  = test_cat_codes
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_12148\3569899414.py in ?()
#      17     skip_complete=True,
#      18     random_state=42)
#      19
#      20 # Fit and transform categorical columns
# ---> 21 X_train_imputed = cat_imputer.fit_transform(X_train_enc[impute_features])
#      22 X_val_imputed = cat_imputer.transform(X_val_enc[impute_features])
#      23 test_data_imputed = cat_imputer.transform(test_data_enc[impute_features])
#      24
#
# c:\Users\Catarina\anaconda3\Lib\site-packages\sklearn\utils\_set_output.py in ?(self, X, *args, **kwargs)
#     317     @wraps(f)
#     318     def wrapped(self, X, *args, **kwargs):
# --> 319         data_to_wrap = f(self, X, *args, **kwargs)
#     320         if isinstance(data_to_wrap, tuple):
#     321             # only wrap the first output for cross decomposition
#     322             return_tuple = (
#
# c:\Users\Catarina\anaconda3\Lib\site-packages\sklearn\base.py in ?(estimator, *args, **kwargs)
#    1385                 skip_parameter_validation=(
#    1386                     prefer_skip_nested_validation or global_skip_validation
#    1387                 )
#    1388             ):
# -> 1389                 return fit_method(estimator, *args, **kwargs)
#
# c:\Users\Catarina\anaconda3\Lib\site-packages\sklearn\impute\_iterative.py in ?(self, X, y, **params)
#     797         self.imputation_sequence_ = []
#     798
#     799         self.initial_imputer_ = None
#     800
# --> 801         X, Xt, mask_missing_values, complete_mask = self._initial_imputation(
#     802             X, in_fit=True
#     803         )
#     804
#
# c:\Users\Catarina\anaconda3\Lib\site-packages\sklearn\impute\_iterative.py in ?(self, X, in_fit)
#     623             ensure_all_finite = "allow-nan"
#     624         else:
#     625             ensure_all_finite = True
#     626
# --> 627         X = validate_data(
#     628             self,
#     629             X,
#     630             dtype=FLOAT_DTYPES,
#
# c:\Users\Catarina\anaconda3\Lib\site-packages\sklearn\utils\validation.py in ?(_estimator, X, y, reset, validate_separately, skip_check_array, **check_params)
#    2940             out = y
#    2941         else:
#    2942             out = X, y
#    2943     elif not no_val_X and no_val_y:
# -> 2944         out = check_array(X, input_name="X", **check_params)
#    2945     elif no_val_X and not no_val_y:
#    2946         out = _check_y(y, **check_params)
#    2947     else:
#
# c:\Users\Catarina\anaconda3\Lib\site-packages\sklearn\utils\validation.py in ?(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_writeable, force_all_finite, ensure_all_finite, ensure_non_negative, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#    1052                         )
#    1053                     array = xp.astype(array, dtype, copy=False)
#    1054                 else:
#    1055                     array = _asarray_with_order(array, order=order, dtype=dtype, xp=xp)
# -> 1056             except ComplexWarning as complex_warning:
#    1057                 raise ValueError(
#    1058                     "Complex data not supported\n{}\n".format(array)
#    1059                 ) from complex_warning
#
# c:\Users\Catarina\anaconda3\Lib\site-packages\sklearn\utils\_array_api.py in ?(array, dtype, order, copy, xp, device)
#     835         # Use NumPy API to support order
#     836         if copy is True:
#     837             array = numpy.array(array, order=order, dtype=dtype)
#     838         else:
# --> 839             array = numpy.asarray(array, order=order, dtype=dtype)
#     840
#     841         # At this point array is a NumPy ndarray. We convert it to an array
#     842         # container that is consistent with the input's namespace.
#
# c:\Users\Catarina\anaconda3\Lib\site-packages\pandas\core\generic.py in ?(self, dtype, copy)
#    2149     def __array__(
#    2150         self, dtype: npt.DTypeLike | None = None, copy: bool_t | None = None
#    2151     ) -> np.ndarray:
#    2152         values = self._values
# -> 2153         arr = np.asarray(values, dtype=dtype)
#    2154         if (
#    2155             astype_is_view(values.dtype, arr.dtype)
#    2156             and using_copy_on_write()
#
# ValueError: could not convert string to float: 'Diesel'

# %%
print("Total missing values in training dataset after imputations:")
print(X_train_enc.isna().sum().sort_values(ascending=False))
print("Total missing values in validation dataset after imputations:")
print(X_val_enc.isna().sum().sort_values(ascending=False))
print("Total missing values in test dataset after imputations:")
print(test_data_enc.isna().sum().sort_values(ascending=False))
# Out:
# Total missing values in training dataset after imputations:
# Brand             0
# model             0
# year              0
# transmission      0
# mileage           0
# fuelType          0
# tax               0
# mpg               0
# engineSize        0
# previousOwners    0
# hasDamage         0
# dtype: int64
# Total missing values in validation dataset after imputations:
# Brand             0
# model             0
# year              0
# transmission      0
# mileage           0
# fuelType          0
# tax               0
# mpg               0
# engineSize        0
# previousOwners    0
# hasDamage         0
# dtype: int64
# Total missing values in test dataset after imputations:
# Brand             0
# model             0
# year              0
# transmission      0
# mileage           0
# fuelType          0
# tax               0
# mpg               0
# engineSize        0
# previousOwners    0
# hasDamage         0
# dtype: int64

# %%
# Map back to original categories
X_train_enc[cat_cols] = ordinal_encoder.inverse_transform(X_train_enc[cat_cols])
X_val_enc[cat_cols] = ordinal_encoder.inverse_transform(X_val_enc[cat_cols])
test_data_enc[cat_cols] = ordinal_encoder.inverse_transform(test_data_enc[cat_cols])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_12148\2207097935.py in ?()
#       1 # Map back to original categories
# ----> 2 X_train_enc[cat_cols] = ordinal_encoder.inverse_transform(X_train_enc[cat_cols])
#       3 X_val_enc[cat_cols] = ordinal_encoder.inverse_transform(X_val_enc[cat_cols])
#       4 test_data_enc[cat_cols] = ordinal_encoder.inverse_transform(test_data_enc[cat_cols])
#
# c:\Users\Catarina\anaconda3\Lib\site-packages\sklearn\preprocessing\_encoders.py in ?(self, X)
#    1625         X_tr : ndarray of shape (n_samples, n_features)
#    1626             Inverse transformed array.
#    1627         """
#    1628         check_is_fitted(self)
# -> 1629         X = check_array(X, ensure_all_finite="allow-nan")
#    1630
#    1631         n_samples, _ = X.shape
#    1632         n_features = len(self.categories_)
#
# c:\Users\Catarina\anaconda3\Lib\site-packages\sklearn\utils\validation.py in ?(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_writeable, force_all_finite, ensure_all_finite, ensure_non_negative, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#    1052                         )
#    1053                     array = xp.astype(array, dtype, copy=False)
#    1054                 else:
#    1055                     array = _asarray_with_order(array, order=order, dtype=dtype, xp=xp)
# -> 1056             except ComplexWarning as complex_warning:
#    1057                 raise ValueError(
#    1058                     "Complex data not supported\n{}\n".format(array)
#    1059                 ) from complex_warning
#
# c:\Users\Catarina\anaconda3\Lib\site-packages\sklearn\utils\_array_api.py in ?(array, dtype, order, copy, xp, device)
#     835         # Use NumPy API to support order
#     836         if copy is True:
#     837             array = numpy.array(array, order=order, dtype=dtype)
#     838         else:
# --> 839             array = numpy.asarray(array, order=order, dtype=dtype)
#     840
#     841         # At this point array is a NumPy ndarray. We convert it to an array
#     842         # container that is consistent with the input's namespace.
#
# c:\Users\Catarina\anaconda3\Lib\site-packages\pandas\core\generic.py in ?(self, dtype, copy)
#    2149     def __array__(
#    2150         self, dtype: npt.DTypeLike | None = None, copy: bool_t | None = None
#    2151     ) -> np.ndarray:
#    2152         values = self._values
# -> 2153         arr = np.asarray(values, dtype=dtype)
#    2154         if (
#    2155             astype_is_view(values.dtype, arr.dtype)
#    2156             and using_copy_on_write()
#
# ValueError: could not convert string to float: 'Diesel'

# %% [markdown]
# - Since we fit the train dataset and transform the validation and test dataset, there is the possibility of the validation and test dataset still have missing values after the interactive imputer because there are categories in *model* that never appeared in the training set so the imputer cannot impute them and leaves them as missing.
# - Therefore, we have decided to fill these missing values with the mode. We have considered this option because the quantity of missing values left to fill is reduced (4 for validation and 16 for test).

# %%
print("Total missing values in training dataset after imputations:")
print(X_train_enc.isna().sum().sort_values(ascending=False))
print("Total missing values in validation dataset after imputations:")
print(X_val_enc.isna().sum().sort_values(ascending=False))
print("Total missing values in test dataset after imputations:")
print(test_data_enc.isna().sum().sort_values(ascending=False))
# Out:
# Total missing values in training dataset after imputations:
# Brand             0
# model             0
# year              0
# transmission      0
# mileage           0
# fuelType          0
# tax               0
# mpg               0
# engineSize        0
# previousOwners    0
# hasDamage         0
# dtype: int64
# Total missing values in validation dataset after imputations:
# Brand             0
# model             0
# year              0
# transmission      0
# mileage           0
# fuelType          0
# tax               0
# mpg               0
# engineSize        0
# previousOwners    0
# hasDamage         0
# dtype: int64
# Total missing values in test dataset after imputations:
# Brand             0
# model             0
# year              0
# transmission      0
# mileage           0
# fuelType          0
# tax               0
# mpg               0
# engineSize        0
# previousOwners    0
# hasDamage         0
# dtype: int64

# %%
# ---------- 6) FINAL FALLBACK: fill any remaining NaNs in VAL/TEST using TRAIN stats (no leakage) ----------
# For each column that still has NaNs in val/test, fill with training median (numeric) or training mode (categorical)
for col in X_train_enc.columns:
    # validation
    if X_val_enc[col].isna().sum() > 0:
        if col in num_cols:
            fillval = X_train_enc[col].median()
        else:
            fillval = X_train_enc[col].mode()[0]
        X_val_enc[col] = X_val_enc[col].fillna(fillval)
    # test
    if test_data_enc[col].isna().sum() > 0:
        if col in num_cols:
            fillval = X_train_enc[col].median()
        else:
            fillval = X_train_enc[col].mode()[0]
        test_data_enc[col] = test_data_enc[col].fillna(fillval)

# %%
print("Total missing values in training dataset after imputations:")
print(X_train_enc.isna().sum().sort_values(ascending=False))
print("Total missing values in validation dataset after imputations:")
print(X_val_enc.isna().sum().sort_values(ascending=False))
print("Total missing values in test dataset after imputations:")
print(test_data_enc.isna().sum().sort_values(ascending=False))
# Out:
# Total missing values in training dataset after imputations:
# Brand             0
# model             0
# year              0
# transmission      0
# mileage           0
# fuelType          0
# tax               0
# mpg               0
# engineSize        0
# previousOwners    0
# hasDamage         0
# dtype: int64
# Total missing values in validation dataset after imputations:
# Brand             0
# model             0
# year              0
# transmission      0
# mileage           0
# fuelType          0
# tax               0
# mpg               0
# engineSize        0
# previousOwners    0
# hasDamage         0
# dtype: int64
# Total missing values in test dataset after imputations:
# Brand             0
# model             0
# year              0
# transmission      0
# mileage           0
# fuelType          0
# tax               0
# mpg               0
# engineSize        0
# previousOwners    0
# hasDamage         0
# dtype: int64

# %%
X_train = X_train_enc
X_val = X_val_enc
test_data = test_data_enc

# %% [markdown]
# **Links:**
# - https://scikit-learn.org/stable/modules/generated/sklearn.impute.IterativeImputer.html
# - https://chatgpt.com/share/692cad70-3fdc-8007-a212-ca8d1e5c714a

# %% [markdown]
# ### 4.8. Feature Engineering

# %% [markdown]
# #### 4.8.1. Creating New Variables

# %%
X_train['engineEfficiency'] = X_train['mpg'] / X_train['engineSize']
X_val['engineEfficiency'] = X_val['mpg'] / X_val['engineSize']
test_data['engineEfficiency'] = test_data['mpg'] / test_data['engineSize']

# %% [markdown]
# #### 4.8.2. Encoding Categorical Features

# %% [markdown]
# - Frequency encoding is used to transform the variables Brand and model into numerical, as these have a high cardinality, while transmission and fuelType was transformed into dummy variables.

# %%
freq_encoding_brand = X_train['Brand'].value_counts()
mean_freq_brand = freq_encoding_brand.mean()
X_train['brand_encoded'] = X_train['Brand'].map(freq_encoding_brand)
X_val['brand_encoded'] = X_val['Brand'].map(freq_encoding_brand).fillna(mean_freq_brand)
test_data['brand_encoded'] = test_data['Brand'].map(freq_encoding_brand).fillna(mean_freq_brand)

# %%
freq_encoding_model = X_train['model'].value_counts()
mean_freq_model = freq_encoding_model.mean()
X_train['model_encoded'] = X_train['model'].map(freq_encoding_model)
X_val['model_encoded'] = X_val['model'].map(freq_encoding_model).fillna(mean_freq_model)
test_data['model_encoded'] = test_data['model'].map(freq_encoding_model).fillna(mean_freq_model)

# %%
freq_encoding_transmission = X_train['transmission'].value_counts()
mean_freq_transmission = freq_encoding_transmission.mean()
X_train['transmission_encoded'] = X_train['transmission'].map(freq_encoding_transmission)
X_val['transmission_encoded'] = X_val['transmission'].map(freq_encoding_transmission).fillna(mean_freq_transmission)
test_data['transmission_encoded'] = test_data['transmission'].map(freq_encoding_transmission).fillna(mean_freq_transmission)

# %% [markdown]
# - We observed that the fuelType variable contained, only 4 Electric cars, which is an extremely low representation for a category, and 46 rows defined as "other". To prevent overfitting and unstable coefficients, these categories were grouped together into the Other class.

# %%
print(X_train["fuelType"].value_counts())
print(X_val["fuelType"].value_counts())
print(test_data["fuelType"].value_counts())
# Out:
# fuelType
# Petrol      29189
# Diesel      22022
# Hybrid       1602
# Electric        4
# Name: count, dtype: int64
# fuelType
# Petrol    12542
# Diesel     9456
# Hybrid      707
# Name: count, dtype: int64
# fuelType
# Petrol      17884
# Diesel      13701
# Hybrid        981
# Electric        1
# Name: count, dtype: int64

# %%
rare_fuels = ['Electric', 'Other']
X_train['fuelType'] = X_train['fuelType'].replace(rare_fuels, 'Other')
X_val['fuelType'] = X_val['fuelType'].replace(rare_fuels, 'Other')
test_data['fuelType'] = test_data['fuelType'].replace(rare_fuels, 'Other')

freq_encoding_fuel = X_train['fuelType'].value_counts() 
mean_freq_fuel = freq_encoding_fuel.mean()
X_train['fuelType_encoded'] = X_train['fuelType'].map(freq_encoding_fuel)
X_val['fuelType_encoded'] = X_val['fuelType'].map(freq_encoding_fuel).fillna(mean_freq_fuel)
test_data['fuelType_encoded'] = test_data['fuelType'].map(freq_encoding_fuel).fillna(mean_freq_fuel)

# %%
X_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 52817 entries, 42520 to 15659
# Data columns (total 16 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Brand                 52817 non-null  object
#  1   model                 52817 non-null  object
#  2   year                  52817 non-null  float64
#  3   transmission          52817 non-null  object
#  4   mileage               52817 non-null  float64
#  5   fuelType              52817 non-null  object
#  6   tax                   52817 non-null  float64
#  7   mpg                   52817 non-null  float64
#  8   engineSize            52817 non-null  float64
#  9   previousOwners        52817 non-null  float64
#  10  hasDamage             52817 non-null  object
#  11  engineEfficiency      52817 non-null  float64
#  12  brand_encoded         52817 non-null  int64
#  13  model_encoded         52817 non-null  int64
#  14  transmission_encoded  52817 non-null  int64
#  15  fuelType_encoded      52817 non-null  int64
# dtypes: float64(7), int64(4), object(5)
# memory usage: 6.9+ MB

# %%
X_val.isna().sum().sort_values(ascending=False)
# Out:
# Brand                   0
# model                   0
# year                    0
# transmission            0
# mileage                 0
# fuelType                0
# tax                     0
# mpg                     0
# engineSize              0
# previousOwners          0
# hasDamage               0
# engineEfficiency        0
# brand_encoded           0
# model_encoded           0
# transmission_encoded    0
# fuelType_encoded        0
# dtype: int64

# %%
test_data.isna().sum().sort_values(ascending=False)
# Out:
# Brand                   0
# model                   0
# year                    0
# transmission            0
# mileage                 0
# fuelType                0
# tax                     0
# mpg                     0
# engineSize              0
# previousOwners          0
# hasDamage               0
# engineEfficiency        0
# brand_encoded           0
# model_encoded           0
# transmission_encoded    0
# fuelType_encoded        0
# dtype: int64

# %%
X_train = X_train.drop(['Brand', 'model', 'transmission', 'fuelType'], axis=1)
X_val = X_val.drop(['Brand', 'model', 'transmission', 'fuelType'], axis=1)
test_data = test_data.drop(['Brand', 'model', 'transmission', 'fuelType'], axis=1)

# %%
# ensuring that y_train has the same rows X_train
y_train = y_train.loc[X_train.index]
y_val = y_val.loc[X_val.index]

print("X_train shape:", X_train.shape)
print("y_train shape:", y_train.shape)
# Out:
# X_train shape: (52817, 12)
# y_train shape: (52817,)

# %% [markdown]
# ### 4.9. Scaling

# %%
#scale the variables using MinMaxScaler()
var = ['tax', 'mpg', 'mileage', 'engineSize', 'hasDamage', 'previousOwners', 'year', 'engineEfficiency', 'brand_encoded',  'model_encoded', 'fuelType_encoded', 'transmission_encoded']
scaler = MinMaxScaler()

# fitting the scaler only on training dataset (to avoid leakage)
X_train[var] = scaler.fit_transform(X_train[var])

# transforming validation and test dataset using the same scaling
X_val[var] = scaler.transform(X_val[var])
test_data[var] = scaler.transform(test_data[var])

# %%
#checking if X_train and y_train have the same number of rows
print("X_train shape:", X_train.shape)
print("y_train shape:", y_train.shape)
# Out:
# X_train shape: (52817, 12)
# y_train shape: (52817,)

# %%
#checking if X_val and y_val have the same number of rows
print("X_val shape:", X_train.shape)
print("y_val shape:", y_train.shape)
# Out:
# X_val shape: (52817, 12)
# y_val shape: (52817,)

# %%
X_val.head()
# Out:
#        year   mileage       tax       mpg  engineSize  previousOwners  \
# carID
# 37025  0.92  0.093850  0.090909  0.250000    0.227273        0.000000
# 65090  0.90  0.188852  0.484848  0.174824    0.181818        0.166667
# 29197  0.96  0.027362  0.439394  0.224688    0.090909        0.000000
# 22100  0.98  0.019254  0.439394  0.229361    0.090909        1.000000
# 70417  0.98  0.019220  0.439394  0.186526    0.090909        0.500000
#
#        hasDamage  engineEfficiency  brand_encoded  model_encoded  \
# carID
# 37025        0.0          0.237517       0.654394       0.778511
# 65090        0.0          0.189823       0.468852       0.086822
# 29197        0.0          0.341551       1.000000       1.000000
# 22100        0.0          0.348654       1.000000       1.000000
# 70417        0.0          0.283540       0.557189       0.031140
#
#        transmission_encoded  fuelType_encoded
# carID
# 37025              0.080362          0.754429
# 65090              1.000000          1.000000
# 29197              1.000000          1.000000
# 22100              1.000000          1.000000
# 70417              1.000000          1.000000

# %%
test_data.head()
# Out:
#             year   mileage       tax       mpg  engineSize  previousOwners  \
# carID
# 89856   0.904842  0.095044  0.621212  0.161604    0.227273        0.500000
# 106581  0.940000  0.067134  0.454545  0.148754    0.318182        0.333333
# 80886   0.920000  0.113904  0.378788  0.200156    0.204545        0.333333
# 100174  0.980000  0.017127  0.439394  0.171729    0.136364        0.166667
# 81376   0.980000  0.028040  0.454545  0.200156    0.318182        0.666667
#
#         hasDamage  engineEfficiency  brand_encoded  model_encoded  \
# carID
# 89856         0.0          0.153535       0.000000       0.051969
# 106581        0.0          0.113061       0.557189       0.184368
# 80886         0.0          0.202839       0.314289       0.117344
# 100174        0.0          0.217539       0.468852       0.057125
# 81376         0.0          0.152129       0.314289       0.202310
#
#         transmission_encoded  fuelType_encoded
# carID
# 89856               0.000000          1.000000
# 106581              0.080362          1.000000
# 80886               0.000000          1.000000
# 100174              1.000000          1.000000
# 81376               0.080362          0.754429

# %%
test_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 32567 entries, 89856 to 99627
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   year                  32567 non-null  float64
#  1   mileage               32567 non-null  float64
#  2   tax                   32567 non-null  float64
#  3   mpg                   32567 non-null  float64
#  4   engineSize            32567 non-null  float64
#  5   previousOwners        32567 non-null  float64
#  6   hasDamage             32567 non-null  float64
#  7   engineEfficiency      32567 non-null  float64
#  8   brand_encoded         32567 non-null  float64
#  9   model_encoded         32567 non-null  float64
#  10  transmission_encoded  32567 non-null  float64
#  11  fuelType_encoded      32567 non-null  float64
# dtypes: float64(12)
# memory usage: 3.2 MB

# %% [markdown]
# ### 4.10. Feature Selection

# %% [markdown]
# #### 4.10.1. Filter Methods

# %% [markdown]
# ##### 4.10.1.1. Variance

# %%
X_train.var()
# Out:
# year                    0.001905
# mileage                 0.004495
# tax                     0.012328
# mpg                     0.001182
# engineSize              0.008663
# previousOwners          0.057434
# hasDamage               0.000000
# engineEfficiency        0.000399
# brand_encoded           0.095782
# model_encoded           0.095133
# transmission_encoded    0.228332
# fuelType_encoded        0.034968
# dtype: float64

# %%
X_val.var()
# Out:
# year                    0.001819
# mileage                 0.004440
# tax                     0.012564
# mpg                     0.001229
# engineSize              0.008882
# previousOwners          0.057256
# hasDamage               0.000000
# engineEfficiency        0.000520
# brand_encoded           0.094189
# model_encoded           0.095741
# transmission_encoded    0.224459
# fuelType_encoded        0.038610
# dtype: float64

# %% [markdown]
# tirar: hasDamaged

# %% [markdown]
# ##### 4.10.1.2. Spearman correlation

# %%
cor_spearman = X_train.corr(method ='spearman')
cor_spearman
# Out:
#                           year   mileage       tax       mpg  engineSize  \
# year                  1.000000 -0.794966  0.325665 -0.317912   -0.033195
# mileage              -0.794966  1.000000 -0.262946  0.327517    0.099256
# tax                   0.325665 -0.262946  1.000000 -0.560862    0.164814
# mpg                  -0.317912  0.327517 -0.560862  1.000000   -0.206054
# engineSize           -0.033195  0.099256  0.164814 -0.206054    1.000000
# previousOwners        0.000284  0.007456  0.002580  0.000832    0.001399
# hasDamage                  NaN       NaN       NaN       NaN         NaN
# engineEfficiency     -0.145949  0.098980 -0.424060  0.694548   -0.821899
# brand_encoded        -0.012362  0.013177 -0.002245  0.042945   -0.088039
# model_encoded        -0.025492  0.028914 -0.145312  0.233214   -0.233373
# transmission_encoded -0.135488  0.114586 -0.151630  0.190098   -0.507404
# fuelType_encoded      0.101474 -0.195256  0.164724 -0.367366   -0.620934
#
#                       previousOwners  hasDamage  engineEfficiency  \
# year                        0.000284        NaN         -0.145949
# mileage                     0.007456        NaN          0.098980
# tax                         0.002580        NaN         -0.424060
# mpg                         0.000832        NaN          0.694548
# engineSize                  0.001399        NaN         -0.821899
# previousOwners              1.000000        NaN         -0.001822
# hasDamage                        NaN        NaN               NaN
# engineEfficiency           -0.001822        NaN          1.000000
# brand_encoded               0.005864        NaN          0.080519
# model_encoded               0.000436        NaN          0.310015
# transmission_encoded        0.005411        NaN          0.452787
# fuelType_encoded            0.001063        NaN          0.249734
#
#                       brand_encoded  model_encoded  transmission_encoded  \
# year                      -0.012362      -0.025492             -0.135488
# mileage                    0.013177       0.028914              0.114586
# tax                       -0.002245      -0.145312             -0.151630
# mpg                        0.042945       0.233214              0.190098
# engineSize                -0.088039      -0.233373             -0.507404
# previousOwners             0.005864       0.000436              0.005411
# hasDamage                       NaN            NaN                   NaN
# engineEfficiency           0.080519       0.310015              0.452787
# brand_encoded              1.000000       0.513953              0.110250
# model_encoded              0.513953       1.000000              0.166369
# transmission_encoded       0.110250       0.166369              1.000000
# fuelType_encoded           0.044776       0.172718              0.320530
#
#                       fuelType_encoded
# year                          0.101474
# mileage                      -0.195256
# tax                           0.164724
# mpg                          -0.367366
# engineSize                   -0.620934
# previousOwners                0.001063
# hasDamage                          NaN
# engineEfficiency              0.249734
# brand_encoded                 0.044776
# model_encoded                 0.172718
# transmission_encoded          0.320530
# fuelType_encoded              1.000000

# %%
mask = np.triu(np.ones_like(cor_spearman, dtype=bool))

# Escolher um estilo de fundo branco
sns.set_theme(style="white")

# Criar a figura
plt.figure(figsize=(16, 12))

# Plotar o heatmap
sns.heatmap(
    cor_spearman,
    mask=mask,
    annot=True,
    fmt=".2f",
    cmap="coolwarm",
    center=0,
    square=True,
    linewidths=0.5,
    cbar_kws={"shrink": 0.8},
)

# Título e layout
plt.title("Correlation Matrix", fontsize=18, pad=20)
plt.xticks(rotation=45, ha='right')
plt.yticks(rotation=0)
plt.tight_layout()
plt.show()

# %% [markdown]
# tirar:
# - previousOwners (no relationship with any other)
# - engineefficiency vs enginesize
# - milage vs year
# - hasDamaged

# %%
#tirar ou rever
cor_pearson = X_train.corr(method ='pearson')
cor_pearson
# Out:
#                           year   mileage       tax       mpg  engineSize  \
# year                  1.000000 -0.704499  0.183181 -0.124740   -0.036806
# mileage              -0.704499  1.000000 -0.214981  0.179545    0.105416
# tax                   0.183181 -0.214981  1.000000 -0.434711    0.267858
# mpg                  -0.124740  0.179545 -0.434711  1.000000   -0.240095
# engineSize           -0.036806  0.105416  0.267858 -0.240095    1.000000
# previousOwners       -0.000826  0.007460  0.003931 -0.003817   -0.001829
# hasDamage                  NaN       NaN       NaN       NaN         NaN
# engineEfficiency     -0.049023  0.005986 -0.398705  0.687245   -0.751582
# brand_encoded        -0.023626  0.004834  0.002115  0.014731   -0.125485
# model_encoded        -0.007055 -0.001265 -0.126477  0.135453   -0.202365
# transmission_encoded -0.132214  0.103486 -0.205082  0.107837   -0.503467
# fuelType_encoded      0.046929 -0.154117  0.163274 -0.430776   -0.351804
#
#                       previousOwners  hasDamage  engineEfficiency  \
# year                       -0.000826        NaN         -0.049023
# mileage                     0.007460        NaN          0.005986
# tax                         0.003931        NaN         -0.398705
# mpg                        -0.003817        NaN          0.687245
# engineSize                 -0.001829        NaN         -0.751582
# previousOwners              1.000000        NaN         -0.002290
# hasDamage                        NaN        NaN               NaN
# engineEfficiency           -0.002290        NaN          1.000000
# brand_encoded               0.006622        NaN          0.117108
# model_encoded               0.001087        NaN          0.278424
# transmission_encoded        0.005976        NaN          0.427889
# fuelType_encoded            0.002908        NaN          0.092953
#
#                       brand_encoded  model_encoded  transmission_encoded  \
# year                      -0.023626      -0.007055             -0.132214
# mileage                    0.004834      -0.001265              0.103486
# tax                        0.002115      -0.126477             -0.205082
# mpg                        0.014731       0.135453              0.107837
# engineSize                -0.125485      -0.202365             -0.503467
# previousOwners             0.006622       0.001087              0.005976
# hasDamage                       NaN            NaN                   NaN
# engineEfficiency           0.117108       0.278424              0.427889
# brand_encoded              1.000000       0.622036              0.154515
# model_encoded              0.622036       1.000000              0.127768
# transmission_encoded       0.154515       0.127768              1.000000
# fuelType_encoded           0.146509       0.133896              0.324511
#
#                       fuelType_encoded
# year                          0.046929
# mileage                      -0.154117
# tax                           0.163274
# mpg                          -0.430776
# engineSize                   -0.351804
# previousOwners                0.002908
# hasDamage                          NaN
# engineEfficiency              0.092953
# brand_encoded                 0.146509
# model_encoded                 0.133896
# transmission_encoded          0.324511
# fuelType_encoded              1.000000

# %%
mask = np.triu(np.ones_like(cor_pearson, dtype=bool))

# Escolher um estilo de fundo branco
sns.set_theme(style="white")

# Criar a figura
plt.figure(figsize=(16, 12))

# Plotar o heatmap
sns.heatmap(
    cor_pearson,
    mask=mask,
    annot=True,
    fmt=".2f",
    cmap="coolwarm",
    center=0,
    square=True,
    linewidths=0.5,
    cbar_kws={"shrink": 0.8},
)

# Título e layout
plt.title("Correlation Matrix", fontsize=18, pad=20)
plt.xticks(rotation=45, ha='right')
plt.yticks(rotation=0)
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 4.10.1.3. Mutual Information (MI)

# %%
print(X_train.shape, y_train.shape)
# Out:
# (52817, 12) (52817,)

# %%
mi_scores = mutual_info_regression(X_train, y_train, random_state=0)

mi_df = pd.DataFrame({
    'Feature': X_train.columns,
    'MI_Score': mi_scores
}).sort_values(by='MI_Score', ascending=False)

print(mi_df.head(10))

top_mi_features = mi_df.head(15)['Feature']
X_train_mi = X_train[top_mi_features]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[116], line 1
# ----> 1 mi_scores = mutual_info_regression(X_train, y_train, random_state=0)
#       3 mi_df = pd.DataFrame({
#       4     'Feature': X_train.columns,
#       5     'MI_Score': mi_scores
#       6 }).sort_values(by='MI_Score', ascending=False)
#       8 print(mi_df.head(10))
#
# File c:\Users\Catarina\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py:216, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     210 try:
#     211     with config_context(
#     212         skip_parameter_validation=(
#     213             prefer_skip_nested_validation or global_skip_validation
#     214         )
#     215     ):
# --> 216         return func(*args, **kwargs)
#     217 except InvalidParameterError as e:
#     218     # When the function is just a wrapper around an estimator, we allow
#     219     # the function to delegate validation to the estimator, but we replace
#     220     # the name of the estimator by the name of the function in the error
#     221     # message to avoid confusion.
#     222     msg = re.sub(
#     223         r"parameter of \w+ must be",
#     224         f"parameter of {func.__qualname__} must be",
#     225         str(e),
#     226     )
#
# File c:\Users\Catarina\anaconda3\Lib\site-packages\sklearn\feature_selection\_mutual_info.py:441, in mutual_info_regression(X, y, discrete_features, n_neighbors, copy, random_state, n_jobs)
#     325 @validate_params(
#     326     {
#     327         "X": ["array-like", "sparse matrix"],
#    (...)
#     345     n_jobs=None,
#     346 ):
#     347     """Estimate mutual information for a continuous target variable.
#     348
#     349     Mutual information (MI) [1]_ between two random variables is a non-negative
#    (...)
#     439     array([0.1..., 2.6...  , 0.0...])
#     440     """
# --> 441     return _estimate_mi(
#     442         X,
#     443         y,
#     444         discrete_features=discrete_features,
#     445         discrete_target=False,
#     446         n_neighbors=n_neighbors,
#     447         copy=copy,
#     448         random_state=random_state,
#     449         n_jobs=n_jobs,
#     450     )
#
# File c:\Users\Catarina\anaconda3\Lib\site-packages\sklearn\feature_selection\_mutual_info.py:271, in _estimate_mi(X, y, discrete_features, discrete_target, n_neighbors, copy, random_state, n_jobs)
#     202 def _estimate_mi(
#     203     X,
#     204     y,
#    (...)
#     211     n_jobs=None,
#     212 ):
#     213     """Estimate mutual information between the features and the target.
#     214
#     215     Parameters
#    (...)
#     269            Data Sets". PLoS ONE 9(2), 2014.
#     270     """
# --> 271     X, y = check_X_y(X, y, accept_sparse="csc", y_numeric=not discrete_target)
#     272     n_samples, n_features = X.shape
#     274     if isinstance(discrete_features, (str, bool)):
#
# File c:\Users\Catarina\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1370, in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_writeable, force_all_finite, ensure_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, estimator)
#    1364     raise ValueError(
#    1365         f"{estimator_name} requires y to be passed, but the target y is None"
#    1366     )
#    1368 ensure_all_finite = _deprecate_force_all_finite(force_all_finite, ensure_all_finite)
# -> 1370 X = check_array(
#    1371     X,
#    1372     accept_sparse=accept_sparse,
#    1373     accept_large_sparse=accept_large_sparse,
#    1374     dtype=dtype,
#    1375     order=order,
#    1376     copy=copy,
#    1377     force_writeable=force_writeable,
#    1378     ensure_all_finite=ensure_all_finite,
#    1379     ensure_2d=ensure_2d,
#    1380     allow_nd=allow_nd,
#    1381     ensure_min_samples=ensure_min_samples,
#    1382     ensure_min_features=ensure_min_features,
#    1383     estimator=estimator,
#    1384     input_name="X",
#    1385 )
#    1387 y = _check_y(y, multi_output=multi_output, y_numeric=y_numeric, estimator=estimator)
#    1389 check_consistent_length(X, y)
#
# File c:\Users\Catarina\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1107, in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_writeable, force_all_finite, ensure_all_finite, ensure_non_negative, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#    1101     raise ValueError(
#    1102         "Found array with dim %d. %s expected <= 2."
#    1103         % (array.ndim, estimator_name)
#    1104     )
#    1106 if ensure_all_finite:
# -> 1107     _assert_all_finite(
#    1108         array,
#    1109         input_name=input_name,
#    1110         estimator_name=estimator_name,
#    1111         allow_nan=ensure_all_finite == "allow-nan",
#    1112     )
#    1114 if copy:
#    1115     if _is_numpy_namespace(xp):
#    1116         # only make a copy if `array` and `array_orig` may share memory`
#
# File c:\Users\Catarina\anaconda3\Lib\site-packages\sklearn\utils\validation.py:120, in _assert_all_finite(X, allow_nan, msg_dtype, estimator_name, input_name)
#     117 if first_pass_isfinite:
#     118     return
# --> 120 _assert_all_finite_element_wise(
#     121     X,
#     122     xp=xp,
#     123     allow_nan=allow_nan,
#     124     msg_dtype=msg_dtype,
#     125     estimator_name=estimator_name,
#     126     input_name=input_name,
#     127 )
#
# File c:\Users\Catarina\anaconda3\Lib\site-packages\sklearn\utils\validation.py:169, in _assert_all_finite_element_wise(X, xp, allow_nan, msg_dtype, estimator_name, input_name)
#     152 if estimator_name and input_name == "X" and has_nan_error:
#     153     # Improve the error message on how to handle missing values in
#     154     # scikit-learn.
#     155     msg_err += (
#     156         f"\n{estimator_name} does not accept missing values"
#     157         " encoded as NaN natively. For supervised learning, you might want"
#    (...)
#     167         "#estimators-that-handle-nan-values"
#     168     )
# --> 169 raise ValueError(msg_err)
#
# ValueError: Input X contains NaN.

# %%
mi_df = mi_df.sort_values(by='MI_Score', ascending=False).reset_index(drop=True)
mi_df['MI_Score_norm'] = mi_df['MI_Score'] / mi_df['MI_Score'].max()

# Plot clean MI curve
plt.figure(figsize=(10, 6))
plt.plot(mi_df['Feature'], mi_df['MI_Score_norm'], marker='o', color='steelblue', linewidth=2)
plt.title("Mutual Information Scores — Feature Importance", fontsize=14, fontweight='bold')
plt.xlabel("Feature", fontsize=12)
plt.ylabel("Normalized MI Score", fontsize=12)
plt.xticks(rotation=45, ha='right')
plt.grid(alpha=0.3)
plt.tight_layout()
plt.show()

# %% [markdown]
# tirar:
# - fuelType_encoded
# - hasDamage
# - previousOwners
# - tax
# - transmission_encoded

# %% [markdown]
# #### 4.10.2. Wrapper Methods

# %% [markdown]
# ##### 4.10.2.1. RFE

# %%
'''# Number of features to select

nof_list = np.arange(1, len(X_train.columns) + 1)
low_rmse = float('inf')  # NEW: Initialize comparison to infinity (high value)
# Variable to store the optimum features
nof = 0 
train_rmse_list = []      # NEW: Store RMSE instead of R-squared score
val_rmse_list = []        # NEW: Store RMSE instead of R-squared score

# --- RFE Loop using RMSE ---
for n in range(len(nof_list)):
    model = LinearRegression() # use LinearRegression as model
    
    # 1. Recursive Feature Elimination
    rfe = RFE(estimator=model, n_features_to_select=nof_list[n])
    X_train_rfe = rfe.fit_transform(X_train, y_train)
    X_val_rfe = rfe.transform(X_val)
    
    # 2. Train Model on Subset
    model.fit(X_train_rfe, y_train)
    
    # 3. Calculate and Store Training RMSE
    y_train_pred = model.predict(X_train_rfe)
    train_rmse = np.sqrt(mean_squared_error(y_train, y_train_pred))
    train_rmse_list.append(train_rmse)
    
    # 4. Calculate and Store Validation RMSE
    y_val_pred = model.predict(X_val_rfe)
    val_rmse = np.sqrt(mean_squared_error(y_val, y_val_pred))
    val_rmse_list.append(val_rmse)
    
    # 5. Check best score (finding the minimum RMSE)
    if(val_rmse <= low_rmse): # CHANGED: Look for the lowest RMSE (less than or equal)
        low_rmse = val_rmse
        nof = nof_list[n]

print("Optimum number of features: %d" % nof)
print("Lowest RMSE with %d features: %f" % (nof, low_rmse))'''
# Out:
# Optimum number of features: 10
# Lowest RMSE with 10 features: 5023.263555

# %%
'''# Create plot to see RFE performance

x = np.arange(1, len(X_train.columns) + 1)

plt.figure(figsize=(10,6))
plt.plot(x, train_rmse_list, label='Training Score', color='yellowgreen', marker='o')
plt.plot(x, val_rmse_list, label='Validation Score', color='dimgray', marker='o')
plt.plot(nof, low_rmse, 'ro',label=f'Optimal Features: {nof} (RMSE: {low_rmse:.4f})', markersize=8)
plt.xlabel("Number of Features", fontsize=12)
plt.ylabel("RMSE Score", fontsize=12)
plt.title("RFE Performance - Training vs Validation Scores", fontsize=14)
plt.legend()
plt.grid(True, linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()'''

# %%
'''# Select features

final_model = LinearRegression()   # Use LinearRegression as model because we want to predict price which is a continuous variable
rfe_final = RFE(estimator=final_model, n_features_to_select=nof)
rfe_final.fit(X_train, y_train)    # Apply RFE to determine the best features in our dataset

# Get the mask of selected features
selected_features_11 = X_train.columns[rfe_final.support_]   # Obtain the best features

print("Selected features using RFE ({} features):".format(nof))
print(list(selected_features_11))'''
# Out:
# Selected features using RFE (10 features):
# ['year', 'mileage', 'tax', 'mpg', 'engineSize', 'engineEfficiency', 'brand_encoded', 'model_encoded', 'transmission_encoded', 'fuelType_encoded']

# %% [markdown]
# ##### 4.10.2.2. RFECV

# %%
# Combine train and validation datasets
X_combined = np.concatenate([X_train, X_val])
y_combined = np.concatenate([y_train, y_val])

# Create a test fold index (-1 for train, 0 for validation)
test_fold = [-1] * len(X_train) + [0] * len(X_val)

print('Test fold: ', len(test_fold))
print('X_combined: ', len(X_combined))
print('y_combined: ', len(y_combined))

# Define the PredefinedSplit
ps = PredefinedSplit(test_fold=test_fold)
# Out:
# Test fold:  75522
# X_combined:  75522
# y_combined:  75522

# %%
# preprune random forest

base_estimator = RandomForestRegressor(
    n_estimators=200,   # number of trees
    max_depth=10,
    min_samples_leaf = 4,
    max_features="sqrt",
    random_state=0,
    n_jobs=-1
)

# %%
# Find number of features
neg_mse_scorer = make_scorer(mean_squared_error, greater_is_better=False)

# 3. Execute RFECV to find the optimal feature count based on Validation RMSE
# Using the balanced estimator for the primary optimization process.
rfecv_selector = RFECV(
    estimator=base_estimator, 
    step=1,
    cv=ps, # Uses the PredefinedSplit (X_val) for scoring
    scoring=neg_mse_scorer
)
rfecv_selector.fit(X_combined, y_combined)

# --- Define the range of features evaluated by RFECV (for the X-axis) ---
feature_counts_range = rfecv_selector.cv_results_['n_features']

# 4. Calculate Training RMSE for the plot (MANUAL LOOP CORRECTED)
# We calculate the Training score for each feature subset size determined by the ranking.
train_rmse_list = []
feature_ranking = rfecv_selector.ranking_

for n in feature_counts_range:
    # Identify the features selected at this step (rank <= n)
    selected_features_mask = feature_ranking <= n
    
    # Subset X_train using the mask, assuming X_train is a Pandas DataFrame.
    X_train_subset = X_train.iloc[:, selected_features_mask]
    
    # Train on the SUBSET of features
    base_estimator.fit(X_train_subset, y_train)
    
    # Predict and calculate Training RMSE on the SUBSET of features
    train_pred = base_estimator.predict(X_train_subset)
    train_mse = mean_squared_error(y_train, train_pred)
    train_rmse_list.append(np.sqrt(train_mse))


# 5. Prepare Plotting Data and Output
optimal_nof = rfecv_selector.n_features_
validation_scores_neg_mse = rfecv_selector.cv_results_['mean_test_score']
# Convert Validation Negative MSE scores to positive RMSE
validation_rmse = np.sqrt(-validation_scores_neg_mse) 
# The index of the optimal number of features is optimal_nof - 1
min_rmse = validation_rmse[optimal_nof - 1] 

# Variables for Plotting
nof_list = feature_counts_range
val_rmse_list = validation_rmse
nof = optimal_nof
low_rmse = min_rmse

print("\n--- RFECV Results (Using Random Forest) ---")
print(f"Optimal number of features found: {nof}")
print(f"Minimum Validation RMSE achieved: {low_rmse:.4f}")
# Out:
# --- RFECV Results (Using Random Forest) ---
# Optimal number of features found: 9
# Minimum Validation RMSE achieved: 2895.4436

# %%
# Plot figure

plt.figure(figsize=(10, 6))

# Training RMSE (NEWLY ADDED)
plt.plot(nof_list, train_rmse_list,
         label="RMSE on Training Set", color='yellowgreen', linewidth=2) 
         
# Validation RMSE
plt.plot(nof_list, val_rmse_list, 
         label="RMSE on Validation Set", color='dimgray', linewidth=2) 

# Highlight the optimal point
plt.plot(nof, low_rmse, 'ro', 
         label=f'Optimal Features: {nof} (RMSE: {low_rmse:.4f})', markersize=8)

plt.xlabel("Number of Features Selected")
plt.ylabel("RMSE (Root Mean Squared Error)") 
plt.title("RFECV Performance: Training vs. Validation Error")
plt.legend(loc='upper right')
plt.grid(True, linestyle='--', alpha=0.6)
plt.show()

# %%
# Get the mask of selected features (True for selected, False otherwise)
# rfecv_selector.support_ stores the mask corresponding to the optimal_nof
selected_feature_mask = rfecv_selector.support_

forward_features = X_train.columns[selected_feature_mask]

print("Selected features using RFECV ({} features):".format(optimal_nof))
print(list(forward_features))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[135], line 3
#       1 # Get the mask of selected features (True for selected, False otherwise)
#       2 # rfecv_selector.support_ stores the mask corresponding to the optimal_nof
# ----> 3 selected_feature_mask = rfecv_selector.support_
#       5 forward_features = X_train.columns[selected_feature_mask]
#       7 print("Selected features using RFECV ({} features):".format(optimal_nof))
#
# NameError: name 'rfecv_selector' is not defined

# %% [markdown]
# ##### 4.10.2.1. Sequential Feature Selector

# %% [markdown]
# **Forward Selection**

# %%
from sklearn.feature_selection import SequentialFeatureSelector

#forward selection

sfs_forward = SequentialFeatureSelector(
    estimator=base_estimator,
    n_features_to_select="auto",   # Let SFS find optimal count
    direction="forward",
    scoring="neg_mean_squared_error",
    cv=ps,                          # small CV to reduce compute
    n_jobs=-1,
    tol=1e-3  
)

sfs_forward.fit(X_combined, y_combined)

# Selected feature mask and names
forward_mask = sfs_forward.get_support()
forward_features = X_train.columns[forward_mask]

print("Forward Selected Features:")
print(list(forward_features))

# Evaluate on validation set
base_estimator.fit(X_train[forward_features], y_train)
y_val_pred_forward = base_estimator.predict(X_val[forward_features])
val_rmse_forward = np.sqrt(mean_squared_error(y_val, y_val_pred_forward))

# Calculate Training RMSE 
y_train_pred_forward = base_estimator.predict(X_train[forward_features])
train_rmse_forward = np.sqrt(mean_squared_error(y_train, y_train_pred_forward))

print("Training RMSE (Forward SFS):", train_rmse_forward)
print("Validation RMSE (Forward SFS):", val_rmse_forward)
# Out:
# Forward Selected Features:
# ['year', 'engineSize', 'engineEfficiency', 'brand_encoded', 'model_encoded']
# Training RMSE (Forward SFS): 2909.84960908877
# Validation RMSE (Forward SFS): 2958.271210599678

# %% [markdown]
# **Backward Selection**

# %%
'''# Backward Selection
sfs_backward = SequentialFeatureSelector(
    estimator=base_estimator,
    n_features_to_select="auto", # Let SFS find optimal count
    direction="backward",        # Key change for Backward Selection
    scoring="neg_mean_squared_error",
    cv=ps,                       # Use the same PredefinedSplit
    n_jobs=-1,
    tol=1e-3
)

sfs_backward.fit(X_combined, y_combined)

# Selected feature mask and names
backward_mask = sfs_backward.get_support()
backward_features = X_train.columns[backward_mask] 

print("\nBackward Selected Features:")
print(list(backward_features))

# Evaluate on validation set
# We must use a fresh fit of the base_estimator on the optimally selected features
base_estimator.fit(X_train[backward_features], y_train)
y_val_pred_backward = base_estimator.predict(X_val[backward_features])
val_rmse_backward = np.sqrt(mean_squared_error(y_val, y_val_pred_backward))

# Calculate Training RMSE 
y_train_pred_backward = base_estimator.predict(X_train[backward_features])
train_rmse_backward = np.sqrt(mean_squared_error(y_train, y_train_pred_backward))

print("Training RMSE (Backward SFS):", train_rmse_backward)
print("Validation RMSE (Backward SFS):", val_rmse_backward)'''
# Out:
# Backward Selected Features:
# ['year', 'mileage', 'mpg', 'engineSize', 'engineEfficiency', 'brand_encoded', 'model_encoded', 'transmission_encoded', 'fuelType_encoded']
# Training RMSE (Backward SFS): 2720.0405933256093
# Validation RMSE (Backward SFS): 2870.6362232239303

# %% [markdown]
# #### 4.10.3. Embedded Methods

# %% [markdown]
# ##### 4.10.3.1 Lasso

# %%
import pandas as pd
import numpy as np

from sklearn.linear_model import Lasso
from sklearn.ensemble import RandomForestRegressor

# -----------------------------------------------------------
# 1. LASSO (L1 Regularization)
# -----------------------------------------------------------

lasso = Lasso(alpha=0.01, random_state=42)
lasso.fit(X_train, y_train)

lasso_importance = pd.DataFrame({
    "feature": X_train.columns,
    "lasso_coef": lasso.coef_
}).sort_values(by="lasso_coef", key=abs, ascending=False)

# %% [markdown]
# ##### 4.10.3.2. Random Forest Feature Importance

# %%
# -----------------------------------------------------------
# 2. RANDOM FOREST FEATURE IMPORTANCE
# -----------------------------------------------------------

rf = RandomForestRegressor(
    n_estimators=500,
    random_state=42,
    n_jobs=-1
)
rf.fit(X_train, y_train)

rf_importance = pd.DataFrame({
    "feature": X_train.columns,
    "rf_importance": rf.feature_importances_
}).sort_values("rf_importance", ascending=False)

# %%
# -----------------------------------------------------------
# 3. MERGE RESULTS
# -----------------------------------------------------------

feature_importance_table = (
    lasso_importance
    .merge(rf_importance, on="feature")
    .sort_values("rf_importance", ascending=False)
)

print(feature_importance_table)
# Out:
#                  feature     lasso_coef  rf_importance
# 5   transmission_encoded   -4278.075694       0.293117
# 3                   year   36337.570107       0.200998
# 0       engineEfficiency  120439.426610       0.178569
# 1             engineSize   73207.650079       0.132259
# 4                mileage  -29410.564828       0.073874
# 9          model_encoded    -508.223381       0.049422
# 7          brand_encoded    1568.899672       0.025960
# 2                    mpg  -71959.426539       0.025237
# 6                    tax   -3269.092968       0.010589
# 10        previousOwners      49.771283       0.005120
# 8       fuelType_encoded   -1456.852730       0.004854
# 11             hasDamage       0.000000       0.000000

# %% [markdown]
# 🟩 Strong & reliable predictors
#
# ✔ engineEfficiency
# ✔ year
# ✔ engineSize
# ✔ mileage
# ✔ transmission
#
# 🟨 Moderate but useful
#
# ✔ model_encoded
# ✔ brand_encoded
#
# 🟥 Weak predictors
#
# ✔ tax
# ✔ fuelType
# ✔ previousOwners
#
# 🚫 Useless
#
# ✔ hasDamage

# %% [markdown]
# ### Final Insights

# %% [markdown]
# | Predictor            | Variance | Spearman Correlation| Mutual Information | RFE (Linear regression) | RFECV (Random Forest) | SFS Forward | SFS Backward | Decision              |
# |----------------------|----------|---------------|---------------------|----------|------------------------|-------------|--------------|------------------------|
# | year                 | Keep     | High correlated| Keep                | Keep     | Keep                   | Keep        | Keep         | Include in the model   |
# | mileage              | Keep     | High correlated| Keep                | Keep     | Keep                   | Keep        | Keep         | Include in the model   |
# | tax                  | Keep     | Keep          | Discard             | Keep     | Keep                   | Discard     | Discard      | Try with and without   |
# | mpg                  | Keep     | Keep          | Keep                | Keep     | Keep                   | Keep        | Keep         | Include in the model   |
# | engineSize           | Keep     | High correlated| Keep                | Keep     | Keep                   | Keep        | Keep         | Include in the model   |
# | engineEfficiency     | Keep     | High correlated| Keep                | Keep     | Keep                   | Keep        | Keep         | Include in the model   |
# | brand_encoded        | Keep     | Keep          | Keep                | Keep     | Keep                   | Keep        | Keep         | Include in the model   |
# | model_encoded        | Keep     | Keep          | Keep                | Keep     | Keep                   | Keep        | Keep         | Include in the model   |
# | transmission_encoded | Keep     | Keep          | Discard             | Keep     | Keep                   | Keep        | Keep         | Include in the model   |
# | fuelType_encoded     | Keep     | Keep          | Discard             | Discard  | Discard                | Discard     | Discard      | Discard                |
# | previousOwners       | Keep     | Discard       | Discard             | Discard  | Discard                | Discard     | Discard      | Discard                |
# | hasDamage            | Discard  | Discard       | Discard             | Discard  | Discard                | Discard     | Discard      | Discard                |

# %% [markdown]
# | Predictor            | Variance | Spearman Correlation| Mutual Information | RFECV (Random Forest) | SFS Forward | Lasso | RFFS | Decision              |
# |----------------------|----------|---------------|---------------------|----------|------------------------|-------------|--------------|------------------------|
# | year                 | Keep     | High correlated| Keep                | Keep     | Keep                | Keep        | Keep         | Include in the model   |
# | mileage              | Keep     | High correlated| Keep                | Keep     | Discard             | Keep        | Keep         | Include in the model   |
# | tax                  | Keep     | Keep          | Discard             | Keep     | Discard              | Medium     | Medium      | Try with and without   |
# | mpg                  | Keep     | Keep          | Keep                | Keep     | Discard              | Keep      | Medium       | Include in the model   |
# | engineSize           | Keep     | High correlated| Keep                | Keep     | Keep                | Keep        | Keep         | Include in the model   |
# | engineEfficiency     | Keep     | High correlated| Keep                | Keep     | Keep                | Keep        | Keep         | Include in the model   |
# | brand_encoded        | Keep     | Keep          | Keep                | Keep     | Keep                 | Medium      | Medium         | Include in the model   |
# | model_encoded        | Keep     | Keep          | Keep                | Keep     | Keep                 | Medium       | Keep         | Include in the model   |
# | transmission_encoded | Keep     | Keep          | Discard             | Keep     | Discard             | Medium        | Keep         | Include in the model   |
# | fuelType_encoded     | Keep     | Keep          | Discard             | Discard  | Discard                | Medium     | Discard      | Discard                |
# | previousOwners       | Keep     | Discard       | Discard             | Discard  | Discard              | Discard     | Discard      | Discard                |
# | hasDamage            | Discard  | Discard       | Discard             | Discard  | Discard              | Discard     | Discard      | Discard                |

# %% [markdown]
# Strategy: 3 or more discard
# - variables: 'year', 'mileage', 'mpg', 'engineSize', 'engineEfficiency', 'brand_encoded', 'model_encoded', 'transmission_encoded', 'tax'(try with and without tax)

# %%
features_to_keep = ['year', 'mileage', 'mpg', 'engineSize', 'engineEfficiency', 
                    'brand_encoded', 'model_encoded', 'transmission_encoded', 'tax']

X_train = X_train[features_to_keep]
X_val = X_val[features_to_keep]
test_data = test_data[features_to_keep]

# %%
y_train_log = np.log1p(y_train)
y_val_log   = np.log1p(y_val)

# %% [markdown]
# # Benchmarking

# %% [markdown]
# ## Initial Benchmarking

# %%
import numpy as np
import pandas as pd

from sklearn.linear_model import LinearRegression, Ridge
from sklearn.neighbors import KNeighborsRegressor
from sklearn.ensemble import RandomForestRegressor, ExtraTreesRegressor, HistGradientBoostingRegressor
from sklearn.metrics import mean_squared_error, r2_score

# ============================
# 1. Função de RMSE na escala original
# ============================
def rmse(y_true, y_pred):
    return np.sqrt(mean_squared_error(y_true, y_pred))

# ============================
# 2. Transformação logarítmica do target
# ============================
y_train_log = np.log1p(y_train)
y_val_log   = np.log1p(y_val)

# ============================
# 3. Modelos para Initial Benchmarking (em log)
#    – simples, antes de qualquer tuning “a sério”
# ============================

benchmark_models_log = {
    "LinearRegression": LinearRegression(),
    
    "Ridge": Ridge(
        alpha=1.0,
        random_state=42
    ),
    
    "KNN": KNeighborsRegressor(
        n_neighbors=30,
        weights="distance",
        p=2
    ),
    
    "RandomForest": RandomForestRegressor(
        n_estimators=200,
        max_depth=None,
        min_samples_leaf=1,
        random_state=42,
        n_jobs=-1
    ),
    
    "ExtraTrees": ExtraTreesRegressor(
        n_estimators=300,
        max_depth=None,
        min_samples_leaf=1,
        random_state=42,
        n_jobs=-1
    ),
    
    "HGBR": HistGradientBoostingRegressor(
        max_depth=8,
        learning_rate=0.05,
        max_iter=300,
        min_samples_leaf=20,
        random_state=42
    ),
}

benchmark_log_results = []
fitted_benchmark_models = {}  # para reutilizar mais tarde se quiseres

# ============================
# 4. Treinar em log, avaliar na escala original
# ============================
for name, model in benchmark_models_log.items():
    
    # Fit em log(y)
    model.fit(X_train, y_train_log)
    fitted_benchmark_models[name] = model
    
    # Predições em log(y)
    y_train_log_pred = model.predict(X_train)
    y_val_log_pred   = model.predict(X_val)
    
    # Voltar à escala original: preço
    y_train_pred = np.expm1(y_train_log_pred)
    y_val_pred   = np.expm1(y_val_log_pred)
    
    # Métricas em £
    train_rmse = rmse(y_train, y_train_pred)
    val_rmse   = rmse(y_val, y_val_pred)
    
    train_r2 = r2_score(y_train, y_train_pred)
    val_r2   = r2_score(y_val, y_val_pred)
    
    benchmark_log_results.append({
        "model": name,
        "train_RMSE": train_rmse,
        "val_RMSE": val_rmse,
        "train_R2": train_r2,
        "val_R2": val_r2
    })
    
    print(f"{name}: RMSE_train={train_rmse:.0f} | RMSE_val={val_rmse:.0f} | R2_val={val_r2:.3f}")

benchmark_log_df = pd.DataFrame(benchmark_log_results).sort_values("val_RMSE").reset_index(drop=True)
benchmark_log_df
# Out:
# LinearRegression: RMSE_train=4679 | RMSE_val=4643 | R2_val=0.773
# Ridge: RMSE_train=4680 | RMSE_val=4645 | R2_val=0.772
# KNN: RMSE_train=31 | RMSE_val=3652 | R2_val=0.859
# RandomForest: RMSE_train=1008 | RMSE_val=2324 | R2_val=0.943
# ExtraTrees: RMSE_train=31 | RMSE_val=2284 | R2_val=0.945
# HGBR: RMSE_train=2401 | RMSE_val=2450 | R2_val=0.937
#               model   train_RMSE     val_RMSE  train_R2    val_R2
# 0        ExtraTrees    31.030186  2284.456922  0.999990  0.944931
# 1      RandomForest  1008.117057  2324.346176  0.989308  0.942992
# 2              HGBR  2401.320848  2450.116656  0.939335  0.936655
# 3               KNN    31.030186  3652.131882  0.999990  0.859256
# 4  LinearRegression  4679.167958  4642.584448  0.769657  0.772565
# 5             Ridge  4679.765472  4644.501720  0.769598  0.772377

# %%
# já existente no teu notebook
X_combined = np.concatenate([X_train, X_val])
y_combined = np.concatenate([y_train, y_val])
ps = PredefinedSplit(test_fold=test_fold)

# %%
# Construir DataFrame “arrumado” para plot
rmse_plot = pd.DataFrame({
    "Model": [
        "Random Forest", "Random Forest",
        "Extra Trees",   "Extra Trees",
        "DNN",           "DNN"
    ],
    "Split": [
        "Train", "Val",
        "Train", "Val",
        "Train", "Val"
    ],
    "RMSE": [
        results.loc["RF RMSE (Train)",  "Value"],
        results.loc["RF RMSE (Val)",    "Value"],
        results.loc["ET RMSE (Train)",  "Value"],
        results.loc["ET RMSE (Val)",    "Value"],
        results.loc["DNN RMSE (Train)", "Value"],
        results.loc["DNN RMSE (Val)",   "Value"],
    ]
})

plt.figure(figsize=(8, 6))
sns.barplot(
    data=rmse_plot,
    x="Model",
    y="RMSE",
    hue="Split"
)
plt.title("RMSE Train vs Val por Modelo (Random Forest, Extra Trees, DNN)")
plt.ylabel("RMSE (escala original do preço)")
plt.xlabel("")
plt.tight_layout()
plt.show()

# %% [markdown]
# Random forest and Extra trees are clearly overfitting, even though they are giving us better results than DNN. Next step is applying Random Search to discover the best combination of parameters in order to perform the pruning.

# %% [markdown]
# ## Random Search

# %%
def evaluate_model_log(
    model,
    X_train, y_train_log,
    X_val,   y_val_log
):
    pred_train_log = model.predict(X_train)
    pred_val_log   = model.predict(X_val)

    y_train_true = np.expm1(y_train_log)
    y_val_true   = np.expm1(y_val_log)

    pred_train = np.expm1(pred_train_log)
    pred_val   = np.expm1(pred_val_log)

    rmse_train = mean_squared_error(y_train_true, pred_train) ** 0.5
    rmse_val   = mean_squared_error(y_val_true,   pred_val)   ** 0.5

    return rmse_train, rmse_val

# %%
def random_search_model(
    model_class,
    param_grid,
    X_train, y_train_log,
    X_val,   y_val_log,
    n_iter=30,
    fixed_params=None
):
    results = []
    best_rmse = float("inf")
    best_model = None
    best_params = None

    keys = list(param_grid.keys())

    for i in range(n_iter):
        params = {k: random.choice(param_grid[k]) for k in keys}

        if fixed_params:
            params = {**params, **fixed_params}

        model = model_class(**params)
        model.fit(X_train, y_train_log)

        rmse_train, rmse_val = evaluate_model_log(
            model,
            X_train, y_train_log,
            X_val,   y_val_log
        )

        results.append({
            **params,
            "RMSE_train": rmse_train,
            "RMSE_val": rmse_val
        })

        if rmse_val < best_rmse:
            best_rmse = rmse_val
            best_model = model
            best_params = params

        print(f"[{i+1}/{n_iter}] RMSE_train={rmse_train:.2f} | RMSE_val={rmse_val:.2f}")

    return (
        pd.DataFrame(results).sort_values("RMSE_val").reset_index(drop=True),
        best_model,
        best_params
    )

# %% [markdown]
# ## Ridge

# %%
param_ridge = {
    "alpha": list(np.logspace(-4, 3, 50)),
    "fit_intercept": [True, False],
    "solver": ["auto", "svd", "cholesky", "lsqr", "sag", "saga"]
}

results_ridge, best_ridge, best_ridge_params = random_search_model(
    model_class=Ridge,
    param_grid=param_ridge,
    X_train=X_train, y_train_log=y_train_log,
    X_val=X_val,     y_val_log=y_val_log,
    n_iter=40,
    fixed_params={"random_state": 42}
)

print("Best Ridge params:", best_ridge_params)
# Out:
# [1/40] RMSE_train=5170.19 | RMSE_val=5070.54
# [2/40] RMSE_train=4679.17 | RMSE_val=4642.59
# [3/40] RMSE_train=5159.57 | RMSE_val=5060.12
# [4/40] RMSE_train=4683.32 | RMSE_val=4651.22
# [5/40] RMSE_train=6334.95 | RMSE_val=6186.67
# [6/40] RMSE_train=4680.68 | RMSE_val=4646.56
# [7/40] RMSE_train=5163.38 | RMSE_val=5063.84
# [8/40] RMSE_train=4679.14 | RMSE_val=4642.60
# [9/40] RMSE_train=5159.93 | RMSE_val=5060.46
# [10/40] RMSE_train=5159.55 | RMSE_val=5060.09
# [11/40] RMSE_train=5159.85 | RMSE_val=5060.42
# [12/40] RMSE_train=5159.60 | RMSE_val=5060.14
# [13/40] RMSE_train=5168.43 | RMSE_val=5068.72
# [14/40] RMSE_train=4679.17 | RMSE_val=4642.59
# [15/40] RMSE_train=5160.57 | RMSE_val=5061.09
# [16/40] RMSE_train=5159.75 | RMSE_val=5060.28
# [17/40] RMSE_train=4690.85 | RMSE_val=4662.01
# [18/40] RMSE_train=8589.55 | RMSE_val=8527.56
# [19/40] RMSE_train=6587.55 | RMSE_val=6436.63
# [20/40] RMSE_train=4733.28 | RMSE_val=4711.64
# [21/40] RMSE_train=5159.55 | RMSE_val=5060.09
# [22/40] RMSE_train=5159.82 | RMSE_val=5060.36
# [23/40] RMSE_train=5159.82 | RMSE_val=5060.36
# [24/40] RMSE_train=4679.17 | RMSE_val=4642.59
# [25/40] RMSE_train=6588.40 | RMSE_val=6437.50
# [26/40] RMSE_train=4679.17 | RMSE_val=4642.59
# [27/40] RMSE_train=5159.55 | RMSE_val=5060.09
# [28/40] RMSE_train=4679.20 | RMSE_val=4642.71
# [29/40] RMSE_train=4679.31 | RMSE_val=4643.23
# [30/40] RMSE_train=5570.88 | RMSE_val=5453.75
# [31/40] RMSE_train=4679.77 | RMSE_val=4644.50
# [32/40] RMSE_train=5159.69 | RMSE_val=5060.23
# [33/40] RMSE_train=5159.50 | RMSE_val=5060.10
# [34/40] RMSE_train=5187.72 | RMSE_val=5087.58
# [35/40] RMSE_train=4698.84 | RMSE_val=4672.15
# [36/40] RMSE_train=4680.68 | RMSE_val=4646.56
# [37/40] RMSE_train=4679.17 | RMSE_val=4642.60
# [38/40] RMSE_train=5160.97 | RMSE_val=5061.49
# [39/40] RMSE_train=5374.85 | RMSE_val=5267.16
# [40/40] RMSE_train=5179.69 | RMSE_val=5079.77
# Best Ridge params: {'alpha': np.float64(0.0013894954943731374), 'fit_intercept': True, 'solver': 'svd', 'random_state': 42}

# %% [markdown]
# ### KNN

# %%
param_knn = {
    "n_neighbors": list(range(3, 61)),
    "weights": ["uniform", "distance"],
    "p": [1, 2],  # 1=Manhattan, 2=Euclidean
    "leaf_size": [10, 20, 30, 40, 50]
}

results_knn, best_knn, best_knn_params = random_search_model(
    model_class=KNeighborsRegressor,
    param_grid=param_knn,
    X_train=X_train, y_train_log=y_train_log,
    X_val=X_val,     y_val_log=y_val_log,
    n_iter=60
)

print("Best KNN params:", best_knn_params)

# %% [markdown]
# ### Random Search para otimizar hiperparametros das extra trees

# %%
# Espaço de hiperparâmetros (igual)
param_dist_et = {
    'n_estimators': [300, 500, 800],
    'min_samples_leaf': [2, 4, 8, 12, 16],
    'min_samples_split': [5, 10, 20],
    'max_depth': [20, 30, 40, None],
    'max_features': ['sqrt', 0.6, 0.8]
}

results_et_df, best_et_model, best_et_params = random_search_et(
    param_dist_et,
    X_train, y_train,
    X_val,   y_val,
    n_iter=60
)

# %% [markdown]
# Gráfico para ver overfit etc

# %%
plt.figure(figsize=(8,6))
sns.scatterplot(
    data=results_et_df,
    x="rmse_train",
    y="rmse_val",
    hue="min_samples_leaf",
    style="max_depth",
    palette="viridis"
)
plt.plot(
    [results_et_df["rmse_train"].min(), results_et_df["rmse_val"].max()],
    [results_et_df["rmse_train"].min(), results_et_df["rmse_val"].max()],
    "--", color="grey"
)
plt.xlabel("RMSE train")
plt.ylabel("RMSE val")
plt.title("Extra Trees — Train vs Validation (Random Search Holdout)")
plt.tight_layout()
plt.show()

# %% [markdown]
# Os parametros com menor RMSE estão meio sus de estar a overfittar por isso vou selecionar os 10 modelos com menor "rmse_val" e desses 10 selecionar o modelo com menor gap.

# %%
results_et_df["gap"] = results_et_df["rmse_val"] - results_et_df["rmse_train"]

top = results_et_df.nsmallest(10, "rmse_val")
best_stable = top.loc[top["gap"].idxmin()]
best_stable
# Out:
# n_estimators                 800
# min_samples_leaf               2
# min_samples_split             10
# max_depth                   40.0
# max_features                 0.6
# rmse_train           1750.194491
# rmse_val             2336.554291
# mae_train             1011.89601
# mae_val              1343.600894
# gap                     586.3598
# Name: 7, dtype: object

# %% [markdown]
# Fazer agora para random forest

# %%
param_rf = {
    "n_estimators": [200, 400, 600, 800],
    "max_depth": [None, 6, 10, 14, 18],
    "min_samples_split": [2, 5, 10, 20],
    "min_samples_leaf": [1, 2, 4, 8],
    "max_features": ["sqrt", "log2", None]
}

results_rf, best_rf, best_rf_params = random_search_model(
    model_class=RandomForestRegressor,
    param_grid=param_rf,
    X_train=X_train, y_train_log=y_train_log,
    X_val=X_val,     y_val_log=y_val_log,
    n_iter=40,
    fixed_params={"random_state": 42, "n_jobs": -1}
)

print("Best RF params:", best_rf_params)

# %%
plt.figure(figsize=(8,6))
sns.scatterplot(
    data=results_rf_df,
    x="rmse_train",
    y="rmse_val",
    hue="min_samples_leaf",
    style="max_depth",
    palette="viridis"
)
plt.plot(
    [results_rf_df["rmse_train"].min(), results_rf_df["rmse_val"].max()],
    [results_rf_df["rmse_train"].min(), results_rf_df["rmse_val"].max()],
    "--", color="grey"
)
plt.xlabel("RMSE train")
plt.ylabel("RMSE val")
plt.title("Random Forest — Train vs Validation (Random Search Holdout)")
plt.tight_layout()
plt.show()

# %%
results_rf_df["gap"] = results_rf_df["rmse_val"] - results_rf_df["rmse_train"]


top = results_rf_df.nsmallest(10, "rmse_val")
best_stable = top.loc[top["gap"].idxmin()]
best_stable
# Out:
# n_estimators                400
# max_depth                    15
# min_samples_leaf              8
# max_features                0.7
# rmse_train          2259.996891
# rmse_val            2572.921841
# gap                   312.92495
# Name: 7, dtype: object

# %% [markdown]
# ### HGBR

# %%
param_hgbr = {
    "learning_rate": [0.01, 0.03, 0.05, 0.08, 0.1],
    "max_depth": [None, 3, 5, 7, 9],
    "max_leaf_nodes": [15, 31, 63, 127],
    "min_samples_leaf": [10, 20, 30, 50],
    "l2_regularization": [0.0, 0.1, 0.5, 1.0],
    "max_bins": [128, 255]
}

results_hgbr, best_hgbr, best_hgbr_params = random_search_model(
    model_class=HistGradientBoostingRegressor,
    param_grid=param_hgbr,
    X_train=X_train, y_train_log=y_train_log,
    X_val=X_val,     y_val_log=y_val_log,
    n_iter=40,
    fixed_params={
        "random_state": 42,
        "early_stopping": False  # mantém avaliação "limpa" só com o teu X_val
    }
)

print("Best HGBR params:", best_hgbr_params)

# %% [markdown]
# Random Search DNN

# %%
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_val_scaled   = scaler.transform(X_val)

param_dist_dnn = {
    "n_hidden":      [1, 2, 3],
    "units":         [32, 64, 128],
    "dropout_rate":  [0.0, 0.2, 0.4],
    "learning_rate": [1e-2, 5e-3, 1e-3],
    "batch_size":    [32, 64, 128],
    "epochs":        [40, 60]
}

def random_search_dnn(param_grid,
                      X_train_s, y_train_log,
                      X_val_s,   y_val_log,
                      n_iter=60):

    results = []
    best_rmse_val = float("inf")
    best_model = None
    best_params = None

    keys = list(param_grid.keys())

    # valores verdadeiros (escala original) – vamos usar sempre os mesmos
    y_train_true = np.expm1(y_train_log)
    y_val_true   = np.expm1(y_val_log)

    for i in range(n_iter):
        # 1) escolher hiperparâmetros aleatórios
        params = {k: random.choice(param_grid[k]) for k in keys}

        # 2) construir modelo
        model = build_dnn(
            input_dim=X_train_s.shape[1],
            n_hidden=params["n_hidden"],
            units=params["units"],
            dropout_rate=params["dropout_rate"],
            learning_rate=params["learning_rate"],
        )

        # early stopping
        early_stop = EarlyStopping(
            monitor='val_loss',
            patience=5,
            restore_best_weights=True,
            verbose=0
        )

        # 3) treinar em log(price)
        model.fit(
            X_train_s, y_train_log,
            validation_data=(X_val_s, y_val_log),
            epochs=params["epochs"],
            batch_size=params["batch_size"],
            callbacks=[early_stop],
            verbose=0
        )

        # 4) previsões (log) -> voltar à escala original
        pred_train_log = model.predict(X_train_s, verbose=0).flatten()
        pred_val_log   = model.predict(X_val_s,   verbose=0).flatten()

        pred_train = np.expm1(pred_train_log)
        pred_val   = np.expm1(pred_val_log)

        # 5) métricas em escala original
        rmse_train = mean_squared_error(y_train_true, pred_train) ** 0.5
        rmse_val   = mean_squared_error(y_val_true,   pred_val) ** 0.5

        results.append({
            **params,
            "rmse_train": rmse_train,
            "rmse_val":   rmse_val,
        })

        print(f"[{i+1}/{n_iter}] rmse_train={rmse_train:.2f} | rmse_val={rmse_val:.2f}")

        # 6) guardar melhor
        if rmse_val < best_rmse_val:
            best_rmse_val = rmse_val
            best_model = model
            best_params = params

    results_dnn_df = (
        pd.DataFrame(results)
        .sort_values("rmse_val")
        .reset_index(drop=True)
    )
    return results_dnn_df, best_model, best_params

results_dnn_df, best_dnn_model, best_dnn_params = random_search_dnn(
    param_dist_dnn,
    X_train_scaled, y_train_log,
    X_val_scaled,   y_val_log,
    n_iter=20  # ajusta consoante o tempo que tiveres
)

print("\nMelhores parâmetros DNN:")
print(best_dnn_params)
print(f"Melhor RMSE_val DNN: {results_dnn_df['rmse_val'].iloc[0]:.2f}")
# Out:
# c:\Users\Catarina\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:95: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# [1/20] rmse_train=3418.31 | rmse_val=3405.70
# c:\Users\Catarina\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:95: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# [2/20] rmse_train=4219.75 | rmse_val=4198.11
# c:\Users\Catarina\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:95: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# [3/20] rmse_train=3265.02 | rmse_val=3294.28
# c:\Users\Catarina\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:95: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# [4/20] rmse_train=3917.11 | rmse_val=3937.31
# c:\Users\Catarina\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:95: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# [5/20] rmse_train=3548.26 | rmse_val=3540.35
# c:\Users\Catarina\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:95: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# [6/20] rmse_train=3596.27 | rmse_val=3596.76
# c:\Users\Catarina\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:95: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# [7/20] rmse_train=3271.28 | rmse_val=3299.86
# c:\Users\Catarina\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:95: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# [8/20] rmse_train=3531.64 | rmse_val=3561.25
# c:\Users\Catarina\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:95: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# [9/20] rmse_train=3406.27 | rmse_val=3423.23
# c:\Users\Catarina\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:95: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# [10/20] rmse_train=3843.90 | rmse_val=3833.04
# c:\Users\Catarina\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:95: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# [11/20] rmse_train=3196.96 | rmse_val=3258.15
# c:\Users\Catarina\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:95: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# [12/20] rmse_train=3387.88 | rmse_val=3421.47
# c:\Users\Catarina\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:95: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# [13/20] rmse_train=3281.17 | rmse_val=3314.88
# c:\Users\Catarina\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:95: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# [14/20] rmse_train=3914.68 | rmse_val=3970.19
# c:\Users\Catarina\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:95: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# [15/20] rmse_train=3617.97 | rmse_val=3606.34
# c:\Users\Catarina\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:95: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# [16/20] rmse_train=3949.11 | rmse_val=3947.34
# c:\Users\Catarina\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:95: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# [17/20] rmse_train=3662.15 | rmse_val=3669.95
# c:\Users\Catarina\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:95: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# [18/20] rmse_train=3841.68 | rmse_val=3822.96
# c:\Users\Catarina\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:95: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# [19/20] rmse_train=3451.34 | rmse_val=3464.53
# c:\Users\Catarina\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:95: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# [20/20] rmse_train=3364.85 | rmse_val=3371.56
#
# Melhores parâmetros DNN:
# {'n_hidden': 3, 'units': 64, 'dropout_rate': 0.0, 'learning_rate': 0.001, 'batch_size': 128, 'epochs': 40}
# Melhor RMSE_val DNN: 3258.15

# %%
results_dnn_df["gap"] = results_dnn_df["rmse_val"] - results_dnn_df["rmse_train"]
results_dnn_df.head()

plt.figure(figsize=(8,6))
sns.scatterplot(
    data=results_dnn_df,
    x="rmse_train",
    y="rmse_val"
)
plt.plot(
    [results_dnn_df["rmse_train"].min(), results_dnn_df["rmse_val"].max()],
    [results_dnn_df["rmse_train"].min(), results_dnn_df["rmse_val"].max()],
    "--", color="grey"
)
plt.xlabel("RMSE train")
plt.ylabel("RMSE val")
plt.title("DNN — Train vs Validation (Random Search Holdout)")
plt.tight_layout()
plt.show()

# %% [markdown]
# Final Benchmarking

# %%
def create_dnn(
    input_dim,
    n_hidden=3,
    units=64,
    dropout_rate=0.0,
    learning_rate=1e-3
):
    model = Sequential()
    model.add(Dense(units, activation='relu', input_shape=(input_dim,)))

    for _ in range(n_hidden - 1):
        model.add(Dense(units, activation='relu'))
        if dropout_rate > 0:
            model.add(Dropout(dropout_rate))

    model.add(Dense(1, activation='linear'))

    model.compile(
        optimizer=Adam(learning_rate=learning_rate),
        loss='mse',
        metrics=['mae']
    )
    return model

# %%
def final_benchmark_log(
    X_train, y_train_log,
    X_val,   y_val_log,
    rf_params,
    et_params,
    dnn_params,
    dnn_epochs=40,
    dnn_batch_size=128
):
    results = {}
    fitted_models = {}

    # valores verdadeiros (escala real)
    y_train_true = np.expm1(y_train_log)
    y_val_true   = np.expm1(y_val_log)

    # ------------------------------------------------
    # 0) Escalamento para DNN
    # ------------------------------------------------
    scaler = StandardScaler()
    X_train_scaled = scaler.fit_transform(X_train)
    X_val_scaled   = scaler.transform(X_val)
    fitted_models["scaler"] = scaler

    # ------------------------------------------------
    # 1) Random Forest (treino em log)
    # ------------------------------------------------
    rf = RandomForestRegressor(
        random_state=42,
        n_jobs=-1,
        **rf_params
    )
    rf.fit(X_train, y_train_log)
    fitted_models["rf"] = rf

    pred_train_log = rf.predict(X_train)
    pred_val_log   = rf.predict(X_val)

    pred_train = np.expm1(pred_train_log)
    pred_val   = np.expm1(pred_val_log)

    results["RF_RMSE_train"] = mean_squared_error(y_train_true, pred_train)**0.5
    results["RF_MAE_train"]  = mean_absolute_error(y_train_true, pred_train)
    results["RF_RMSE_val"]   = mean_squared_error(y_val_true, pred_val)**0.5
    results["RF_MAE_val"]    = mean_absolute_error(y_val_true, pred_val)

    # ------------------------------------------------
    # 2) Extra Trees (treino em log)
    # ------------------------------------------------
    et = ExtraTreesRegressor(
        random_state=42,
        n_jobs=-1,
        **et_params
    )
    et.fit(X_train, y_train_log)
    fitted_models["et"] = et

    pred_train_log = et.predict(X_train)
    pred_val_log   = et.predict(X_val)

    pred_train = np.expm1(pred_train_log)
    pred_val   = np.expm1(pred_val_log)

    results["ET_RMSE_train"] = mean_squared_error(y_train_true, pred_train)**0.5
    results["ET_MAE_train"]  = mean_absolute_error(y_train_true, pred_train)
    results["ET_RMSE_val"]   = mean_squared_error(y_val_true, pred_val)**0.5
    results["ET_MAE_val"]    = mean_absolute_error(y_val_true, pred_val)

    # ------------------------------------------------
    # 3) DNN (treino em log)
    # ------------------------------------------------
    dnn = create_dnn(
        input_dim=X_train.shape[1],
        **dnn_params
    )
    early = EarlyStopping(
        monitor='val_loss',
        patience=5,
        restore_best_weights=True,
        verbose=0
    )

    dnn.fit(
        X_train_scaled, y_train_log,
        validation_data=(X_val_scaled, y_val_log),
        epochs=dnn_epochs,
        batch_size=dnn_batch_size,
        callbacks=[early],
        verbose=0
    )
    fitted_models["dnn"] = dnn

    pred_train_log = dnn.predict(X_train_scaled).flatten()
    pred_val_log   = dnn.predict(X_val_scaled).flatten()

    pred_train = np.expm1(pred_train_log)
    pred_val   = np.expm1(pred_val_log)

    results["DNN_RMSE_train"] = mean_squared_error(y_train_true, pred_train)**0.5
    results["DNN_MAE_train"]  = mean_absolute_error(y_train_true, pred_train)
    results["DNN_RMSE_val"]   = mean_squared_error(y_val_true, pred_val)**0.5
    results["DNN_MAE_val"]    = mean_absolute_error(y_val_true, pred_val)

    # ------------------------------------------------
    # 4) Organizar resultados numa tabela
    # ------------------------------------------------
    df = pd.DataFrame([
        ["RandomForest", results["RF_RMSE_train"], results["RF_MAE_train"], results["RF_RMSE_val"], results["RF_MAE_val"]],
        ["ExtraTrees",   results["ET_RMSE_train"], results["ET_MAE_train"], results["ET_RMSE_val"], results["ET_MAE_val"]],
        ["DNN",          results["DNN_RMSE_train"], results["DNN_MAE_train"], results["DNN_RMSE_val"], results["DNN_MAE_val"]],
    ], columns=["Model","RMSE_train","MAE_train","RMSE_val","MAE_val"])

    df = df.set_index("Model")

    return df, fitted_models

# %%
rf_best_params = {
    "n_estimators": 400,
    "max_depth": 15,
    "min_samples_leaf": 8,
    "max_features": 0.7,
}

et_best_params = {
    "n_estimators": 800,
    "min_samples_leaf": 2,
    "min_samples_split": 5,
    "max_depth": 40,
    "max_features": 0.8,
}

dnn_best_params = {
    "n_hidden": 3,
    "units": 64,
    "dropout_rate": 0.0,
    "learning_rate": 0.001,
}

benchmark_log_df, final_models = final_benchmark_log(
    X_train, y_train_log,
    X_val,   y_val_log,
    rf_params=rf_best_params,
    et_params=et_best_params,
    dnn_params=dnn_best_params,
    dnn_epochs=40,
    dnn_batch_size=128
)

display(benchmark_log_df)
# Out:
# c:\Users\Catarina\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:95: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1651/1651 ━━━━━━━━━━━━━━━━━━━━ 1s 681us/step
# 710/710 ━━━━━━━━━━━━━━━━━━━━ 1s 733us/step
#                RMSE_train    MAE_train     RMSE_val      MAE_val
# Model
# RandomForest  2343.903691  1272.102404  2621.695914  1465.599268
# ExtraTrees    1426.217880   784.742394  2319.658053  1292.446854
# DNN           3239.990971  1930.961629  3281.316554  1978.392189

# %% [markdown]
# ## HistGradientBoostingRegressor

# %%
# 1. Transformar target
y_train_log = np.log1p(y_train)
y_val_log   = np.log1p(y_val)

# 2. Modelo (podes começar com os best_params dela)
hgb_log = HistGradientBoostingRegressor(
    min_samples_leaf=20,
    max_leaf_nodes=31,
    max_iter=500,
    max_depth=10,
    learning_rate=0.5,
    l2_regularization=0,
    random_state=42
)

hgb_log.fit(X_train, y_train_log)

# 3. Previsão e inversão
y_pred_val_log = hgb_log.predict(X_val)
y_pred_val = np.expm1(y_pred_val_log)

# 4. Métricas
mse = mean_squared_error(y_val, y_pred_val)
rmse = np.sqrt(mse)
r2 = r2_score(y_val, y_pred_val)

print("HGBR com log(y)")
print("RMSE:", rmse)
print("R²:", r2)
# Out:
# c:\Users\Catarina\anaconda3\Lib\site-packages\joblib\externals\loky\backend\context.py:136: UserWarning: Could not find the number of physical cores for the following reason:
# [WinError 2] O sistema não conseguiu localizar o ficheiro especificado
# Returning the number of logical cores instead. You can silence this warning by setting LOKY_MAX_CPU_COUNT to the number of cores you want to use.
#   warnings.warn(
#   File "c:\Users\Catarina\anaconda3\Lib\site-packages\joblib\externals\loky\backend\context.py", line 257, in _count_physical_cores
#     cpu_info = subprocess.run(
#         "wmic CPU Get NumberOfCores /Format:csv".split(),
#         capture_output=True,
#         text=True,
#     )
#   File "c:\Users\Catarina\anaconda3\Lib\subprocess.py", line 554, in run
#     with Popen(*popenargs, **kwargs) as process:
#          ~~~~~^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Catarina\anaconda3\Lib\subprocess.py", line 1039, in __init__
#     self._execute_child(args, executable, preexec_fn, close_fds,
#     ~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#                         pass_fds, cwd, env,
#                         ^^^^^^^^^^^^^^^^^^^
#     ...<5 lines>...
#                         gid, gids, uid, umask,
#                         ^^^^^^^^^^^^^^^^^^^^^^
#                         start_new_session, process_group)
#                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Catarina\anaconda3\Lib\subprocess.py", line 1554, in _execute_child
#     hp, ht, pid, tid = _winapi.CreateProcess(executable, args,
#                        ~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^
#                              # no special security
#                              ^^^^^^^^^^^^^^^^^^^^^
#     ...<4 lines>...
#                              cwd,
#                              ^^^^
#                              startupinfo)
#                              ^^^^^^^^^^^^
# HGBR com log(y)
# RMSE: 2246.9016170442883
# R²: 0.946727209027369

# %% [markdown]
# # stacking

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, mean_absolute_error

def rmse(y_true, y_pred):
    return mean_squared_error(y_true, y_pred) ** 0.5

# ==============================
# 1) Recuperar modelos finais
# ==============================
rf_final   = final_models["rf"]
et_final   = final_models["et"]
dnn_final  = final_models["dnn"]
scaler_fin = final_models["scaler"]

# Escalar X para a DNN
X_train_scaled = scaler_fin.transform(X_train)
X_val_scaled   = scaler_fin.transform(X_val)

# Target em escala real
y_val_true = np.expm1(y_val_log)

# ==============================
# 2) Obter previsões em LOG (nível 1)
# ==============================

# Random Forest (log)
rf_val_log  = rf_final.predict(X_val)
# Extra Trees (log)
et_val_log  = et_final.predict(X_val)
# DNN (log)
dnn_val_log = dnn_final.predict(X_val_scaled).flatten()

# Matriz de features para o meta-modelo
X_meta_val = np.column_stack([rf_val_log, et_val_log, dnn_val_log])
y_meta_val = y_val_log

# ==============================
# 3) Meta-modelo (Regressão Linear em log)
# ==============================
meta_model = LinearRegression()
meta_model.fit(X_meta_val, y_meta_val)

# ==============================
# 4) Avaliar individualmente + stacking em escala real
# ==============================

# Previsões individuais em euros
rf_val_pred  = np.expm1(rf_val_log)
et_val_pred  = np.expm1(et_val_log)
dnn_val_pred = np.expm1(dnn_val_log)

# Previsão stacking em log -> euros
stack_val_log  = meta_model.predict(X_meta_val)
stack_val_pred = np.expm1(stack_val_log)

results_stack = pd.DataFrame({
    "Modelo": ["RandomForest", "ExtraTrees", "DNN", "STACKING"],
    "RMSE_Val": [
        rmse(y_val_true, rf_val_pred),
        rmse(y_val_true, et_val_pred),
        rmse(y_val_true, dnn_val_pred),
        rmse(y_val_true, stack_val_pred),
    ],
    "MAE_Val": [
        mean_absolute_error(y_val_true, rf_val_pred),
        mean_absolute_error(y_val_true, et_val_pred),
        mean_absolute_error(y_val_true, dnn_val_pred),
        mean_absolute_error(y_val_true, stack_val_pred),
    ]
})

display(results_stack)

# guardar também o meta-modelo para uso posterior (Kaggle)
final_models["stack_meta"] = meta_model
# Out:
# 710/710 ━━━━━━━━━━━━━━━━━━━━ 1s 763us/step
#          Modelo     RMSE_Val      MAE_Val
# 0  RandomForest  2621.695914  1465.599268
# 1    ExtraTrees  2319.658053  1292.446854
# 2           DNN  3281.316554  1978.392189
# 3      STACKING  2294.270578  1289.299894

# %% [markdown]
# # aplicar no test

# %%
features_to_keep = ['year', 'mileage', 'mpg', 'engineSize', 'engineEfficiency',
                    'brand_encoded', 'model_encoded', 'transmission_encoded', 'tax']

# %%
test_final = test_data[features_to_keep].copy()

# -----------------------------------------
# 2. Recover final models + scaler
# -----------------------------------------
rf_final   = final_models["rf"]
et_final   = final_models["et"]
dnn_final  = final_models["dnn"]
scaler_fin = final_models["scaler"]
meta_model = final_models["stack_meta"]   # stacking meta-model

# -----------------------------------------
# 3. Prepare data for DNN
# -----------------------------------------
X_test_scaled = scaler_fin.transform(test_final)

# -----------------------------------------
# 4. Base model predictions (LOG space)
# -----------------------------------------
rf_test_log  = rf_final.predict(test_final)
et_test_log  = et_final.predict(test_final)
dnn_test_log = dnn_final.predict(X_test_scaled).flatten()

# Matrix for stacking
X_meta_test = np.column_stack([rf_test_log, et_test_log, dnn_test_log])

# -----------------------------------------
# 5. Stacking prediction  (LOG → ORIGINAL SCALE)
# -----------------------------------------
stack_test_log  = meta_model.predict(X_meta_test)
stack_test_pred = np.expm1(stack_test_log)   # convert back to £

# -----------------------------------------
# 6. Build submission DataFrame
# -----------------------------------------
submission = pd.DataFrame({
    "carID": test_final.index,        # index is carID after .set_index earlier
    "price": stack_test_pred
})

# -----------------------------------------
# 7. Export CSV
# -----------------------------------------
submission.to_csv("submission_stacking.csv", index=False)
print("FILE CREATED: submission_stacking.csv")
# Out:
# 1018/1018 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step
# FILE CREATED: submission_stacking.csv
